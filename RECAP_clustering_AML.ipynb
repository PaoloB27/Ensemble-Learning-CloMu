# %% [markdown]
# # IMPORT STATEMENTS

# %%
# enter the directory containing CloMu.py
# %cd CloMu-main

# import some useful libraries
import os
import numpy as np
import CloMu
import matplotlib.pyplot as plt
import random as rd
import time

# import the function that will be used to train an instance of the CloMu model
from CloMu import trainModel
# Out:
# /Users/paolobresolin/Desktop/current working directory/code/CloMu-main

# %% [markdown]
# # UTILITY FUNCTIONS

# %%
# Given dataset, it removes all trees longer than max_length. Then it saves the obtained dataset in path.
# max_length: maximum length of a tree, i.e., maximum number of different mutations a tree can contain.
# dataset: input dataset to process. It is a numpy array of lists. Each list is a patient and it is represented
#          as a list of trees. Given a patient, all associated trees have the same length. A tree is a list of edges.
# path: path where to save the obtained dataset. The dataset is saved as a .npy file with trees stored with the same
#       format of dataset.
# The function returns the created dataset as a numpy array.
def remove_long_trees(max_length, dataset, path):
    
    # create a new numpy array with the same size of dataset
    new_dataset = np.empty(shape=dataset.shape, dtype="object")
    # number of patients added to new_dataset so far
    number_added_patients = 0

    # iterate over the patients in the dataset
    for patient in dataset:

        # length of the trees associated with the current patient
        trees_length = len(patient[0])

        # save the patient in the new dataset only if it is not longer than max_length
        if trees_length <= max_length:
            new_dataset[number_added_patients] = patient
            number_added_patients += 1
        
    # reshape the numpy array so that it contains all and only the added patients
    new_dataset = new_dataset[:number_added_patients]

    # save the dataset as a .npy file
    np.save(path, new_dataset)

    # return the dataset
    return new_dataset

# %%
# Function that, given an input dataset, returns a shuffled version of it.
# input_dataset: the dataset to be shuffled.
# path: path where to save the obtained dataset. The dataset is saved as a .npy file with trees stored with the same
#       format of input_dataset.
# seed: random seed used to allow for reproducibility.
# Returns a shuffled version of input_dataset.
def shuffle_dataset(input_dataset, path, seed):

    # generate a permutation of the indices in input_dataset
    indices = [i for i in range(len(input_dataset))]
    rd.seed(seed)
    rd.shuffle(indices)

    # create a shuffled version of the dataset according to the permutation of indices
    shuffled_dataset = np.empty(shape=input_dataset.shape, dtype="object")

    for i in range(len(indices)):
        shuffled_dataset[i] = input_dataset[indices[i]]
    
    # save the dataset as a .npy file
    np.save(path, shuffled_dataset)
    
    return shuffled_dataset

# %%
# Splits the input dataset into two subsets, where the first one contains n patients chosen uniformly at random
# and the other one contains all other patients in the dataset.
# dataset: input dataset to be split.
# n: number of patients to be included in the first set.
# random_seed: random seed used for choosing patients. For reproducibility seek.
# Returns two sets:
#   ~ n_set contains n patients chosen uniformly at random from dataset;
#   ~ other_set contains all other patients in dataset.
def split_two_n(dataset, n, random_seed):

    # the two subsets to be returned, where set_n will contain almost n trees
    n_set = []
    other_set = []

    # choose uniformly at random n indices of patients in dataset without replacement
    rd.seed(random_seed)
    indices_n_set = rd.sample(range(len(dataset)), n)

    # fill n_set with the patients in dataset with index in indices_n_set
    n_set = [dataset[i] for i in indices_n_set]

    # fill other_set with all other patients in dataset
    other_set = [dataset[i] for i in range(len(dataset)) if i not in indices_n_set]

    return np.array(n_set, dtype=object), np.array(other_set, dtype=object)

# %%
# Function to compute the number of trees in a dataset of patients.
# dataset: the dataset in which we want to compute the number of trees.
# Returns the number of trees in dataset.
def compute_n_trees(dataset):

    n = 0
    for patient in dataset:
        n += len(patient)
    
    return n

# %%
# Function to concatenate two arrays.
# set_1: base array.
# set_2: array to be appended to set_1.
# Returns set_2 appended after set_1.
def concatenate_sets(set_1, set_2):
    
    # array that will be returned
    concatenation = []

    # add the elements of the first array
    for patient in set_1:
        concatenation.append(patient)
    
    # add the elements of the second array
    for patient in set_2:
        concatenation.append(patient)
    
    return np.array(concatenation, dtype=object)

# %%
# Function that checks whether a folder exists and creates it if not.
# path: path to the folder to create.
# Returns True if the folder has been created because it did not exist before and False otherwise.
# It prints a string saying whether the creation of the folder has been completed or not.
def create_folder(path):
    if os.path.exists(path):
        print("Folder " + "path " + "already exists.")
        return False
    else:
        os.mkdir(path)
        print("Folder " + "path " + "created successfully.")
        return True

# %%
# Function that, given a set of clusters, trains a different instance of CloMu on each cluster and returns the
# computed probabilities for the clusters and for the test set.
# clustering: list of clusters.
# test_cluster: test set to be appended to each cluster during training. The models will not be trained on the test
#               set, but they will assign probabilities to trees in the test set.
# dest: path to the directory where all results will be stored.
# n_iter: number of iterations for each training.
# Returns two list of lists of probabilities:
#   ~ the first list contains an array of probabilities for each cluster, containing the probabilities assigned to
#     those trees belonging to that cluster;
#   ~ the second list contains an array of probabilities for each cluster, but containing the values assigned by the
#     model trained on the corresponding cluster to trees in the test set.
def train_on_clustering(clustering, test_cluster, dest, n_iter=1000):

    # check whether the destination folder exists and create it otherwise
    _ = create_folder(dest)
    
    # list that will contain the probabilities assigned to trees belonging to patients in the clusters
    clusters_prob = []
    # list that will contain the probabilities assigned to trees belonging to patients in the test set
    test_prob = []

    # set some parameters necessary for training
    input_format = "raw"
    regularize_factor = "default"
    infinite_sites = False
    verbose = True
    n_iterations = n_iter
    max_tree_length = 10

    # compute the number of trees in the test set
    n_trees_test_cl = compute_n_trees(test_cluster)

    # iterate over the single clusters
    for i in range(len(clustering)):

        # create the folders where to store datasets and training results related with the current cluster
        subfolder_name = "cluster_" + str(i + 1)
        cluster_i_folder = os.path.join(dest, subfolder_name)
        _ = create_folder(cluster_i_folder)

        datasets_folder = os.path.join(cluster_i_folder, "datasets")
        _ = create_folder(datasets_folder)
        training_folder = os.path.join(cluster_i_folder, "training_results")
        _ = create_folder(training_folder)

        # append the test cluster to the current cluster and save the resulting dataset
        complete_cluster = concatenate_sets(clustering[i], test_cluster)
        complete_cluster_name = "cluster_" + str(i) + "_and_test_set.npy"
        complete_cluster_path = os.path.join(datasets_folder, complete_cluster_name)
        np.save(complete_cluster_path, complete_cluster)

        # set some parameters needed for training
        input_files = [complete_cluster_path]
        curr_model_name = "cluster_" + str(i) + "_model.pt"
        model_file = os.path.join(training_folder, curr_model_name)
        curr_prob_name = "cluster_" + str(i) + "_prob.npy"
        prob_file = os.path.join(training_folder, curr_prob_name)
        curr_mut_name = "cluster_" + str(i) + "_mutations.npy"
        mutation_file = os.path.join(training_folder, curr_mut_name)

        n_patients_training = len(clustering[i])
        
        # train an instance of the CloMu model on the cluster considered in this iteration
        trainModel(input_files, model_file, prob_file, mutation_file, patientNames='', inputFormat=input_format, infiniteSites=infinite_sites, trainSize=n_patients_training, maxM=max_tree_length, regularizeFactor=regularize_factor, iterations=n_iterations, verbose=verbose)

        # load the probabilities and append them to the corresponding lists
        curr_prob = np.load(prob_file, allow_pickle=True)
        clusters_prob.append(curr_prob[:-n_trees_test_cl])
        test_prob.append(curr_prob[-n_trees_test_cl:])

    return clusters_prob, test_prob

# %%
# Function that extracts clusters ids of patients from the .txt file that results from the application of RECAP
# to a dataset of patients.
# path: path to the output .txt file from the application of RECAP.
# Returns a list of cluster indices, where indices_list[i] is the cluster index for patient i in the original dataset
# given as input to RECAP.
def extract_cluster_indices(path):

    # list of clusters indices for patients
    indices_list = []
    
    # open the file and read it line by line
    with open(path, 'r') as file:
        
        # iterate over the lines in the file
        for line in file:
            
            # check whether the line contains the word "cluster" and extract the index in case
            if "cluster" in line:
                # the cluster index is always the first word in the line
                indices_list.append(line[0])
    
    # remove the first value in the list, because it is the total number of clusters
    indices_list = indices_list[1:]

    return indices_list

# %%
# Function that, given a dataset of patients and a list of cluster indices for them, returns the corresponding
# clusters of patients.
# dataset: input dataset of patients.
# cluster_indices: list of cluster indices for patients in dataset. cluster_indices[i] is the cluster index for
#                  patient dataset[i].
# Returns a list of clusters of patients.
def get_clusters(dataset, cluster_indices):

    # create an empty dictionary that will contain clusters ids as keys and lists of patients as values
    dict_clusters = {}

    # assign each patient in dataset to the cluster with index in cluster_indices
    for i in range(len(cluster_indices)):
        
        # check whether the cluster with index cluster_indices[i] has already been initialized
        if cluster_indices[i] in dict_clusters:
            dict_clusters[cluster_indices[i]].append(dataset[i])
        else:
            dict_clusters[cluster_indices[i]] = [dataset[i]]

    # create a list of clusters from the dictionary
    list_clusters = []
    for key in dict_clusters.keys():
        list_clusters.append(dict_clusters[key])
    
    return list_clusters

# %% [markdown]
# # PATHS AND FOLDERS CREATION

# %%
# path to the current directory
current_dir = os.getcwd()

# create the folder where to store the training results
main_folder = os.path.join(current_dir, "..", "RECAP_clustering_AML")
_ = create_folder(main_folder)

# create the folder where to store the dataset
dataset_folder = os.path.join(main_folder, "datasets")
_ = create_folder(dataset_folder)

# create the folder where to store the clusterings results
results_clusterings_folder = os.path.join(main_folder, "results_clusterings")
_ = create_folder(results_clusterings_folder)

# create a folder for each value of K inside results_clusterings
results_clusterings_k_2_folder = os.path.join(results_clusterings_folder, "K_2")
_ = create_folder(results_clusterings_k_2_folder)
results_clusterings_k_3_folder = os.path.join(results_clusterings_folder, "K_3")
_ = create_folder(results_clusterings_k_3_folder)
results_clusterings_k_4_folder = os.path.join(results_clusterings_folder, "K_4")
_ = create_folder(results_clusterings_k_4_folder)

# create the folder where to store the trainings results
results_trainings_folder = os.path.join(main_folder, "results_trainings")
_ = create_folder(results_trainings_folder)

# create a folder for each value of K inside results_trainings
results_trainings_k_2_folder = os.path.join(results_trainings_folder, "K_2")
_ = create_folder(results_trainings_k_2_folder)
results_trainings_k_3_folder = os.path.join(results_trainings_folder, "K_3")
_ = create_folder(results_trainings_k_3_folder)
results_trainings_k_4_folder = os.path.join(results_trainings_folder, "K_4")
_ = create_folder(results_trainings_k_4_folder)

# path to the input file for training
input_file_AML = os.path.join(current_dir, "data", "realData", "AML.npy")
# Out:
# Folder path already exists.
# Folder path already exists.
# Folder path already exists.
# Folder path already exists.
# Folder path already exists.
# Folder path already exists.
# Folder path already exists.
# Folder path already exists.
# Folder path already exists.
# Folder path already exists.

# %% [markdown]
# # DATASET

# %% [markdown]
# ### Pre-processing

# %% [markdown]
# We remove too long trees from the dataset and shuffle the resulting set as a pre-processing step.

# %%
# random seed for reproducibility of the shuffle
RANDOM_SEED = 27

# maximum number of mutations allowed for each tree, i.e., maximum tree length
maxM = 10

# load the original dataset as a numpy array
treeData = np.load(input_file_AML, allow_pickle=True)

# remove too long trees
treeData = remove_long_trees(maxM, treeData, os.path.join(dataset_folder, "processed_AML_dataset.npy"))

# shuffle the dataset and save it as a .npy file
dataset_file = os.path.join(dataset_folder, "shuffled_AML_dataset.npy")
treeData = shuffle_dataset(treeData, dataset_file, RANDOM_SEED)

# compute the number of trees in the dataset
n_trees_dataset = compute_n_trees(treeData)

# print the number of patients in the dataset and the number of trees
print("Number of patients in the dataset: " + str(len(treeData)))
print("Number of trees in the dataset: " + str(n_trees_dataset))
# Out:
# Number of patients in the dataset: 75
# Number of trees in the dataset: 105

# %% [markdown]
# ### Split into training set and test set

# %%
# number of patients to be included in the training set: 2/3 of the overall number of patients in the dataset
n_patients_train = len(treeData) // 3 * 2
n_patients_test = len(treeData) - n_patients_train

# split the dataset into training set and test set
training_set, test_set = split_two_n(treeData, n_patients_train, RANDOM_SEED)

# save the two datasets and the new complete dataset with test_set appended after training_set
training_set_file = os.path.join(dataset_folder, "training_set_AML.npy")
np.save(training_set_file, training_set)

test_set_file = os.path.join(dataset_folder, "test_set_AML.npy")
np.save(test_set_file, test_set)

treeData = np.concatenate((training_set, test_set))
treeData_file = os.path.join(dataset_folder, "complete_final_treeData.npy")
np.save(treeData_file, treeData)

# compute the number of trees in each set
n_trees_train = compute_n_trees(training_set)
n_trees_test = compute_n_trees(test_set)

# print number of patients and trees in each set
print("Number of patients in the training set: " + str(len(training_set)))
print("Number of patients in the test set: " + str(len(test_set)))
print()
print("Number of trees in the training set: " + str(n_trees_train))
print("Number of trees in the test set: " + str(n_trees_test))
# Out:
# Number of patients in the training set: 50
# Number of patients in the test set: 25
#
# Number of trees in the training set: 76
# Number of trees in the test set: 29

# %% [markdown]
# # CLUSTER PATIENTS WITH RECAP

# %% [markdown]
# ## Input dataset

# %% [markdown]
# ### Collapse mutations at gene level

# %% [markdown]
# #### Function

# %%
# Function that, given a dataset of patients, collapeses the mutations appearing in the trees at gene level.
# dataset: input dataset of patients.
# Returns a version of dataset where mutations are collapsed at gene level.
def collapse_gene_level(dataset):

    # new version of the dataset that will be returned
    new_dataset = []

    # iterate over patients
    for patient in dataset:
        
        # new version of the current patient
        new_patient = []

        # iterate over trees of the current patient
        for tree in patient:

            # new version of the current tree of the current patient
            new_tree = []

            # iterate over edges of the current tree
            for edge in tree:

                # new version of the edge
                new_edge = []

                # iterate over the pair of mutations contained in the edge
                for mutation in edge:

                    # new version of the current mutation
                    new_mutation = ""

                    # collapse the mutation at gene level
                    for i in range(len(mutation)):
                        if mutation[i] == "_" or mutation[i] == ".":
                            break
                        else:
                            new_mutation += mutation[i]
                    
                    # add the collapsed mutation to the new edge
                    new_edge.append(new_mutation)
                
                # add new_edge to new_tree
                new_tree.append(new_edge)
            
            # add new_tree to new_patient
            new_patient.append(new_tree)
        
        # add new_patient to new_dataset
        new_dataset.append(new_patient)
    
    return new_dataset

# %% [markdown]
# #### Apply the function

# %%
# collapse mutations in the training set at gene level
collapsed_training_set = collapse_gene_level(training_set)

# %% [markdown]
# ### Dataset format conversion

# %% [markdown]
# #### Function

# %%
# Function to save a dataset stored as a numpy array in a .txt file following the format required for RECAP.
# dataset: numpy array containing patients stored as lists of trees, where each tree is a list of edges.
# path: path where to store the converted dataset.
# Creates a .txt file containing dataset, but stored according to the RECAP format.
def convert_to_RECAP(dataset, path):

    # open the file
    with open(path, 'w') as file:
        
        # the first thing to write is the number of patients
        first_line = str(len(dataset)) + " # patients\n"
        file.write(first_line)

        # consider each patient one at the time
        for i in range(len(dataset)):

            # now we need to write the number of trees contained by the current patient
            curr_line = str(len(dataset[i])) + " # trees patient " + str(i) + "\n"
            file.write(curr_line)

            # iterate over the trees of the current patient
            for j in range(len(dataset[i])):

                # write the number of edges in the current tree
                curr_line = str(len(dataset[i][j])) + " # edges tree " + str(j) + "\n"
                file.write(curr_line)

                # iterate over the edges of the current tree
                for edge in dataset[i][j]:

                    # save the two ordered mutations related to the current edge
                    mut_1 = edge[0]
                    mut_2 = edge[1]

                    # write the two ordered mutations on a line of the file
                    curr_line = mut_1 + " " + mut_2 + "\n"
                    file.write(curr_line)

    # print that the file has been created and written
    print("The file has been correctly created and written.")

# %% [markdown]
# #### Apply the function to the training set

# %%
path_RECAP_dataset = os.path.join(dataset_folder, "RECAP_input_dataset.txt")
convert_to_RECAP(collapsed_training_set, path_RECAP_dataset)
# convert_to_RECAP(training_set, path_RECAP_dataset)
# Out:
# The file has been correctly created and written.

# %% [markdown]
# ## Cluster patients with RECAP

# %% [markdown]
# ### 50 Restarts

# %% [markdown]
# #### K = 2

# %%
# clustering with K = 2 and 50 restarts
start_time = time.time()
# !./../RECAP/build/recap -k 2 -p "./../RECAP_clustering_AML/results_clusterings/K_2/k2_50" -R "Root" "./../RECAP_clustering_AML/datasets/RECAP_input_dataset.txt"
end_time = time.time()

elapsed_time = end_time - start_time
elapsed_hours = int(elapsed_time // (60 * 60))
elapsed_minutes = int((elapsed_time % (60 * 60)) // 60)
elapsed_seconds = int((elapsed_time % (60 * 60)) % 60)
string_time = str(elapsed_hours) + "h " + str(elapsed_minutes) + "min " + str(elapsed_seconds) + "sec"

print()
print("Time required for clustering with K = 2: " +  string_time)
# Out:
# Time required for clustering with K = 2: 0h 0min 0sec

# %% [markdown]
# #### K = 3

# %%
# clustering with K = 3 and 50 restarts
start_time = time.time()
# !./../RECAP/build/recap -k 3 -p "./../RECAP_clustering_AML/results_clusterings/K_3/k3_50" -R "Root" "./../RECAP_clustering_AML/datasets/RECAP_input_dataset.txt"
end_time = time.time()

elapsed_time = end_time - start_time
elapsed_hours = int(elapsed_time // (60 * 60))
elapsed_minutes = int((elapsed_time % (60 * 60)) // 60)
elapsed_seconds = int((elapsed_time % (60 * 60)) % 60)
string_time = str(elapsed_hours) + "h " + str(elapsed_minutes) + "min " + str(elapsed_seconds) + "sec"

print()
print("Time required for clustering with K = 3: " +  string_time)
# Out:
# Time required for clustering with K = 3: 0h 0min 0sec

# %% [markdown]
# #### K = 4

# %%
# clustering with K = 4 and 50 restarts
start_time = time.time()
# !./../RECAP/build/recap -k 4 -p "./../RECAP_clustering_AML/results_clusterings/K_4/k4_50" -R "Root" "./../RECAP_clustering_AML/datasets/RECAP_input_dataset.txt"
end_time = time.time()

elapsed_time = end_time - start_time
elapsed_hours = int(elapsed_time // (60 * 60))
elapsed_minutes = int((elapsed_time % (60 * 60)) // 60)
elapsed_seconds = int((elapsed_time % (60 * 60)) % 60)
string_time = str(elapsed_hours) + "h " + str(elapsed_minutes) + "min " + str(elapsed_seconds) + "sec"

print()
print("Time required for clustering with K = 4: " +  string_time)
# Out:
# Time required for clustering with K = 4: 0h 0min 0sec

# %% [markdown]
# ### 1000 Restarts

# %% [markdown]
# #### K = 2

# %%
# clustering with K = 2 and 1000 restarts
start_time = time.time()
# !./../RECAP/build/recap -k 2 -r 1000 -p "./../RECAP_clustering_AML/results_clusterings/K_2/k2" -R "Root" "./../RECAP_clustering_AML/datasets/RECAP_input_dataset.txt"
end_time = time.time()

elapsed_time = end_time - start_time
elapsed_hours = int(elapsed_time // (60 * 60))
elapsed_minutes = int((elapsed_time % (60 * 60)) // 60)
elapsed_seconds = int((elapsed_time % (60 * 60)) % 60)
string_time = str(elapsed_hours) + "h " + str(elapsed_minutes) + "min " + str(elapsed_seconds) + "sec"

print()
print("Time required for clustering with K = 2: " +  string_time)
# Out:
# Time required for clustering with K = 2: 0h 0min 0sec

# %% [markdown]
# #### K = 3

# %%
# clustering with K = 3 and 1000 restarts
start_time = time.time()
# !./../RECAP/build/recap -k 3 -r 1000 -p "./../RECAP_clustering_AML/results_clusterings/K_3/k3" -R "Root" "./../RECAP_clustering_AML/datasets/RECAP_input_dataset.txt"
end_time = time.time()

elapsed_time = end_time - start_time
elapsed_hours = int(elapsed_time // (60 * 60))
elapsed_minutes = int((elapsed_time % (60 * 60)) // 60)
elapsed_seconds = int((elapsed_time % (60 * 60)) % 60)
string_time = str(elapsed_hours) + "h " + str(elapsed_minutes) + "min " + str(elapsed_seconds) + "sec"

print()
print("Time required for clustering with K = 3: " +  string_time)
# Out:
# Time required for clustering with K = 3: 0h 0min 0sec

# %% [markdown]
# #### K = 4

# %%
# clustering with K = 4 and 1000 restarts
start_time = time.time()
# !./../RECAP/build/recap -k 4 -r 1000 -p "./../RECAP_clustering_AML/results_clusterings/K_4/k4" -R "Root" "./../RECAP_clustering_AML/datasets/RECAP_input_dataset.txt"
end_time = time.time()

elapsed_time = end_time - start_time
elapsed_hours = int(elapsed_time // (60 * 60))
elapsed_minutes = int((elapsed_time % (60 * 60)) // 60)
elapsed_seconds = int((elapsed_time % (60 * 60)) % 60)
string_time = str(elapsed_hours) + "h " + str(elapsed_minutes) + "min " + str(elapsed_seconds) + "sec"

print()
print("Time required for clustering with K = 4: " +  string_time)
# Out:
# Time required for clustering with K = 4: 0h 0min 0sec

# %% [markdown]
# ## Extract clusters

# %% [markdown]
# ### 1000 restarts, K = 2

# %%
# path to the file containing the output from RECAP that provides a cluster id per patient in the dataset
clustering_path = os.path.join(results_clusterings_k_2_folder, "k2.solution.txt")

# extract indices for patients
cluster_indices = extract_cluster_indices(clustering_path)

# retrieve the actual clusters of patients
clustering_K_2 = get_clusters(training_set, cluster_indices)

# %% [markdown]
# ### 1000 restarts, K = 3

# %%
# path to the file containing the output from RECAP that provides a cluster id per patient in the dataset
clustering_path = os.path.join(results_clusterings_k_3_folder, "k3.solution.txt")

# extract indices for patients
cluster_indices = extract_cluster_indices(clustering_path)

# retrieve the actual clusters of patients
clustering_K_3 = get_clusters(training_set, cluster_indices)

# %% [markdown]
# ### 1000 restarts, K = 4

# %%
# path to the file containing the output from RECAP that provides a cluster id per patient in the dataset
clustering_path = os.path.join(results_clusterings_k_4_folder, "k4.solution.txt")

# extract indices for patients
cluster_indices = extract_cluster_indices(clustering_path)

# retrieve the actual clusters of patients
clustering_K_4 = get_clusters(training_set, cluster_indices)

# %% [markdown]
# # TRAIN ON CLUSTERS

# %% [markdown]
# ## K = 2

# %%
# train on the clustering with K = 2 and extract the probabilities assigned by the model
start_time = time.time()
clusters_K_2_prob, test_K_2_prob = train_on_clustering(clustering_K_2, test_set, results_trainings_k_2_folder, n_iter=1000)
end_time = time.time()

elapsed_time = end_time - start_time
elapsed_hours = int(elapsed_time // (60 * 60))
elapsed_minutes = int((elapsed_time % (60 * 60)) // 60)
elapsed_seconds = int((elapsed_time % (60 * 60)) % 60)
string_time = str(elapsed_hours) + "h " + str(elapsed_minutes) + "min " + str(elapsed_seconds) + "sec"

print()
print("Time required for training on clustering with K = 2: " +  string_time)
# Out:
# Folder path already exists.
# Folder path created successfully.
# Folder path created successfully.
# Folder path created successfully.
# iteration 0 of 1000
#
# Mean Probability:  1.7530657688781802e-05
# Training Score:  -12.828952962495691 Testing Score: -12.164518917810467
# Loss:  11.61777594737829
# iteration 1 of 1000
#
# Mean Probability:  3.491859671158163e-05
# Training Score:  -12.547995148293877 Testing Score: -11.791066771110422
# Loss:  7.648923281757793
# iteration 2 of 1000
#
# Mean Probability:  5.208783355085209e-05
# Training Score:  -12.364058587513252 Testing Score: -11.557916059063695
# Loss:  5.211794723540308
# iteration 3 of 1000
#
# Mean Probability:  6.829000011959357e-05
# Training Score:  -12.228427873062879 Testing Score: -11.381426239758584
# Loss:  4.52388772889513
# iteration 4 of 1000
#
# Mean Probability:  8.344654925909917e-05
# Training Score:  -12.129800277504796 Testing Score: -11.255430216841807
# Loss:  3.4829871448003287
# iteration 5 of 1000
#
# Mean Probability:  9.771069749944759e-05
# Training Score:  -12.041684081356113 Testing Score: -11.144151121591246
# Loss:  3.6289468214465344
# iteration 6 of 1000
#
# Mean Probability:  0.00011111679967991403
# Training Score:  -11.968466064376214 Testing Score: -11.05548590974113
# Loss:  3.064979062766023
# iteration 7 of 1000
#
# Mean Probability:  0.00012350854132804756
# Training Score:  -11.907711061530026 Testing Score: -10.966744744088741
# Loss:  2.688620581198831
# iteration 8 of 1000
#
# Mean Probability:  0.00013522245194991738
# Training Score:  -11.85532112856136 Testing Score: -10.899996622051656
# Loss:  2.639185058040694
# iteration 9 of 1000
#
# Mean Probability:  0.00014598968941749004
# Training Score:  -11.809494568944203 Testing Score: -10.837066273212479
# Loss:  2.3301961648796805
# iteration 10 of 1000
#
# Mean Probability:  0.00015562720719326207
# Training Score:  -11.771768914083333 Testing Score: -10.788250738493053
# Loss:  2.424038160817677
# iteration 11 of 1000
#
# Mean Probability:  0.00016501461382961008
# Training Score:  -11.73438381065211 Testing Score: -10.736600362787765
# Loss:  2.0722435916790554
# iteration 12 of 1000
#
# Mean Probability:  0.0001736628537297885
# Training Score:  -11.700318692252155 Testing Score: -10.691116726785237
# Loss:  2.4193704426021663
# iteration 13 of 1000
#
# Mean Probability:  0.000181554303101115
# Training Score:  -11.670204501934585 Testing Score: -10.662111504073764
# Loss:  1.8191292732493152
# iteration 14 of 1000
#
# Mean Probability:  0.00018843137110173482
# Training Score:  -11.645081286042046 Testing Score: -10.627568701630501
# Loss:  1.7209644442836247
# iteration 15 of 1000
#
# Mean Probability:  0.00019600522212378472
# Training Score:  -11.61408291946014 Testing Score: -10.593150750821557
# Loss:  1.9897226866890825
# iteration 16 of 1000
#
# Mean Probability:  0.00020192068464201592
# Training Score:  -11.593581647351373 Testing Score: -10.569777617674333
# Loss:  1.8879165796154231
# iteration 17 of 1000
#
# Mean Probability:  0.0002080707100351239
# Training Score:  -11.573862912524813 Testing Score: -10.540615704568932
# Loss:  1.703026333663582
# iteration 18 of 1000
#
# Mean Probability:  0.0002132426838044583
# Training Score:  -11.552739203249786 Testing Score: -10.512552822891834
# Loss:  1.5666718981832906
# iteration 19 of 1000
#
# Mean Probability:  0.0002178617606133188
# Training Score:  -11.538784664406496 Testing Score: -10.500273154082558
# Loss:  1.5049847170626092
# iteration 20 of 1000
#
# Mean Probability:  0.00022377221289617794
# Training Score:  -11.51832434718242 Testing Score: -10.466502317377106
# Loss:  1.6471921396491205
# iteration 21 of 1000
#
# Mean Probability:  0.00022773964177033956
# Training Score:  -11.505692909875975 Testing Score: -10.4464417532775
# Loss:  1.492101628163376
# iteration 22 of 1000
#
# Mean Probability:  0.0002314288389233384
# Training Score:  -11.49296013970089 Testing Score: -10.439063915072918
# Loss:  1.6171851326842028
# iteration 23 of 1000
#
# Mean Probability:  0.00023531006428096927
# Training Score:  -11.473207323843667 Testing Score: -10.435021072197594
# Loss:  1.797605082283737
# iteration 24 of 1000
#
# Mean Probability:  0.00023929037299553013
# Training Score:  -11.461795370204026 Testing Score: -10.422600457359552
# Loss:  1.3707869634330458
# iteration 25 of 1000
#
# Mean Probability:  0.00024284836028422196
# Training Score:  -11.45176369799224 Testing Score: -10.414743810091041
# Loss:  1.3683523592475288
# iteration 26 of 1000
#
# Mean Probability:  0.00024614544167219114
# Training Score:  -11.43978849788689 Testing Score: -10.409526188323053
# Loss:  1.5183799734635632
# iteration 27 of 1000
#
# Mean Probability:  0.0002493322710761445
# Training Score:  -11.431074976401131 Testing Score: -10.406213683049693
# Loss:  1.3013608009197877
# iteration 28 of 1000
#
# Mean Probability:  0.00025232668874183384
# Training Score:  -11.418787550808291 Testing Score: -10.398746510607923
# Loss:  1.5878215621333391
# iteration 29 of 1000
#
# Mean Probability:  0.0002550667640312034
# Training Score:  -11.410676592455022 Testing Score: -10.384467346291393
# Loss:  1.4137421255833569
# iteration 30 of 1000
#
# Mean Probability:  0.0002573700410000145
# Training Score:  -11.403303402908262 Testing Score: -10.372718361558041
# Loss:  1.239350894654636
# iteration 31 of 1000
#
# Mean Probability:  0.0002596330923742075
# Training Score:  -11.39850717788536 Testing Score: -10.351353048942046
# Loss:  1.430211395289151
# iteration 32 of 1000
#
# Mean Probability:  0.0002614654593871344
# Training Score:  -11.388322111254242 Testing Score: -10.351906336074078
# Loss:  1.444793262828002
# iteration 33 of 1000
#
# Mean Probability:  0.0002637976441232396
# Training Score:  -11.378604133638682 Testing Score: -10.344279262875283
# Loss:  1.306358234064511
# iteration 34 of 1000
#
# Mean Probability:  0.0002655906272304612
# Training Score:  -11.375514124434284 Testing Score: -10.342438049203828
# Loss:  1.3323013414552782
# iteration 35 of 1000
#
# Mean Probability:  0.0002681962710317899
# Training Score:  -11.36856608524683 Testing Score: -10.33246543600613
# Loss:  1.4113347789102542
# iteration 36 of 1000
#
# Mean Probability:  0.0002700007939213841
# Training Score:  -11.35962952266598 Testing Score: -10.325406176915035
# Loss:  1.286610797041424
# iteration 37 of 1000
#
# Mean Probability:  0.0002725535092139097
# Training Score:  -11.353524906233663 Testing Score: -10.322939996747293
# Loss:  1.2900776653401729
# iteration 38 of 1000
#
# Mean Probability:  0.0002740966352543321
# Training Score:  -11.346731000581977 Testing Score: -10.31491936563401
# Loss:  1.2883721504713974
# iteration 39 of 1000
#
# Mean Probability:  0.00027561453677617633
# Training Score:  -11.34108185383334 Testing Score: -10.313497894112295
# Loss:  1.5884781075776935
# iteration 40 of 1000
#
# Mean Probability:  0.000277012009574475
# Training Score:  -11.33641785680617 Testing Score: -10.306054359167806
# Loss:  1.2191524130961984
# iteration 41 of 1000
#
# Mean Probability:  0.00027905339697426815
# Training Score:  -11.334083365105084 Testing Score: -10.294108745508838
# Loss:  1.097800135207533
# iteration 42 of 1000
#
# Mean Probability:  0.00028050025714156237
# Training Score:  -11.330566965946643 Testing Score: -10.296219612139929
# Loss:  1.3193871360122158
# iteration 43 of 1000
#
# Mean Probability:  0.0002820552699114048
# Training Score:  -11.324852616562398 Testing Score: -10.298337141912887
# Loss:  1.2204020752830147
# iteration 44 of 1000
#
# Mean Probability:  0.00028338392162654196
# Training Score:  -11.322545969990317 Testing Score: -10.287868445995057
# Loss:  1.1779313698490141
# iteration 45 of 1000
#
# Mean Probability:  0.0002841073313948326
# Training Score:  -11.316061144749428 Testing Score: -10.283807809028621
# Loss:  1.3463451956610084
# iteration 46 of 1000
#
# Mean Probability:  0.00028525215985499404
# Training Score:  -11.31168353571016 Testing Score: -10.27933300468492
# Loss:  1.3352065534005597
# iteration 47 of 1000
#
# Mean Probability:  0.00028697673996688284
# Training Score:  -11.307510837501425 Testing Score: -10.278947570589871
# Loss:  1.1531170585974313
# iteration 48 of 1000
#
# Mean Probability:  0.0002878730989959043
# Training Score:  -11.30698051651956 Testing Score: -10.279164411858403
# Loss:  1.159788724460705
# iteration 49 of 1000
#
# Mean Probability:  0.000289491048928101
# Training Score:  -11.302768055820184 Testing Score: -10.272027054544987
# Loss:  1.2424831964130705
# iteration 50 of 1000
#
# Mean Probability:  0.0002921661100253547
# Training Score:  -11.29900914622132 Testing Score: -10.243992498109895
# Loss:  1.389082782005247
# iteration 51 of 1000
#
# Mean Probability:  0.00029314284248233913
# Training Score:  -11.299131794516967 Testing Score: -10.233046731932868
# Loss:  1.3388714657158483
# iteration 52 of 1000
#
# Mean Probability:  0.0002939459708124816
# Training Score:  -11.29487987907699 Testing Score: -10.234463653595807
# Loss:  1.2296926294137895
# iteration 53 of 1000
#
# Mean Probability:  0.0002954889009560249
# Training Score:  -11.293805581290773 Testing Score: -10.227590059659502
# Loss:  1.289027233000056
# iteration 54 of 1000
#
# Mean Probability:  0.0002968636740337
# Training Score:  -11.288053907716872 Testing Score: -10.22867373509058
# Loss:  1.4357463846628375
# iteration 55 of 1000
#
# Mean Probability:  0.00029843309761319516
# Training Score:  -11.284637430580405 Testing Score: -10.229028355588612
# Loss:  1.1561254885104841
# iteration 56 of 1000
#
# Mean Probability:  0.0002997968148224205
# Training Score:  -11.281506693178814 Testing Score: -10.226043991060502
# Loss:  1.4170217108856813
# iteration 57 of 1000
#
# Mean Probability:  0.00030073992087870793
# Training Score:  -11.281732313871416 Testing Score: -10.224373655000873
# Loss:  1.1423754182656052
# iteration 58 of 1000
#
# Mean Probability:  0.0003018268924345419
# Training Score:  -11.28289366446053 Testing Score: -10.226539111793192
# Loss:  1.0031613309149812
# iteration 59 of 1000
#
# Mean Probability:  0.00030261973618024124
# Training Score:  -11.275826178003678 Testing Score: -10.219209158492882
# Loss:  1.1914788681768687
# iteration 60 of 1000
#
# Mean Probability:  0.00030332684800385683
# Training Score:  -11.270998301136457 Testing Score: -10.224934734952122
# Loss:  1.151741642578755
# iteration 61 of 1000
#
# Mean Probability:  0.0003043770086065162
# Training Score:  -11.265303539422755 Testing Score: -10.217456281845282
# Loss:  1.2180917956958668
# iteration 62 of 1000
#
# Mean Probability:  0.00030459181829589144
# Training Score:  -11.267582529090618 Testing Score: -10.210418484924697
# Loss:  1.4088189883295859
# iteration 63 of 1000
#
# Mean Probability:  0.0003046501229657499
# Training Score:  -11.268001435426203 Testing Score: -10.200027670596803
# Loss:  1.181527147037842
# iteration 64 of 1000
#
# Mean Probability:  0.00030514101724848285
# Training Score:  -11.267724018147032 Testing Score: -10.190333004559095
# Loss:  1.2331998983967127
# iteration 65 of 1000
#
# Mean Probability:  0.0003051887974253214
# Training Score:  -11.262576046973521 Testing Score: -10.196948246437309
# Loss:  1.3064924574569141
# iteration 66 of 1000
#
# Mean Probability:  0.000305473530263868
# Training Score:  -11.261361673374244 Testing Score: -10.192910207770035
# Loss:  0.9958855285656563
# iteration 67 of 1000
#
# Mean Probability:  0.00030688622275296085
# Training Score:  -11.256033128685388 Testing Score: -10.200048846393797
# Loss:  1.2265705787911232
# iteration 68 of 1000
#
# Mean Probability:  0.00030741364948851796
# Training Score:  -11.253096571121423 Testing Score: -10.199421255123646
# Loss:  1.3898202911298674
# iteration 69 of 1000
#
# Mean Probability:  0.00030863727620276715
# Training Score:  -11.251342536865906 Testing Score: -10.194697244415288
# Loss:  1.234070008127401
# iteration 70 of 1000
#
# Mean Probability:  0.00031045957666062693
# Training Score:  -11.240204549924837 Testing Score: -10.199348719242899
# Loss:  1.296998920752366
# iteration 71 of 1000
#
# Mean Probability:  0.0003116818719894903
# Training Score:  -11.23946703052233 Testing Score: -10.189606815505115
# Loss:  1.2280367936612822
# iteration 72 of 1000
#
# Mean Probability:  0.0003122714936800442
# Training Score:  -11.237583802171686 Testing Score: -10.188034911199388
# Loss:  1.3474859311000729
# iteration 73 of 1000
#
# Mean Probability:  0.0003128751079958254
# Training Score:  -11.23401481466881 Testing Score: -10.193280249705337
# Loss:  1.1842964408872618
# iteration 74 of 1000
#
# Mean Probability:  0.0003131384704142778
# Training Score:  -11.232701092717303 Testing Score: -10.190621938686848
# Loss:  1.1389782287099117
# iteration 75 of 1000
#
# Mean Probability:  0.00031300648928523934
# Training Score:  -11.227562114261433 Testing Score: -10.190062324780774
# Loss:  1.1250428770658472
# iteration 76 of 1000
#
# Mean Probability:  0.0003129318503755185
# Training Score:  -11.232560193979124 Testing Score: -10.194386533512194
# Loss:  1.1286976049337296
# iteration 77 of 1000
#
# Mean Probability:  0.0003140064243211962
# Training Score:  -11.232958706707437 Testing Score: -10.178974009115457
# Loss:  1.067520106589889
# iteration 78 of 1000
#
# Mean Probability:  0.00031643993439457426
# Training Score:  -11.225449925806606 Testing Score: -10.185630012335038
# Loss:  1.1942920235681167
# iteration 79 of 1000
#
# Mean Probability:  0.0003176686504165056
# Training Score:  -11.224458047025516 Testing Score: -10.186034956555629
# Loss:  1.328285736776635
# iteration 80 of 1000
#
# Mean Probability:  0.0003192305439276239
# Training Score:  -11.219027343986866 Testing Score: -10.180635803678669
# Loss:  1.2209571689309549
# iteration 81 of 1000
#
# Mean Probability:  0.00031979228584255476
# Training Score:  -11.214156068763396 Testing Score: -10.187072660007889
# Loss:  1.2101435070096513
# iteration 82 of 1000
#
# Mean Probability:  0.0003197898197806164
# Training Score:  -11.215187877041188 Testing Score: -10.192856390329677
# Loss:  1.1763472398321295
# iteration 83 of 1000
#
# Mean Probability:  0.000319854825584553
# Training Score:  -11.219015491143827 Testing Score: -10.188258822323174
# Loss:  1.0759263155651637
# iteration 84 of 1000
#
# Mean Probability:  0.00032076215450489633
# Training Score:  -11.215539361184806 Testing Score: -10.19166890910279
# Loss:  1.3760626883614324
# iteration 85 of 1000
#
# Mean Probability:  0.0003206296760485997
# Training Score:  -11.212220928848463 Testing Score: -10.193231132441557
# Loss:  1.4058078109055794
# iteration 86 of 1000
#
# Mean Probability:  0.00032042797793669693
# Training Score:  -11.214176294726265 Testing Score: -10.197270630494211
# Loss:  1.319518495697457
# iteration 87 of 1000
#
# Mean Probability:  0.0003215061039085176
# Training Score:  -11.211021470031334 Testing Score: -10.18057735749845
# Loss:  1.0862725100337383
# iteration 88 of 1000
#
# Mean Probability:  0.00032151986476927744
# Training Score:  -11.209536994147188 Testing Score: -10.174212877649818
# Loss:  1.1832167104754165
# iteration 89 of 1000
#
# Mean Probability:  0.0003229672287825517
# Training Score:  -11.209146356136365 Testing Score: -10.165172709662102
# Loss:  1.1856262929966035
# iteration 90 of 1000
#
# Mean Probability:  0.0003238214543251247
# Training Score:  -11.209703926140111 Testing Score: -10.169772376738429
# Loss:  1.0640157041658125
# iteration 91 of 1000
#
# Mean Probability:  0.00032479364947884726
# Training Score:  -11.203998566490018 Testing Score: -10.176537793130866
# Loss:  1.0941130188806996
# iteration 92 of 1000
#
# Mean Probability:  0.0003248383025395928
# Training Score:  -11.196215835823665 Testing Score: -10.180622061244978
# Loss:  1.1934823126308252
# iteration 93 of 1000
#
# Mean Probability:  0.0003249312331097364
# Training Score:  -11.196062338548481 Testing Score: -10.174873133751644
# Loss:  1.2082333374951097
# iteration 94 of 1000
#
# Mean Probability:  0.0003265198793149634
# Training Score:  -11.198259472981423 Testing Score: -10.155873786909517
# Loss:  1.1147317945932969
# iteration 95 of 1000
#
# Mean Probability:  0.00032653300989077906
# Training Score:  -11.203217871751738 Testing Score: -10.151142543472996
# Loss:  0.9518784167886207
# iteration 96 of 1000
#
# Mean Probability:  0.0003265688763762645
# Training Score:  -11.202203678196877 Testing Score: -10.136649718755704
# Loss:  1.066917612191787
# iteration 97 of 1000
#
# Mean Probability:  0.0003278713509926195
# Training Score:  -11.198577902188385 Testing Score: -10.132126669987274
# Loss:  1.2769401911005933
# iteration 98 of 1000
#
# Mean Probability:  0.0003287531387739604
# Training Score:  -11.196237293786645 Testing Score: -10.134950686582876
# Loss:  1.2770003581265819
# iteration 99 of 1000
#
# Mean Probability:  0.000328384422456189
# Training Score:  -11.19656395001419 Testing Score: -10.142741358101272
# Loss:  0.9579564404074408
# iteration 100 of 1000
#
# Mean Probability:  0.0003284543458449144
# Training Score:  -11.200328075124508 Testing Score: -10.146342590845356
# Loss:  1.0609915512616674
# iteration 101 of 1000
#
# Mean Probability:  0.0003290158193122963
# Training Score:  -11.202041192262111 Testing Score: -10.15405463803413
# Loss:  1.2479703618802322
# iteration 102 of 1000
#
# Mean Probability:  0.0003313363846782966
# Training Score:  -11.201151443112389 Testing Score: -10.144831825892911
# Loss:  1.189762617883472
# iteration 103 of 1000
#
# Mean Probability:  0.0003323981540266698
# Training Score:  -11.19777679228848 Testing Score: -10.138374970221598
# Loss:  1.0996877280422483
# iteration 104 of 1000
#
# Mean Probability:  0.0003328353847224428
# Training Score:  -11.19180118082094 Testing Score: -10.140721776237255
# Loss:  1.167177180199709
# iteration 105 of 1000
#
# Mean Probability:  0.00033413067011646555
# Training Score:  -11.194174965117268 Testing Score: -10.13547391283317
# Loss:  1.2725970341207047
# iteration 106 of 1000
#
# Mean Probability:  0.00033546370170727777
# Training Score:  -11.186425682089967 Testing Score: -10.127670901406253
# Loss:  1.1565826336930927
# iteration 107 of 1000
#
# Mean Probability:  0.00033717322102993895
# Training Score:  -11.183882081106328 Testing Score: -10.110320359231453
# Loss:  1.0216260493179337
# iteration 108 of 1000
#
# Mean Probability:  0.00033807493016641937
# Training Score:  -11.177180677163829 Testing Score: -10.117297139162401
# Loss:  1.1940494230346617
# iteration 109 of 1000
#
# Mean Probability:  0.00033854217840669523
# Training Score:  -11.176359015644575 Testing Score: -10.125388472125936
# Loss:  1.0954355611344124
# iteration 110 of 1000
#
# Mean Probability:  0.000338135067914671
# Training Score:  -11.179428391020686 Testing Score: -10.132574182648323
# Loss:  0.95364931363596
# iteration 111 of 1000
#
# Mean Probability:  0.00033878518655401413
# Training Score:  -11.173159386653756 Testing Score: -10.126302965310792
# Loss:  0.9732511843264928
# iteration 112 of 1000
#
# Mean Probability:  0.00033930996724526575
# Training Score:  -11.172210402748592 Testing Score: -10.130985336833119
# Loss:  1.129288503051387
# iteration 113 of 1000
#
# Mean Probability:  0.00033913566401971097
# Training Score:  -11.173861003176777 Testing Score: -10.12168603537474
# Loss:  1.4141910564201068
# iteration 114 of 1000
#
# Mean Probability:  0.00033875129789467966
# Training Score:  -11.174181256511453 Testing Score: -10.127121999716314
# Loss:  1.2130373468877949
# iteration 115 of 1000
#
# Mean Probability:  0.00033906456484018556
# Training Score:  -11.16844382317593 Testing Score: -10.13460166689199
# Loss:  1.2204247895789027
# iteration 116 of 1000
#
# Mean Probability:  0.00033982559768045264
# Training Score:  -11.163898731706695 Testing Score: -10.125784135284754
# Loss:  1.4756885572055314
# iteration 117 of 1000
#
# Mean Probability:  0.0003398936263576576
# Training Score:  -11.159051385257301 Testing Score: -10.1282055186159
# Loss:  1.2897968180567774
# iteration 118 of 1000
#
# Mean Probability:  0.0003410708284969814
# Training Score:  -11.154922184517858 Testing Score: -10.125307378361533
# Loss:  1.1177758353980418
# iteration 119 of 1000
#
# Mean Probability:  0.00034064861473145414
# Training Score:  -11.158246216862057 Testing Score: -10.129659594251985
# Loss:  0.9594292813750374
# iteration 120 of 1000
#
# Mean Probability:  0.00034094864762794876
# Training Score:  -11.158559369457336 Testing Score: -10.131820194691745
# Loss:  1.114558557941184
# iteration 121 of 1000
#
# Mean Probability:  0.00034162850432752073
# Training Score:  -11.154335254621834 Testing Score: -10.135609736933958
# Loss:  1.113046366090109
# iteration 122 of 1000
#
# Mean Probability:  0.0003412073416615547
# Training Score:  -11.154133694700862 Testing Score: -10.136415603776861
# Loss:  1.0341876455873187
# iteration 123 of 1000
#
# Mean Probability:  0.00034120351118942347
# Training Score:  -11.153392082504112 Testing Score: -10.139592308128
# Loss:  1.1298171510565655
# iteration 124 of 1000
#
# Mean Probability:  0.00034158534532285374
# Training Score:  -11.155200942959851 Testing Score: -10.14103621662145
# Loss:  0.9070016442097839
# iteration 125 of 1000
#
# Mean Probability:  0.00034139202694870134
# Training Score:  -11.152302179903634 Testing Score: -10.144359268244663
# Loss:  0.9839780892255698
# iteration 126 of 1000
#
# Mean Probability:  0.0003419672430000827
# Training Score:  -11.155166893964104 Testing Score: -10.146229040260836
# Loss:  1.2780162834285231
# iteration 127 of 1000
#
# Mean Probability:  0.00034323515479689915
# Training Score:  -11.152447065842026 Testing Score: -10.150774002768854
# Loss:  1.1948381119780207
# iteration 128 of 1000
#
# Mean Probability:  0.0003443398758272017
# Training Score:  -11.151539239231923 Testing Score: -10.155151876278069
# Loss:  1.1950970470330375
# iteration 129 of 1000
#
# Mean Probability:  0.0003443292789931557
# Training Score:  -11.150571642794347 Testing Score: -10.125753828605811
# Loss:  1.046100729953891
# iteration 130 of 1000
#
# Mean Probability:  0.00034549199071750284
# Training Score:  -11.139652593749116 Testing Score: -10.11252576526908
# Loss:  1.1526256342693273
# iteration 131 of 1000
#
# Mean Probability:  0.00034564628494871487
# Training Score:  -11.145972731680594 Testing Score: -10.105415299460667
# Loss:  0.926044114080041
# iteration 132 of 1000
#
# Mean Probability:  0.00034656525699216893
# Training Score:  -11.147284977593136 Testing Score: -10.108845500623785
# Loss:  0.9525977560013604
# iteration 133 of 1000
#
# Mean Probability:  0.00034753892327181105
# Training Score:  -11.140269806355633 Testing Score: -10.11615134079434
# Loss:  1.0866457610692701
# iteration 134 of 1000
#
# Mean Probability:  0.00034774832162773724
# Training Score:  -11.1326672073329 Testing Score: -10.096817456693516
# Loss:  1.0884094718223616
# iteration 135 of 1000
#
# Mean Probability:  0.00034877519425910854
# Training Score:  -11.132799037139984 Testing Score: -10.098524841686624
# Loss:  1.096809694669397
# iteration 136 of 1000
#
# Mean Probability:  0.0003494442607906728
# Training Score:  -11.128101734417806 Testing Score: -10.102121070563152
# Loss:  1.092922453427685
# iteration 137 of 1000
#
# Mean Probability:  0.0003506480472217844
# Training Score:  -11.128318079665988 Testing Score: -10.109703358569112
# Loss:  1.4927030120913225
# iteration 138 of 1000
#
# Mean Probability:  0.00035080303585712094
# Training Score:  -11.127258010241794 Testing Score: -10.115013716843498
# Loss:  1.186921921706471
# iteration 139 of 1000
#
# Mean Probability:  0.00035228052012654113
# Training Score:  -11.113852061650498 Testing Score: -10.121757243288545
# Loss:  1.1182457734634315
# iteration 140 of 1000
#
# Mean Probability:  0.0003520348679649937
# Training Score:  -11.10943431284534 Testing Score: -10.128147718361566
# Loss:  1.3127021284550764
# iteration 141 of 1000
#
# Mean Probability:  0.0003516864760184357
# Training Score:  -11.11159780419086 Testing Score: -10.122926379813753
# Loss:  1.1969174126213418
# iteration 142 of 1000
#
# Mean Probability:  0.0003525920596736058
# Training Score:  -11.110597800447339 Testing Score: -10.112015593551265
# Loss:  1.0459317958783245
# iteration 143 of 1000
#
# Mean Probability:  0.00035579571919318456
# Training Score:  -11.10095386309399 Testing Score: -10.103866791541718
# Loss:  1.0853008790107337
# iteration 144 of 1000
#
# Mean Probability:  0.0003562355092348454
# Training Score:  -11.100489838241318 Testing Score: -10.099878831102304
# Loss:  1.3433070159893177
# iteration 145 of 1000
#
# Mean Probability:  0.000356270394677426
# Training Score:  -11.099275725329866 Testing Score: -10.106199622952786
# Loss:  1.2043903006246852
# iteration 146 of 1000
#
# Mean Probability:  0.00035748184578977637
# Training Score:  -11.104441870937201 Testing Score: -10.090133238208983
# Loss:  0.9752595431351676
# iteration 147 of 1000
#
# Mean Probability:  0.0003567592474854828
# Training Score:  -11.098373337465226 Testing Score: -10.098173837872569
# Loss:  1.1026199494021927
# iteration 148 of 1000
#
# Mean Probability:  0.0003575781207388894
# Training Score:  -11.09770220011633 Testing Score: -10.102549303499138
# Loss:  0.9689995252178906
# iteration 149 of 1000
#
# Mean Probability:  0.00035756778561126966
# Training Score:  -11.09898229934857 Testing Score: -10.094098886089197
# Loss:  1.4204586797642897
# iteration 150 of 1000
#
# Mean Probability:  0.0003586714500844257
# Training Score:  -11.09509674601508 Testing Score: -10.07610095664634
# Loss:  1.1062365989581253
# iteration 151 of 1000
#
# Mean Probability:  0.00035814320142317523
# Training Score:  -11.093915847076005 Testing Score: -10.064423615516182
# Loss:  1.19776456855314
# iteration 152 of 1000
#
# Mean Probability:  0.000357960111320751
# Training Score:  -11.09319473680629 Testing Score: -10.067815561857035
# Loss:  1.1821309123378534
# iteration 153 of 1000
#
# Mean Probability:  0.00035874278290844353
# Training Score:  -11.094854514824686 Testing Score: -10.067236301228148
# Loss:  0.8579099548578663
# iteration 154 of 1000
#
# Mean Probability:  0.00035858615881265274
# Training Score:  -11.089255612362408 Testing Score: -10.072141651912567
# Loss:  1.018481326507645
# iteration 155 of 1000
#
# Mean Probability:  0.0003585998690844495
# Training Score:  -11.088044535453742 Testing Score: -10.075536384347046
# Loss:  1.1467036760692886
# iteration 156 of 1000
#
# Mean Probability:  0.00035909146844074347
# Training Score:  -11.080996480369196 Testing Score: -10.079228573156747
# Loss:  1.3659584234102435
# iteration 157 of 1000
#
# Mean Probability:  0.00036057858729957504
# Training Score:  -11.07712253544856 Testing Score: -10.069377853055713
# Loss:  1.0308694554910378
# iteration 158 of 1000
#
# Mean Probability:  0.0003616063512370659
# Training Score:  -11.083405180826164 Testing Score: -10.058078520828664
# Loss:  1.1717846024905223
# iteration 159 of 1000
#
# Mean Probability:  0.000362841886528063
# Training Score:  -11.088265569624452 Testing Score: -10.043749372508673
# Loss:  0.9356303225156186
# iteration 160 of 1000
#
# Mean Probability:  0.0003626737813119142
# Training Score:  -11.087720783539655 Testing Score: -10.031644090605585
# Loss:  1.0157716562562702
# iteration 161 of 1000
#
# Mean Probability:  0.0003628093020022361
# Training Score:  -11.082221199065073 Testing Score: -10.040372244438041
# Loss:  1.3133325598208472
# iteration 162 of 1000
#
# Mean Probability:  0.0003625636021925568
# Training Score:  -11.079693764697854 Testing Score: -10.036392116652998
# Loss:  0.9462789084309401
# iteration 163 of 1000
#
# Mean Probability:  0.00036295322183751137
# Training Score:  -11.078448407075598 Testing Score: -10.036670805958886
# Loss:  1.2012197961070001
# iteration 164 of 1000
#
# Mean Probability:  0.0003622627584767239
# Training Score:  -11.082370493442948 Testing Score: -10.043876079279835
# Loss:  0.9305421588122191
# iteration 165 of 1000
#
# Mean Probability:  0.00036260528755942565
# Training Score:  -11.08402320619372 Testing Score: -10.043652900398058
# Loss:  1.1796645859126897
# iteration 166 of 1000
#
# Mean Probability:  0.0003628099735297603
# Training Score:  -11.085418725910928 Testing Score: -10.031861473353564
# Loss:  0.9785220951569331
# iteration 167 of 1000
#
# Mean Probability:  0.0003628898807766048
# Training Score:  -11.085595099477612 Testing Score: -10.028515895110983
# Loss:  0.9945160147284634
# iteration 168 of 1000
#
# Mean Probability:  0.0003619997145909314
# Training Score:  -11.083900393311872 Testing Score: -10.035435640387165
# Loss:  1.0338219642485527
# iteration 169 of 1000
#
# Mean Probability:  0.0003611803795527843
# Training Score:  -11.086404123364513 Testing Score: -10.044515008280674
# Loss:  1.297784488483373
# iteration 170 of 1000
#
# Mean Probability:  0.0003631318982385073
# Training Score:  -11.070706321366409 Testing Score: -10.052637878991433
# Loss:  1.1929002778387652
# iteration 171 of 1000
#
# Mean Probability:  0.0003625710487284006
# Training Score:  -11.072200034475932 Testing Score: -10.045874054862939
# Loss:  1.0255274289334209
# iteration 172 of 1000
#
# Mean Probability:  0.0003623385177052198
# Training Score:  -11.067721325432496 Testing Score: -10.042351933035057
# Loss:  1.445019451718032
# iteration 173 of 1000
#
# Mean Probability:  0.0003634311709318222
# Training Score:  -11.066420815370913 Testing Score: -10.048374180289288
# Loss:  1.0295167211477216
# iteration 174 of 1000
#
# Mean Probability:  0.00036345692065400357
# Training Score:  -11.071063319788793 Testing Score: -10.043175191729674
# Loss:  0.8741588789521562
# iteration 175 of 1000
#
# Mean Probability:  0.00036397153142130175
# Training Score:  -11.07178244708581 Testing Score: -10.047909084811739
# Loss:  0.9501693546478388
# iteration 176 of 1000
#
# Mean Probability:  0.0003666250196500519
# Training Score:  -11.074136571999338 Testing Score: -10.032238332587246
# Loss:  1.0985927838780254
# iteration 177 of 1000
#
# Mean Probability:  0.0003656216352288562
# Training Score:  -11.07677787795056 Testing Score: -10.030623591043224
# Loss:  1.0224335243687452
# iteration 178 of 1000
#
# Mean Probability:  0.0003657727351798542
# Training Score:  -11.075592660246553 Testing Score: -10.020055116889752
# Loss:  1.170393467270283
# iteration 179 of 1000
#
# Mean Probability:  0.00036561313222664514
# Training Score:  -11.077973836427496 Testing Score: -10.028219066693119
# Loss:  1.2165340236117586
# iteration 180 of 1000
#
# Mean Probability:  0.00036719310107694627
# Training Score:  -11.075195756695772 Testing Score: -10.017835006530422
# Loss:  1.093422860700326
# iteration 181 of 1000
#
# Mean Probability:  0.0003683443091197394
# Training Score:  -11.069709860184778 Testing Score: -10.014443740174439
# Loss:  1.0131203722471336
# iteration 182 of 1000
#
# Mean Probability:  0.0003694193751018856
# Training Score:  -11.070136337177622 Testing Score: -10.005358862716717
# Loss:  0.9740190854719455
# iteration 183 of 1000
#
# Mean Probability:  0.00036946366628764083
# Training Score:  -11.066298553495606 Testing Score: -10.014778334818212
# Loss:  1.153877968162672
# iteration 184 of 1000
#
# Mean Probability:  0.00036832378585642246
# Training Score:  -11.064801607255466 Testing Score: -10.019156902577109
# Loss:  1.1390671060037154
# iteration 185 of 1000
#
# Mean Probability:  0.00036885400483411017
# Training Score:  -11.064294324112728 Testing Score: -10.02706074168104
# Loss:  1.0531455078793504
# iteration 186 of 1000
#
# Mean Probability:  0.00036814968538552477
# Training Score:  -11.064707511151326 Testing Score: -10.023478512042988
# Loss:  1.0372316581975927
# iteration 187 of 1000
#
# Mean Probability:  0.00036745910053406853
# Training Score:  -11.05909958693363 Testing Score: -10.021722267398504
# Loss:  1.0931467842367146
# iteration 188 of 1000
#
# Mean Probability:  0.0003697769734317031
# Training Score:  -11.060897523276793 Testing Score: -10.011182731593987
# Loss:  1.272584094034308
# iteration 189 of 1000
#
# Mean Probability:  0.0003696381158363977
# Training Score:  -11.067059981605027 Testing Score: -10.021357825095617
# Loss:  1.0628120995381536
# iteration 190 of 1000
#
# Mean Probability:  0.00036885809587565205
# Training Score:  -11.063539124523414 Testing Score: -10.03102523605036
# Loss:  0.9754492847457836
# iteration 191 of 1000
#
# Mean Probability:  0.00037032725494583413
# Training Score:  -11.06554195645399 Testing Score: -10.018867881186502
# Loss:  0.9093518203396509
# iteration 192 of 1000
#
# Mean Probability:  0.0003709443354840804
# Training Score:  -11.053257305374451 Testing Score: -10.025481714236477
# Loss:  1.1553010880630967
# iteration 193 of 1000
#
# Mean Probability:  0.00037049566444461574
# Training Score:  -11.051036738175293 Testing Score: -10.03172269261679
# Loss:  1.130488420906945
# iteration 194 of 1000
#
# Mean Probability:  0.0003733225743412155
# Training Score:  -11.045349214782028 Testing Score: -10.040706065294103
# Loss:  1.0268041705727722
# iteration 195 of 1000
#
# Mean Probability:  0.0003738952105915567
# Training Score:  -11.039069502084278 Testing Score: -10.046637489616328
# Loss:  1.221344053558847
# iteration 196 of 1000
#
# Mean Probability:  0.0003735331389251553
# Training Score:  -11.042380523029657 Testing Score: -10.040875079675484
# Loss:  1.0045383366468967
# iteration 197 of 1000
#
# Mean Probability:  0.0003727064669681795
# Training Score:  -11.041193882870544 Testing Score: -10.049253113059626
# Loss:  0.9776160746945971
# iteration 198 of 1000
#
# Mean Probability:  0.0003719534365737881
# Training Score:  -11.04620419797422 Testing Score: -10.054715703570738
# Loss:  0.9275202735606672
# iteration 199 of 1000
#
# Mean Probability:  0.00037472343098753584
# Training Score:  -11.040744880432797 Testing Score: -10.04319852842853
# Loss:  1.1565858371079107
# iteration 200 of 1000
#
# Mean Probability:  0.0003738691761511264
# Training Score:  -11.038917774671647 Testing Score: -10.051261214131467
# Loss:  1.332286519820726
# iteration 201 of 1000
#
# Mean Probability:  0.000375703475499731
# Training Score:  -11.03704109007468 Testing Score: -10.040633099787785
# Loss:  0.9081575789900985
# iteration 202 of 1000
#
# Mean Probability:  0.0003790938512608149
# Training Score:  -11.02810969078565 Testing Score: -10.045858768515048
# Loss:  1.254027114981546
# iteration 203 of 1000
#
# Mean Probability:  0.0003791092867772043
# Training Score:  -11.023516321389913 Testing Score: -10.051795103883272
# Loss:  1.1178749379433714
# iteration 204 of 1000
#
# Mean Probability:  0.00038041718224707206
# Training Score:  -11.025691410048411 Testing Score: -10.055886512910508
# Loss:  0.9643481725411325
# iteration 205 of 1000
#
# Mean Probability:  0.00037996101084702337
# Training Score:  -11.017306892936357 Testing Score: -10.061464082969582
# Loss:  1.1446030301947037
# iteration 206 of 1000
#
# Mean Probability:  0.00038067931668830105
# Training Score:  -11.019511767401697 Testing Score: -10.065004221510819
# Loss:  1.265317704600509
# iteration 207 of 1000
#
# Mean Probability:  0.0003839275277903464
# Training Score:  -11.012480704698845 Testing Score: -10.058058129442907
# Loss:  1.0828623468371479
# iteration 208 of 1000
#
# Mean Probability:  0.0003833479279692398
# Training Score:  -11.019330964860956 Testing Score: -10.060448693500312
# Loss:  0.8479977114836057
# iteration 209 of 1000
#
# Mean Probability:  0.00038634150848794116
# Training Score:  -11.019085487932346 Testing Score: -10.033041154333889
# Loss:  1.4274046712197554
# iteration 210 of 1000
#
# Mean Probability:  0.0003850604750367339
# Training Score:  -11.023627983371385 Testing Score: -10.039484022406686
# Loss:  1.2093494506533922
# iteration 211 of 1000
#
# Mean Probability:  0.0003851098168102641
# Training Score:  -11.026639113447862 Testing Score: -10.047081227009302
# Loss:  1.0275182848782514
# iteration 212 of 1000
#
# Mean Probability:  0.0003843184796774957
# Training Score:  -11.019838952003212 Testing Score: -10.054014169269443
# Loss:  0.9644322065246488
# iteration 213 of 1000
#
# Mean Probability:  0.000387083962681301
# Training Score:  -11.02072316111638 Testing Score: -10.043616465249585
# Loss:  1.0268236382168001
# iteration 214 of 1000
#
# Mean Probability:  0.00038664236769668145
# Training Score:  -11.020357975248066 Testing Score: -10.03333610703498
# Loss:  1.198792402257188
# iteration 215 of 1000
#
# Mean Probability:  0.0003856912582573258
# Training Score:  -11.022332863432052 Testing Score: -10.029025489268118
# Loss:  1.0547702777816692
# iteration 216 of 1000
#
# Mean Probability:  0.0003851779862958329
# Training Score:  -11.019713346569636 Testing Score: -10.035296474621958
# Loss:  1.3268141347142155
# iteration 217 of 1000
#
# Mean Probability:  0.00038648377670088695
# Training Score:  -11.021825713290285 Testing Score: -10.039169893671415
# Loss:  1.0471190181060765
# iteration 218 of 1000
#
# Mean Probability:  0.00038545733664280556
# Training Score:  -11.020655839972374 Testing Score: -10.043535566798989
# Loss:  0.957954030043194
# iteration 219 of 1000
#
# Mean Probability:  0.0003863981869211824
# Training Score:  -11.023727203953278 Testing Score: -10.043735789690672
# Loss:  1.0886115013804076
# iteration 220 of 1000
#
# Mean Probability:  0.000385920364073406
# Training Score:  -11.026493299088813 Testing Score: -10.0329294144874
# Loss:  0.9768304581627912
# iteration 221 of 1000
#
# Mean Probability:  0.0003854192005937775
# Training Score:  -11.026880326033718 Testing Score: -10.018022297477247
# Loss:  1.0129240808393
# iteration 222 of 1000
#
# Mean Probability:  0.00038677157973810144
# Training Score:  -11.020626907950415 Testing Score: -10.008931035845347
# Loss:  1.1556668972369113
# iteration 223 of 1000
#
# Mean Probability:  0.000387211091868495
# Training Score:  -11.016968795506553 Testing Score: -10.004562535949042
# Loss:  1.100495712432664
# iteration 224 of 1000
#
# Mean Probability:  0.00038608678082628596
# Training Score:  -11.017637021047454 Testing Score: -10.012330377215696
# Loss:  1.0199825525159532
# iteration 225 of 1000
#
# Mean Probability:  0.0003865552331291142
# Training Score:  -11.017904709376264 Testing Score: -10.00275093051104
# Loss:  1.0444983942244503
# iteration 226 of 1000
#
# Mean Probability:  0.0003869852234335485
# Training Score:  -11.010326930471098 Testing Score: -9.998374198639398
# Loss:  1.216158713307514
# iteration 227 of 1000
#
# Mean Probability:  0.0003864317747365382
# Training Score:  -11.007744202142923 Testing Score: -10.004173330058991
# Loss:  1.1433095600685788
# iteration 228 of 1000
#
# Mean Probability:  0.000387077798419202
# Training Score:  -11.006699210117358 Testing Score: -10.000637472067961
# Loss:  1.0906121252722238
# iteration 229 of 1000
#
# Mean Probability:  0.0003878615914850744
# Training Score:  -11.010732524742304 Testing Score: -10.01017817071065
# Loss:  1.138815807341049
# iteration 230 of 1000
#
# Mean Probability:  0.0003873805555482423
# Training Score:  -11.01545158210665 Testing Score: -10.017949924639883
# Loss:  0.9327483799028804
# iteration 231 of 1000
#
# Mean Probability:  0.0003870850732921475
# Training Score:  -11.018529359228744 Testing Score: -10.02074034445256
# Loss:  1.0714709586769184
# iteration 232 of 1000
#
# Mean Probability:  0.0003885484622382677
# Training Score:  -11.012380383964834 Testing Score: -10.025627285808868
# Loss:  1.1546924634906532
# iteration 233 of 1000
#
# Mean Probability:  0.0003903974977268059
# Training Score:  -11.012249082881668 Testing Score: -10.026126347737852
# Loss:  0.9359128860883051
# iteration 234 of 1000
#
# Mean Probability:  0.0003897627026633932
# Training Score:  -11.016902000347631 Testing Score: -10.031993940904066
# Loss:  1.1465182667147793
# iteration 235 of 1000
#
# Mean Probability:  0.00039093714985525543
# Training Score:  -11.008969167356408 Testing Score: -10.036392524413683
# Loss:  1.2264870588634265
# iteration 236 of 1000
#
# Mean Probability:  0.0003914619253581042
# Training Score:  -10.999384157296435 Testing Score: -10.033322072896754
# Loss:  1.026334157427439
# iteration 237 of 1000
#
# Mean Probability:  0.00039379619546961784
# Training Score:  -10.994006151838413 Testing Score: -10.010616638495236
# Loss:  1.043539231397423
# iteration 238 of 1000
#
# Mean Probability:  0.0003949038530699105
# Training Score:  -10.99426241088816 Testing Score: -10.011824427292092
# Loss:  1.0096123528211427
# iteration 239 of 1000
#
# Mean Probability:  0.00039425226976398247
# Training Score:  -10.999394792386239 Testing Score: -10.007846253427186
# Loss:  0.9257393467985282
# iteration 240 of 1000
#
# Mean Probability:  0.0003976260353834805
# Training Score:  -10.98683915034869 Testing Score: -9.984920170962436
# Loss:  1.1456716187126286
# iteration 241 of 1000
#
# Mean Probability:  0.00039654827920015224
# Training Score:  -10.989626857664248 Testing Score: -9.993849529825049
# Loss:  1.0587857667791347
# iteration 242 of 1000
#
# Mean Probability:  0.0003959769405618147
# Training Score:  -10.993503344085235 Testing Score: -10.001808079920757
# Loss:  1.3440525238247314
# iteration 243 of 1000
#
# Mean Probability:  0.0003958817271657961
# Training Score:  -10.998202661989943 Testing Score: -10.009311173520999
# Loss:  0.9235872987885844
# iteration 244 of 1000
#
# Mean Probability:  0.000396275204813678
# Training Score:  -10.997180086161771 Testing Score: -9.998415814160396
# Loss:  0.966001056046978
# iteration 245 of 1000
#
# Mean Probability:  0.00039727474623031835
# Training Score:  -10.999379887906258 Testing Score: -10.003282434667899
# Loss:  1.0025509634471108
# iteration 246 of 1000
#
# Mean Probability:  0.00039809513704517426
# Training Score:  -11.00047768581432 Testing Score: -10.010620080812764
# Loss:  0.9914361813859335
# iteration 247 of 1000
#
# Mean Probability:  0.0003987271871921713
# Training Score:  -11.00362849133097 Testing Score: -10.00378528691544
# Loss:  0.9064113082159728
# iteration 248 of 1000
#
# Mean Probability:  0.0003997221214087415
# Training Score:  -11.00060985816038 Testing Score: -10.012130300996045
# Loss:  0.9977540189574314
# iteration 249 of 1000
#
# Mean Probability:  0.0004000688451548998
# Training Score:  -10.99383499720008 Testing Score: -10.018878082134009
# Loss:  1.0954610673607799
# iteration 250 of 1000
#
# Mean Probability:  0.00040127914213226504
# Training Score:  -10.991336327846039 Testing Score: -10.00822940549871
# Loss:  1.0832046787618546
# iteration 251 of 1000
#
# Mean Probability:  0.0004021335416698975
# Training Score:  -10.993044858437738 Testing Score: -10.008408780947752
# Loss:  1.0048019444311316
# iteration 252 of 1000
#
# Mean Probability:  0.0004015626520295338
# Training Score:  -10.995423796802342 Testing Score: -9.991226106326064
# Loss:  0.9639868998155116
# iteration 253 of 1000
#
# Mean Probability:  0.000402918204798707
# Training Score:  -10.996165112985107 Testing Score: -9.99002055075445
# Loss:  1.3125592444730905
# iteration 254 of 1000
#
# Mean Probability:  0.0004065992572382068
# Training Score:  -10.997005834191032 Testing Score: -9.980839830207692
# Loss:  0.9483237879538162
# iteration 255 of 1000
#
# Mean Probability:  0.00040925163922802865
# Training Score:  -10.99110051708007 Testing Score: -9.960088389348108
# Loss:  1.2531924993424102
# iteration 256 of 1000
#
# Mean Probability:  0.00040978339598909063
# Training Score:  -10.993330076732386 Testing Score: -9.959733269409561
# Loss:  0.9120554252277675
# iteration 257 of 1000
#
# Mean Probability:  0.00041021892393222213
# Training Score:  -10.994520738726337 Testing Score: -9.968285318392663
# Loss:  0.9701329205532149
# iteration 258 of 1000
#
# Mean Probability:  0.00040897608870966334
# Training Score:  -10.999480259175519 Testing Score: -9.967715349941818
# Loss:  1.226155202959952
# iteration 259 of 1000
#
# Mean Probability:  0.000407645063734034
# Training Score:  -10.994929302383118 Testing Score: -9.977835480661096
# Loss:  1.113614034543252
# iteration 260 of 1000
#
# Mean Probability:  0.0004087459967929668
# Training Score:  -10.991352736825679 Testing Score: -9.969247160268068
# Loss:  0.9128037896085782
# iteration 261 of 1000
#
# Mean Probability:  0.00040857795291572303
# Training Score:  -10.995329492751399 Testing Score: -9.964935147380752
# Loss:  1.1650373361017525
# iteration 262 of 1000
#
# Mean Probability:  0.00041191676722427664
# Training Score:  -10.986649706130445 Testing Score: -9.962934873939917
# Loss:  1.1966374892518103
# iteration 263 of 1000
#
# Mean Probability:  0.00041233217886421723
# Training Score:  -10.98737835830983 Testing Score: -9.959916177976273
# Loss:  0.8892298319498989
# iteration 264 of 1000
#
# Mean Probability:  0.00041172519934421425
# Training Score:  -10.983341271071657 Testing Score: -9.957278108697821
# Loss:  1.0690576499786348
# iteration 265 of 1000
#
# Mean Probability:  0.00041283938402305296
# Training Score:  -10.977315788949433 Testing Score: -9.943672547460768
# Loss:  1.1649713338947938
# iteration 266 of 1000
#
# Mean Probability:  0.0004135890592388694
# Training Score:  -10.97370642060823 Testing Score: -9.950614050420313
# Loss:  0.9885951615232426
# iteration 267 of 1000
#
# Mean Probability:  0.00041207183688314033
# Training Score:  -10.972583121082593 Testing Score: -9.961413947224607
# Loss:  1.1830781452792993
# iteration 268 of 1000
#
# Mean Probability:  0.0004160769111896804
# Training Score:  -10.958871650775361 Testing Score: -9.958280719538907
# Loss:  1.0138926905846024
# iteration 269 of 1000
#
# Mean Probability:  0.0004144990382467886
# Training Score:  -10.964299161122288 Testing Score: -9.964204872720224
# Loss:  1.0448555057661468
# iteration 270 of 1000
#
# Mean Probability:  0.00041344025869535555
# Training Score:  -10.965132733108998 Testing Score: -9.966922233033797
# Loss:  1.0261384004163667
# iteration 271 of 1000
#
# Mean Probability:  0.00041445563925791927
# Training Score:  -10.960371306630313 Testing Score: -9.950714412314507
# Loss:  1.2461529815626708
# iteration 272 of 1000
#
# Mean Probability:  0.0004138216921752272
# Training Score:  -10.961758697166644 Testing Score: -9.949248163230541
# Loss:  0.8942634586789351
# iteration 273 of 1000
#
# Mean Probability:  0.00041455013490273115
# Training Score:  -10.95811646804208 Testing Score: -9.959936719683501
# Loss:  1.3250785652687525
# iteration 274 of 1000
#
# Mean Probability:  0.0004139097433854579
# Training Score:  -10.95735357325241 Testing Score: -9.959260110677972
# Loss:  1.1315697587426075
# iteration 275 of 1000
#
# Mean Probability:  0.000413411573380262
# Training Score:  -10.961365285071944 Testing Score: -9.962056885694768
# Loss:  0.9838693545100277
# iteration 276 of 1000
#
# Mean Probability:  0.00041244696252684237
# Training Score:  -10.960661750141261 Testing Score: -9.970091193782128
# Loss:  0.9835838153400841
# iteration 277 of 1000
#
# Mean Probability:  0.0004160679048154099
# Training Score:  -10.955513701645689 Testing Score: -9.949682413899776
# Loss:  1.133648009075254
# iteration 278 of 1000
#
# Mean Probability:  0.0004157687628397438
# Training Score:  -10.962111427333268 Testing Score: -9.943684858112828
# Loss:  0.8095983741611824
# iteration 279 of 1000
#
# Mean Probability:  0.00041907170786872807
# Training Score:  -10.955321355987643 Testing Score: -9.945521606708468
# Loss:  1.1432904182578993
# iteration 280 of 1000
#
# Mean Probability:  0.00042029007653265855
# Training Score:  -10.950312751123167 Testing Score: -9.938672083541533
# Loss:  1.2291834302958669
# iteration 281 of 1000
#
# Mean Probability:  0.0004190696270167296
# Training Score:  -10.95665387801326 Testing Score: -9.929567175792071
# Loss:  1.0273887391861547
# iteration 282 of 1000
#
# Mean Probability:  0.0004195526457527607
# Training Score:  -10.955432583329765 Testing Score: -9.928087576018259
# Loss:  1.0600466470310788
# iteration 283 of 1000
#
# Mean Probability:  0.0004198939952479926
# Training Score:  -10.95276914601662 Testing Score: -9.930122573001986
# Loss:  0.8962356298777415
# iteration 284 of 1000
#
# Mean Probability:  0.00041926829812214105
# Training Score:  -10.945641928259475 Testing Score: -9.931966148485351
# Loss:  1.0761367909146062
# iteration 285 of 1000
#
# Mean Probability:  0.0004185563888503132
# Training Score:  -10.94668253029744 Testing Score: -9.927306142370732
# Loss:  1.0170640345571942
# iteration 286 of 1000
#
# Mean Probability:  0.0004200751226607794
# Training Score:  -10.949279000383223 Testing Score: -9.919906192634137
# Loss:  1.0994632310330748
# iteration 287 of 1000
#
# Mean Probability:  0.00041913376775348755
# Training Score:  -10.954777229023797 Testing Score: -9.924714386059843
# Loss:  0.8780907532605029
# iteration 288 of 1000
#
# Mean Probability:  0.00042003638593204136
# Training Score:  -10.954763603318876 Testing Score: -9.925743196895587
# Loss:  1.4727125329541741
# iteration 289 of 1000
#
# Mean Probability:  0.00041928117278269806
# Training Score:  -10.954267727543394 Testing Score: -9.932872422474192
# Loss:  1.0837813324727592
# iteration 290 of 1000
#
# Mean Probability:  0.0004183296240948716
# Training Score:  -10.95667665713592 Testing Score: -9.942817733596646
# Loss:  1.046027289693975
# iteration 291 of 1000
#
# Mean Probability:  0.00041805013952794865
# Training Score:  -10.956136144133747 Testing Score: -9.938810569377695
# Loss:  1.0142832173468017
# iteration 292 of 1000
#
# Mean Probability:  0.00041710346772795526
# Training Score:  -10.94979640858894 Testing Score: -9.938447384228319
# Loss:  1.1657999277345863
# iteration 293 of 1000
#
# Mean Probability:  0.0004164679931584455
# Training Score:  -10.949909413543638 Testing Score: -9.946232284488921
# Loss:  1.0501659491229751
# iteration 294 of 1000
#
# Mean Probability:  0.0004156029804690511
# Training Score:  -10.95059256473285 Testing Score: -9.9534163868072
# Loss:  0.9931017199023396
# iteration 295 of 1000
#
# Mean Probability:  0.00041605179204635766
# Training Score:  -10.95500130543386 Testing Score: -9.943969709117278
# Loss:  0.9702377395147781
# iteration 296 of 1000
#
# Mean Probability:  0.00042023246660768596
# Training Score:  -10.954425058657286 Testing Score: -9.933823194800723
# ...
#
# Mean Probability:  0.0064202632388813356
# Training Score:  -1.6148965611768946 Testing Score: -13.038204901338002
# Loss:  0.6532828783785897
# iteration 902 of 1000
#
# Mean Probability:  0.0066223519751362125
# Training Score:  -1.5838794813557755 Testing Score: -13.04217965099753
# Loss:  0.30624425198201544
# iteration 903 of 1000
#
# Mean Probability:  0.005983566984257771
# Training Score:  -1.6853661775162918 Testing Score: -13.045511605832127
# Loss:  0.18355187408503404
# iteration 904 of 1000
#
# Mean Probability:  0.00623898629808522
# Training Score:  -1.6435345864735584 Testing Score: -13.048605159409073
# Loss:  0.3147044115743429
# iteration 905 of 1000
#
# Mean Probability:  0.006476967219815694
# Training Score:  -1.6060737603077502 Testing Score: -13.051331889359403
# Loss:  0.30994381386414327
# iteration 906 of 1000
#
# Mean Probability:  0.006698365352249532
# Training Score:  -1.572440944324788 Testing Score: -13.053241140560251
# Loss:  0.30578778730936906
# iteration 907 of 1000
#
# Mean Probability:  0.006903422488432409
# Training Score:  -1.5422683784503548 Testing Score: -13.05469136885411
# Loss:  0.30203376728789744
# iteration 908 of 1000
#
# Mean Probability:  0.00709388882835985
# Training Score:  -1.5150363669571452 Testing Score: -13.055193167277885
# Loss:  0.2989144571399207
# iteration 909 of 1000
#
# Mean Probability:  0.006406198238124046
# Training Score:  -1.6170561102611647 Testing Score: -13.056322761649023
# Loss:  0.1815271235493063
# iteration 910 of 1000
#
# Mean Probability:  0.0066497565141159665
# Training Score:  -1.5797206365090113 Testing Score: -13.056475637357817
# Loss:  0.3076989247762546
# iteration 911 of 1000
#
# Mean Probability:  0.006006129299651907
# Training Score:  -1.6815764993816127 Testing Score: -13.057162277194617
# Loss:  0.1819807469962394
# iteration 912 of 1000
#
# Mean Probability:  0.005426976275537413
# Training Score:  -1.7830374397384423 Testing Score: -13.056716621593395
# Loss:  0.18340794552443773
# iteration 913 of 1000
#
# Mean Probability:  0.0057709332961719175
# Training Score:  -1.72154655418182 Testing Score: -13.056652619523506
# Loss:  0.3283804186182989
# iteration 914 of 1000
#
# Mean Probability:  0.005214839768685985
# Training Score:  -1.8229377979713521 Testing Score: -13.055458900213855
# Loss:  0.18367723199259967
# iteration 915 of 1000
#
# Mean Probability:  0.005584386222097716
# Training Score:  -1.754427069482654 Testing Score: -13.054532354193269
# Loss:  0.33397017947104857
# iteration 916 of 1000
#
# Mean Probability:  0.005046580747794999
# Training Score:  -1.8557590116648572 Testing Score: -13.054412135972793
# Loss:  0.18385860131994447
# iteration 917 of 1000
#
# Mean Probability:  0.004562744527744663
# Training Score:  -1.956621074305314 Testing Score: -13.054359858525018
# Loss:  0.1849316556772549
# iteration 918 of 1000
#
# Mean Probability:  0.00500047088225954
# Training Score:  -1.8649464085393075 Testing Score: -13.054097301229328
# Loss:  0.3535562286364229
# iteration 919 of 1000
#
# Mean Probability:  0.005399691247899474
# Training Score:  -1.788085353494629 Testing Score: -13.053802137968544
# Loss:  0.34023269906032544
# iteration 920 of 1000
#
# Mean Probability:  0.004880070749000361
# Training Score:  -1.889339198736808 Testing Score: -13.052629622437793
# Loss:  0.18406220316726796
# iteration 921 of 1000
#
# Mean Probability:  0.00441242162769529
# Training Score:  -1.990154989078202 Testing Score: -13.052061197923967
# Loss:  0.18508278466145717
# iteration 922 of 1000
#
# Mean Probability:  0.003991806984248624
# Training Score:  -2.0904222248076736 Testing Score: -13.051040491637599
# Loss:  0.18700002476887678
# iteration 923 of 1000
#
# Mean Probability:  0.0036133005422004155
# Training Score:  -2.1901418700960207 Testing Score: -13.049746817231613
# Loss:  0.18836789249547942
# iteration 924 of 1000
#
# Mean Probability:  0.0041488816107923335
# Training Score:  -2.0517984114759575 Testing Score: -13.049042272942977
# Loss:  0.3908444191873908
# iteration 925 of 1000
#
# Mean Probability:  0.004639414041397493
# Training Score:  -1.9399598452399307 Testing Score: -13.047845534474892
# Loss:  0.36867796522454377
# iteration 926 of 1000
#
# Mean Probability:  0.00419522725213175
# Training Score:  -2.040685345489947 Testing Score: -13.046758854860318
# Loss:  0.18565589812149252
# iteration 927 of 1000
#
# Mean Probability:  0.004684509656969042
# Training Score:  -1.9302838971994114 Testing Score: -13.045343619040846
# Loss:  0.36707394472275423
# iteration 928 of 1000
#
# Mean Probability:  0.004235485368709774
# Training Score:  -2.03113199349362 Testing Score: -13.043736310323688
# Loss:  0.18522658125542174
# iteration 929 of 1000
#
# Mean Probability:  0.0038314881517168267
# Training Score:  -2.131470580454709 Testing Score: -13.043124102421096
# Loss:  0.18667822093583847
# iteration 930 of 1000
#
# Mean Probability:  0.004356156847739034
# Training Score:  -2.003020778272493 Testing Score: -13.042145442973004
# Loss:  0.3815410060220884
# iteration 931 of 1000
#
# Mean Probability:  0.004835833725086922
# Training Score:  -1.8984761163529007 Testing Score: -13.041446241526193
# Loss:  0.36154289419792696
# iteration 932 of 1000
#
# Mean Probability:  0.00526811031582907
# Training Score:  -1.812797005482327 Testing Score: -13.040832513745647
# Loss:  0.3458309315919713
# iteration 933 of 1000
#
# Mean Probability:  0.005662755754595531
# Training Score:  -1.7405110430343822 Testing Score: -13.039674602960934
# Loss:  0.3340895881092014
# iteration 934 of 1000
#
# Mean Probability:  0.006017863496508878
# Training Score:  -1.6796520685082086 Testing Score: -13.03927799011065
# Loss:  0.3245035057503784
# iteration 935 of 1000
#
# Mean Probability:  0.005434101070698435
# Training Score:  -1.781758514236369 Testing Score: -13.038042676422402
# Loss:  0.18135484179656777
# iteration 936 of 1000
#
# Mean Probability:  0.004909043256134337
# Training Score:  -1.8834485093868902 Testing Score: -13.037443115520041
# Loss:  0.18284041321200284
# iteration 937 of 1000
#
# Mean Probability:  0.005342682863065009
# Training Score:  -1.7987401271451207 Testing Score: -13.036723915310796
# Loss:  0.34405377074637833
# iteration 938 of 1000
#
# Mean Probability:  0.004826626891314108
# Training Score:  -1.9003968159923308 Testing Score: -13.035556221854069
# Loss:  0.18299764434021532
# iteration 939 of 1000
#
# Mean Probability:  0.005270166513245121
# Training Score:  -1.812419390936734 Testing Score: -13.034871645569531
# Loss:  0.3464661390440197
# iteration 940 of 1000
#
# Mean Probability:  0.004761227209556895
# Training Score:  -1.9140540758034357 Testing Score: -13.033713600488314
# Loss:  0.18309926634529228
# iteration 941 of 1000
#
# Mean Probability:  0.005213056833190483
# Training Score:  -1.8233263905029848 Testing Score: -13.033100546342295
# Loss:  0.34850787580846704
# iteration 942 of 1000
#
# Mean Probability:  0.005619374711991973
# Training Score:  -1.7482213984292856 Testing Score: -13.03247766404614
# Loss:  0.3359059945497268
# iteration 943 of 1000
#
# Mean Probability:  0.0059904296335123825
# Training Score:  -1.6842382914643492 Testing Score: -13.031461347324155
# Loss:  0.3258767862723673
# iteration 944 of 1000
#
# Mean Probability:  0.005408699325127559
# Training Score:  -1.786462613309589 Testing Score: -13.030470117773065
# Loss:  0.1813441151516979
# iteration 945 of 1000
#
# Mean Probability:  0.005798531798586881
# Training Score:  -1.716820642993429 Testing Score: -13.02926624724253
# Loss:  0.3305189002891675
# iteration 946 of 1000
#
# Mean Probability:  0.006151656507679228
# Training Score:  -1.6576675829910248 Testing Score: -13.028885370022625
# Loss:  0.32195784553647455
# iteration 947 of 1000
#
# Mean Probability:  0.00647141499126201
# Training Score:  -1.606964359837801 Testing Score: -13.028655561521978
# Loss:  0.31421643224004187
# iteration 948 of 1000
#
# Mean Probability:  0.005841107618861686
# Training Score:  -1.7095037809816986 Testing Score: -13.028185872951424
# Loss:  0.18040771116491694
# iteration 949 of 1000
#
# Mean Probability:  0.005273788860938191
# Training Score:  -1.8117470841954062 Testing Score: -13.027334942945718
# Loss:  0.18087754450091975
# iteration 950 of 1000
#
# Mean Probability:  0.004763357272657563
# Training Score:  -1.9136233628398664 Testing Score: -13.02675198084283
# Loss:  0.1824257680956225
# iteration 951 of 1000
#
# Mean Probability:  0.004304006726822613
# Training Score:  -2.015117830969201 Testing Score: -13.02615900527661
# Loss:  0.18315945103682063
# iteration 952 of 1000
#
# Mean Probability:  0.0038905514600793803
# Training Score:  -2.1162113772602407 Testing Score: -13.02496265728699
# Loss:  0.18477648900389432
# iteration 953 of 1000
#
# Mean Probability:  0.0044345136541394815
# Training Score:  -1.985224421285468 Testing Score: -13.024020646400873
# Loss:  0.379990107469653
# iteration 954 of 1000
#
# Mean Probability:  0.004927037181993876
# Training Score:  -1.8798190806594939 Testing Score: -13.022380914597028
# Loss:  0.3596116219680432
# iteration 955 of 1000
#
# Mean Probability:  0.004450946821724154
# Training Score:  -1.9815256494972684 Testing Score: -13.022051166915853
# Loss:  0.18264245532735524
# iteration 956 of 1000
#
# Mean Probability:  0.004022642457601583
# Training Score:  -2.082798591237033 Testing Score: -13.02157504324648
# Loss:  0.18415307611951803
# iteration 957 of 1000
#
# Mean Probability:  0.00455707459411695
# Training Score:  -1.9579444142307536 Testing Score: -13.021349063729076
# Loss:  0.3746810637271635
# iteration 958 of 1000
#
# Mean Probability:  0.005040337925151659
# Training Score:  -1.857071375634557 Testing Score: -13.020433712356219
# Loss:  0.35563909488057427
# iteration 959 of 1000
#
# Mean Probability:  0.005477519268098817
# Training Score:  -1.7738307816053507 Testing Score: -13.020286078029507
# Loss:  0.3408624036792373
# iteration 960 of 1000
#
# Mean Probability:  0.005869872569368812
# Training Score:  -1.7046033001329135 Testing Score: -13.019626132768703
# Loss:  0.3293125662197197
# iteration 961 of 1000
#
# Mean Probability:  0.006227763370999303
# Training Score:  -1.6453809021871413 Testing Score: -13.019659895471726
# Loss:  0.3207002688909785
# iteration 962 of 1000
#
# Mean Probability:  0.0065515422405896485
# Training Score:  -1.5946672903570485 Testing Score: -13.0182388138624
# Loss:  0.3136335141374483
# iteration 963 of 1000
#
# Mean Probability:  0.0068439029228945835
# Training Score:  -1.5509843025428796 Testing Score: -13.017971870722086
# Loss:  0.30731553537548884
# iteration 964 of 1000
#
# Mean Probability:  0.007108718626461997
# Training Score:  -1.5129997793030772 Testing Score: -13.01669857506492
# Loss:  0.30269584775012737
# iteration 965 of 1000
#
# Mean Probability:  0.006413378462002683
# Training Score:  -1.6159963148477923 Testing Score: -13.015545774804457
# Loss:  0.17865092384053055
# iteration 966 of 1000
#
# Mean Probability:  0.00578770960300328
# Training Score:  -1.7187130750518214 Testing Score: -13.01553509246683
# Loss:  0.17986464613312145
# iteration 967 of 1000
#
# Mean Probability:  0.005224608623359502
# Training Score:  -1.8211444225845073 Testing Score: -13.0151434768658
# Loss:  0.18035889427074583
# iteration 968 of 1000
#
# Mean Probability:  0.005650185894121034
# Training Score:  -1.742780047698368 Testing Score: -13.01485321690457
# Loss:  0.3364490761956055
# iteration 969 of 1000
#
# Mean Probability:  0.006034989695952893
# Training Score:  -1.6768504591513276 Testing Score: -13.014948178142928
# Loss:  0.32575082729545646
# iteration 970 of 1000
#
# Mean Probability:  0.005446832795992305
# Training Score:  -1.7794620156009306 Testing Score: -13.01418639178785
# Loss:  0.18016252381484038
# iteration 971 of 1000
#
# Mean Probability:  0.005849400839860246
# Training Score:  -1.70810806947155 Testing Score: -13.013721196254178
# Loss:  0.3302023160283767
# iteration 972 of 1000
#
# Mean Probability:  0.005279746586614457
# Training Score:  -1.8106430338294128 Testing Score: -13.013922920514027
# Loss:  0.18039485336700217
# iteration 973 of 1000
#
# Mean Probability:  0.005700062217559672
# Training Score:  -1.733989725170134 Testing Score: -13.013374410026193
# Loss:  0.3344042232366856
# iteration 974 of 1000
#
# Mean Probability:  0.00608329305275857
# Training Score:  -1.6688770807667432 Testing Score: -13.013029894487271
# Loss:  0.32506480133515503
# iteration 975 of 1000
#
# Mean Probability:  0.005490055427243288
# Training Score:  -1.7715564526874485 Testing Score: -13.012934210674812
# Loss:  0.1796574616293382
# iteration 976 of 1000
#
# Mean Probability:  0.0049562390246164975
# Training Score:  -1.8739264481312579 Testing Score: -13.012865420311519
# Loss:  0.18091591041061228
# iteration 977 of 1000
#
# Mean Probability:  0.004475878234381438
# Training Score:  -1.9759590975190506 Testing Score: -13.012657849528074
# Loss:  0.18161752297717948
# iteration 978 of 1000
#
# Mean Probability:  0.004980830307150803
# Training Score:  -1.8689754932852274 Testing Score: -13.011916118698936
# Loss:  0.35899416528485295
# iteration 979 of 1000
#
# Mean Probability:  0.004497843870635048
# Training Score:  -1.9710617590485275 Testing Score: -13.010565600319921
# Loss:  0.18145927034340775
# iteration 980 of 1000
#
# Mean Probability:  0.005001800266196364
# Training Score:  -1.8647729558248867 Testing Score: -13.009837178606851
# Loss:  0.35837508649574606
# iteration 981 of 1000
#
# Mean Probability:  0.004516607956611887
# Training Score:  -1.9668972141592038 Testing Score: -13.008620405138675
# Loss:  0.18123177913862826
# iteration 982 of 1000
#
# Mean Probability:  0.004080034076222723
# Training Score:  -2.0686492303657626 Testing Score: -13.008859592147926
# Loss:  0.1829283655524903
# iteration 983 of 1000
#
# Mean Probability:  0.004625470240209789
# Training Score:  -1.943061662878888 Testing Score: -13.008605758937557
# Loss:  0.3730730246986264
# iteration 984 of 1000
#
# Mean Probability:  0.004177936068652378
# Training Score:  -2.0449168247979794 Testing Score: -13.007507660349875
# Loss:  0.18268987510906992
# iteration 985 of 1000
#
# Mean Probability:  0.004714819565170486
# Training Score:  -1.923914890641338 Testing Score: -13.006280318444038
# Loss:  0.3693077795853158
# iteration 986 of 1000
#
# Mean Probability:  0.004258181114031064
# Training Score:  -2.02587590544062 Testing Score: -13.006666734064853
# Loss:  0.1824398006142866
# iteration 987 of 1000
#
# Mean Probability:  0.003847365460628868
# Training Score:  -2.127432003505641 Testing Score: -13.00688079690331
# Loss:  0.1828271014715463
# iteration 988 of 1000
#
# Mean Probability:  0.003477679471507174
# Training Score:  -2.228568579201893 Testing Score: -13.007064588711295
# Loss:  0.18495646811172478
# iteration 989 of 1000
#
# Mean Probability:  0.0031450443438586985
# Training Score:  -2.3292314105297924 Testing Score: -13.006582993554323
# Loss:  0.18558226694502378
# iteration 990 of 1000
#
# Mean Probability:  0.0028458553745180333
# Training Score:  -2.429333762720124 Testing Score: -13.006539736639713
# Loss:  0.18814388829992174
# iteration 991 of 1000
#
# Mean Probability:  0.0035149724266825685
# Training Score:  -2.2178960879639664 Testing Score: -13.006314498805873
# Loss:  0.43714579064756764
# iteration 992 of 1000
#
# Mean Probability:  0.0031786406421618184
# Training Score:  -2.3185979158184873 Testing Score: -13.006281831148986
# Loss:  0.1863779092295591
# iteration 993 of 1000
#
# Mean Probability:  0.0038167511703420687
# Training Score:  -2.1354390415234987 Testing Score: -13.00560566664853
# Loss:  0.4163370447585169
# iteration 994 of 1000
#
# Mean Probability:  0.0034499596339360003
# Training Score:  -2.2365905577686105 Testing Score: -13.005776097227232
# Loss:  0.1849173996003871
# iteration 995 of 1000
#
# Mean Probability:  0.0031200430768043882
# Training Score:  -2.3372335070255392 Testing Score: -13.00517424752349
# Loss:  0.1856690287943265
# iteration 996 of 1000
#
# Mean Probability:  0.0037614134526936416
# Training Score:  -2.150063383578717 Testing Score: -13.004680468365386
# Loss:  0.42000918559634715
# iteration 997 of 1000
#
# Mean Probability:  0.0043422392874854976
# Training Score:  -2.0063226923331268 Testing Score: -13.004932324072085
# Loss:  0.3864657217456112
# iteration 998 of 1000
#
# Mean Probability:  0.0039227479415037386
# Training Score:  -2.1080221444554774 Testing Score: -13.004926773378534
# Loss:  0.1830062998765189
# iteration 999 of 1000
#
# Mean Probability:  0.004488860008080058
# Training Score:  -1.9730846864990346 Testing Score: -13.004189781244241
# Loss:  0.3797218897233168
#
# Time required for training on clustering with K = 2: 0h 1min 49sec

# %% [markdown]
# ## K = 3

# %%
# train on the clustering with K = 3 and extract the probabilities assigned by the model
start_time = time.time()
clusters_K_3_prob, test_K_3_prob = train_on_clustering(clustering_K_3, test_set, results_trainings_k_3_folder, n_iter=1000)
end_time = time.time()

elapsed_time = end_time - start_time
elapsed_hours = int(elapsed_time // (60 * 60))
elapsed_minutes = int((elapsed_time % (60 * 60)) // 60)
elapsed_seconds = int((elapsed_time % (60 * 60)) % 60)
string_time = str(elapsed_hours) + "h " + str(elapsed_minutes) + "min " + str(elapsed_seconds) + "sec"

print()
print("Time required for training on clustering with K = 2: " +  string_time)
# Out:
# Folder path already exists.
# Folder path created successfully.
# Folder path created successfully.
# Folder path created successfully.
# iteration 0 of 1000
#
# Mean Probability:  2.32812437503873e-05
# Training Score:  -12.368721523398838 Testing Score: -12.085750221982865
# Loss:  10.09184615222265
# iteration 1 of 1000
#
# Mean Probability:  4.640076843484822e-05
# Training Score:  -11.999715866048817 Testing Score: -11.743957863185381
# Loss:  6.618241554919215
# iteration 2 of 1000
#
# Mean Probability:  6.825136040098363e-05
# Training Score:  -11.759195722742184 Testing Score: -11.51606913419218
# Loss:  4.916902152333651
# iteration 3 of 1000
#
# Mean Probability:  8.939618027235794e-05
# Training Score:  -11.584448425203716 Testing Score: -11.345962319769942
# Loss:  3.546508655469763
# iteration 4 of 1000
#
# Mean Probability:  0.00010802572902744499
# Training Score:  -11.461829741632492 Testing Score: -11.23069954812091
# Loss:  3.118568850510953
# iteration 5 of 1000
#
# Mean Probability:  0.0001256352237251543
# Training Score:  -11.350052081981568 Testing Score: -11.142625180130489
# Loss:  2.553655181014367
# iteration 6 of 1000
#
# Mean Probability:  0.00014197234005272253
# Training Score:  -11.267952265064977 Testing Score: -11.048381188816093
# Loss:  2.681409412796192
# iteration 7 of 1000
#
# Mean Probability:  0.00015693558936927338
# Training Score:  -11.199516569729026 Testing Score: -10.983740130872858
# Loss:  2.045334382840683
# iteration 8 of 1000
#
# Mean Probability:  0.00016949805017672277
# Training Score:  -11.132404952174268 Testing Score: -10.937147783031822
# Loss:  2.225262136217976
# iteration 9 of 1000
#
# Mean Probability:  0.00018283491788480686
# Training Score:  -11.075827790113767 Testing Score: -10.873641206204832
# Loss:  1.9768859432388048
# iteration 10 of 1000
#
# Mean Probability:  0.0001939093535079385
# Training Score:  -11.02860831620788 Testing Score: -10.826100866592867
# Loss:  2.0108707856312655
# iteration 11 of 1000
#
# Mean Probability:  0.00020375121050680777
# Training Score:  -10.989364131872843 Testing Score: -10.799295477002026
# Loss:  1.8684092565317376
# iteration 12 of 1000
#
# Mean Probability:  0.00021264300111894924
# Training Score:  -10.951264505500532 Testing Score: -10.77153565319511
# Loss:  1.671795896310532
# iteration 13 of 1000
#
# Mean Probability:  0.0002215558509133743
# Training Score:  -10.919922499510823 Testing Score: -10.732873006999455
# Loss:  1.6158537405226538
# iteration 14 of 1000
#
# Mean Probability:  0.00023000234266601816
# Training Score:  -10.886872909346005 Testing Score: -10.71281535674073
# Loss:  1.518783639412381
# iteration 15 of 1000
#
# Mean Probability:  0.00023647947931592535
# Training Score:  -10.8545460805865 Testing Score: -10.69708188409005
# Loss:  1.6064364993689986
# iteration 16 of 1000
#
# Mean Probability:  0.0002445449072214371
# Training Score:  -10.830874665244009 Testing Score: -10.653161106122441
# Loss:  1.4813573265120086
# iteration 17 of 1000
#
# Mean Probability:  0.0002499341925433501
# Training Score:  -10.80591066737491 Testing Score: -10.633968678616966
# Loss:  1.6138104749735556
# iteration 18 of 1000
#
# Mean Probability:  0.00025522861792677434
# Training Score:  -10.79025192690078 Testing Score: -10.607987587824969
# Loss:  1.496167691959248
# iteration 19 of 1000
#
# Mean Probability:  0.0002617341577703283
# Training Score:  -10.766836449190963 Testing Score: -10.598030761219741
# Loss:  1.3362563351942038
# iteration 20 of 1000
#
# Mean Probability:  0.0002703373627050733
# Training Score:  -10.743196687845787 Testing Score: -10.580724785107295
# Loss:  1.2582190189634734
# iteration 21 of 1000
#
# Mean Probability:  0.000274502482534264
# Training Score:  -10.728309542057481 Testing Score: -10.57654870024225
# Loss:  1.196098954111206
# iteration 22 of 1000
#
# Mean Probability:  0.00027727890974496523
# Training Score:  -10.718432263718014 Testing Score: -10.573000222885168
# Loss:  1.7024911686729478
# iteration 23 of 1000
#
# Mean Probability:  0.00028132868608660654
# Training Score:  -10.700282314494238 Testing Score: -10.564161803633974
# Loss:  1.3619030023445369
# iteration 24 of 1000
#
# Mean Probability:  0.00028870545275455005
# Training Score:  -10.686640536517736 Testing Score: -10.544358206041785
# Loss:  1.2862293331390668
# iteration 25 of 1000
#
# Mean Probability:  0.000290418411142133
# Training Score:  -10.678372198079481 Testing Score: -10.535925862305989
# Loss:  1.1076026842791393
# iteration 26 of 1000
#
# Mean Probability:  0.0002913374024893132
# Training Score:  -10.66503277820992 Testing Score: -10.53525578486518
# Loss:  1.4088907577951686
# iteration 27 of 1000
#
# Mean Probability:  0.00029509440815020626
# Training Score:  -10.65605311563716 Testing Score: -10.520066611567016
# Loss:  1.3205959573801107
# iteration 28 of 1000
#
# Mean Probability:  0.00030056617000999626
# Training Score:  -10.638466045987878 Testing Score: -10.520496085699072
# Loss:  1.1850385454406647
# iteration 29 of 1000
#
# Mean Probability:  0.0003031221276161463
# Training Score:  -10.63851002325406 Testing Score: -10.499026962795178
# Loss:  1.3847013598398674
# iteration 30 of 1000
#
# Mean Probability:  0.00030698779593335
# Training Score:  -10.626584605722245 Testing Score: -10.488121377555764
# Loss:  1.2617340765062348
# iteration 31 of 1000
#
# Mean Probability:  0.00031051439063398687
# Training Score:  -10.616455488720547 Testing Score: -10.479329500067788
# Loss:  1.2454762058380653
# iteration 32 of 1000
#
# Mean Probability:  0.00031233374693626206
# Training Score:  -10.614631271250504 Testing Score: -10.478910500385275
# Loss:  1.7119934825275127
# iteration 33 of 1000
#
# Mean Probability:  0.00031409425828552606
# Training Score:  -10.607230699695927 Testing Score: -10.477972059680008
# Loss:  1.058749823247171
# iteration 34 of 1000
#
# Mean Probability:  0.0003132853516503956
# Training Score:  -10.60817433942666 Testing Score: -10.48105628847401
# Loss:  1.177229753397456
# iteration 35 of 1000
#
# Mean Probability:  0.0003151198061123637
# Training Score:  -10.604651242114494 Testing Score: -10.483042544285825
# Loss:  1.1255729051626764
# iteration 36 of 1000
#
# Mean Probability:  0.00031935085350473855
# Training Score:  -10.59656560448208 Testing Score: -10.481100931070047
# Loss:  1.2957589448089648
# iteration 37 of 1000
#
# Mean Probability:  0.000321749178756868
# Training Score:  -10.590785011934157 Testing Score: -10.482371817681141
# Loss:  1.0851543363160014
# iteration 38 of 1000
#
# Mean Probability:  0.00032299063840504036
# Training Score:  -10.584932387207903 Testing Score: -10.472987665509978
# Loss:  1.1798633901107771
# iteration 39 of 1000
#
# Mean Probability:  0.00032335577666285366
# Training Score:  -10.580326025471711 Testing Score: -10.470225474458289
# Loss:  1.1466537947274011
# iteration 40 of 1000
#
# Mean Probability:  0.0003291940021106846
# Training Score:  -10.571168008835173 Testing Score: -10.469423838652142
# Loss:  1.3097201863875483
# iteration 41 of 1000
#
# Mean Probability:  0.0003334404068961419
# Training Score:  -10.565599123888408 Testing Score: -10.459213716215631
# Loss:  0.9978637069892298
# iteration 42 of 1000
#
# Mean Probability:  0.0003329610806506545
# Training Score:  -10.56604019644769 Testing Score: -10.450799017183176
# Loss:  1.0956875557160957
# iteration 43 of 1000
#
# Mean Probability:  0.0003325067409945523
# Training Score:  -10.566324954484992 Testing Score: -10.454117073476162
# Loss:  1.1524549518212677
# iteration 44 of 1000
#
# Mean Probability:  0.00033385225505850653
# Training Score:  -10.562620725665939 Testing Score: -10.44577040910617
# Loss:  1.1564996447704083
# iteration 45 of 1000
#
# Mean Probability:  0.00033440816699775727
# Training Score:  -10.55316895899719 Testing Score: -10.428478542729259
# Loss:  1.2627951428468103
# iteration 46 of 1000
#
# Mean Probability:  0.00033527576040522176
# Training Score:  -10.545874059501877 Testing Score: -10.427493277474536
# Loss:  1.2899040937628496
# iteration 47 of 1000
#
# Mean Probability:  0.00033531484624093266
# Training Score:  -10.540396043776436 Testing Score: -10.42521268668397
# Loss:  1.3030546466275927
# iteration 48 of 1000
#
# Mean Probability:  0.00033377604806175925
# Training Score:  -10.54192961985951 Testing Score: -10.419969055804026
# Loss:  1.061071885295648
# iteration 49 of 1000
#
# Mean Probability:  0.0003349010352765368
# Training Score:  -10.542551504473332 Testing Score: -10.41843294677488
# Loss:  1.0784645878695551
# iteration 50 of 1000
#
# Mean Probability:  0.00034036009930528275
# Training Score:  -10.533283543267771 Testing Score: -10.419067178705541
# Loss:  1.0471562905081517
# iteration 51 of 1000
#
# Mean Probability:  0.00034227395167931633
# Training Score:  -10.526632980376787 Testing Score: -10.41967323529571
# Loss:  1.2197127326600392
# iteration 52 of 1000
#
# Mean Probability:  0.0003469116099045164
# Training Score:  -10.515964691865845 Testing Score: -10.415009654271442
# Loss:  1.1969959502378937
# iteration 53 of 1000
#
# Mean Probability:  0.00034455159824731054
# Training Score:  -10.520424075540422 Testing Score: -10.412474158130214
# Loss:  1.0109035091836969
# iteration 54 of 1000
#
# Mean Probability:  0.00034509616651680857
# Training Score:  -10.50709602589864 Testing Score: -10.41659950179704
# Loss:  1.213251890945679
# iteration 55 of 1000
#
# Mean Probability:  0.00034455982192911015
# Training Score:  -10.499635295477036 Testing Score: -10.412326963626455
# Loss:  1.0830685073733926
# iteration 56 of 1000
#
# Mean Probability:  0.0003432909193334129
# Training Score:  -10.491229336879911 Testing Score: -10.415665730082731
# Loss:  1.1445946552934008
# iteration 57 of 1000
#
# Mean Probability:  0.00034271455227753646
# Training Score:  -10.493620625117039 Testing Score: -10.413817400664211
# Loss:  1.0419054536150196
# iteration 58 of 1000
#
# Mean Probability:  0.0003456845582703019
# Training Score:  -10.491374152253725 Testing Score: -10.405182879243771
# Loss:  1.0334540921992774
# iteration 59 of 1000
#
# Mean Probability:  0.0003492500653915343
# Training Score:  -10.488800845608555 Testing Score: -10.373329669902528
# Loss:  1.3591086065487241
# iteration 60 of 1000
#
# Mean Probability:  0.00034877183775284864
# Training Score:  -10.489950114720854 Testing Score: -10.35799658542556
# Loss:  0.9154328659367176
# iteration 61 of 1000
#
# Mean Probability:  0.0003512260370414832
# Training Score:  -10.48498908767776 Testing Score: -10.34970721840215
# Loss:  1.128376358390168
# iteration 62 of 1000
#
# Mean Probability:  0.0003568478410711416
# Training Score:  -10.474339879039775 Testing Score: -10.348951991114967
# Loss:  1.3016901598632769
# iteration 63 of 1000
#
# Mean Probability:  0.0003598572580651554
# Training Score:  -10.462627358860264 Testing Score: -10.354282182310538
# Loss:  1.3826978426349863
# iteration 64 of 1000
#
# Mean Probability:  0.0003586286265295046
# Training Score:  -10.461354977711334 Testing Score: -10.349320484351598
# Loss:  1.0566726222044722
# iteration 65 of 1000
#
# Mean Probability:  0.00035866244169246655
# Training Score:  -10.465159357038479 Testing Score: -10.350971211056375
# Loss:  1.0378229564984596
# iteration 66 of 1000
#
# Mean Probability:  0.0003639952190775962
# Training Score:  -10.46140888716748 Testing Score: -10.348011197167859
# Loss:  1.0916329241998368
# iteration 67 of 1000
#
# Mean Probability:  0.00036383584942928154
# Training Score:  -10.460017033708038 Testing Score: -10.341138571068774
# Loss:  1.074655628099546
# iteration 68 of 1000
#
# Mean Probability:  0.00036357233998098547
# Training Score:  -10.45710641442087 Testing Score: -10.345741798733961
# Loss:  0.9796884914432661
# iteration 69 of 1000
#
# Mean Probability:  0.00036461243966000507
# Training Score:  -10.451097014457739 Testing Score: -10.336831896209656
# Loss:  1.0010688922343476
# iteration 70 of 1000
#
# Mean Probability:  0.0003638473632474217
# Training Score:  -10.454165341261689 Testing Score: -10.320943229615953
# Loss:  1.0278062329282398
# iteration 71 of 1000
#
# Mean Probability:  0.000363295048791097
# Training Score:  -10.453970871063305 Testing Score: -10.32404669205557
# Loss:  0.9815506728226222
# iteration 72 of 1000
#
# Mean Probability:  0.000364796132780873
# Training Score:  -10.44497550052736 Testing Score: -10.32523012111658
# Loss:  1.0392297473811445
# iteration 73 of 1000
#
# Mean Probability:  0.00036213515833414807
# Training Score:  -10.447912521806364 Testing Score: -10.329873037634544
# Loss:  0.9803542513192866
# iteration 74 of 1000
#
# Mean Probability:  0.00036637105448043876
# Training Score:  -10.444059752875297 Testing Score: -10.32270480046223
# Loss:  1.1927824929032602
# iteration 75 of 1000
#
# Mean Probability:  0.0003655176504492658
# Training Score:  -10.442922572803635 Testing Score: -10.327312583104765
# Loss:  1.097332404354844
# iteration 76 of 1000
#
# Mean Probability:  0.0003648984975710023
# Training Score:  -10.437535015166619 Testing Score: -10.330784197942252
# Loss:  0.9919245883329323
# iteration 77 of 1000
#
# Mean Probability:  0.000363755143628417
# Training Score:  -10.433557248957586 Testing Score: -10.331927483813693
# Loss:  0.9467480744377474
# iteration 78 of 1000
#
# Mean Probability:  0.0003628510393075119
# Training Score:  -10.425747576555986 Testing Score: -10.333043124660815
# Loss:  1.5388913933091557
# iteration 79 of 1000
#
# Mean Probability:  0.00036243584667054323
# Training Score:  -10.426510500325271 Testing Score: -10.330282046775617
# Loss:  0.8521213351149782
# iteration 80 of 1000
#
# Mean Probability:  0.00036215911550096017
# Training Score:  -10.422857978703501 Testing Score: -10.334634415037971
# Loss:  0.959885533715625
# iteration 81 of 1000
#
# Mean Probability:  0.0003624186879291625
# Training Score:  -10.423167074430715 Testing Score: -10.336964739460186
# Loss:  1.0093585316832825
# iteration 82 of 1000
#
# Mean Probability:  0.00036511195563686445
# Training Score:  -10.421638501818125 Testing Score: -10.332123035835417
# Loss:  1.041695981527591
# iteration 83 of 1000
#
# Mean Probability:  0.0003660455570885562
# Training Score:  -10.416085941163189 Testing Score: -10.32968574171833
# Loss:  1.1199591129851139
# iteration 84 of 1000
#
# Mean Probability:  0.00036612419159491697
# Training Score:  -10.420254515172271 Testing Score: -10.333582460109362
# Loss:  1.0151295907613114
# iteration 85 of 1000
#
# Mean Probability:  0.00036414065226012926
# Training Score:  -10.426526430176866 Testing Score: -10.337841287422563
# Loss:  0.9565853242059196
# iteration 86 of 1000
#
# Mean Probability:  0.0003662530465637276
# Training Score:  -10.41920808950921 Testing Score: -10.337676952485456
# Loss:  1.256773511315528
# iteration 87 of 1000
#
# Mean Probability:  0.00036983920265603877
# Training Score:  -10.414292805252007 Testing Score: -10.332414142192256
# Loss:  1.0752335763371397
# iteration 88 of 1000
#
# Mean Probability:  0.0003712870811179773
# Training Score:  -10.41207545163172 Testing Score: -10.32402166644383
# Loss:  0.9242158121424804
# iteration 89 of 1000
#
# Mean Probability:  0.00037320257520042483
# Training Score:  -10.410183163447567 Testing Score: -10.316935257066264
# Loss:  1.1150168874791229
# iteration 90 of 1000
#
# Mean Probability:  0.00037363007809064686
# Training Score:  -10.408694459225659 Testing Score: -10.32225087892772
# Loss:  1.183708565429022
# iteration 91 of 1000
#
# Mean Probability:  0.00037411774438055414
# Training Score:  -10.409300006597801 Testing Score: -10.32735905282843
# Loss:  0.872280023231369
# iteration 92 of 1000
#
# Mean Probability:  0.00037321468130376825
# Training Score:  -10.413361119986035 Testing Score: -10.324589482844162
# Loss:  1.0298315592570473
# iteration 93 of 1000
#
# Mean Probability:  0.00037994463937082414
# Training Score:  -10.397360319212138 Testing Score: -10.326410224194847
# Loss:  1.2254952773176357
# iteration 94 of 1000
#
# Mean Probability:  0.0003781763337242885
# Training Score:  -10.39939959138479 Testing Score: -10.328977442458529
# Loss:  0.934584709610328
# iteration 95 of 1000
#
# Mean Probability:  0.0003768966020004198
# Training Score:  -10.393417088637193 Testing Score: -10.329467757395925
# Loss:  1.0381783398326914
# iteration 96 of 1000
#
# Mean Probability:  0.0003781393341777522
# Training Score:  -10.392324436314532 Testing Score: -10.332428484612302
# Loss:  1.2021876014373747
# iteration 97 of 1000
#
# Mean Probability:  0.00037664198069832776
# Training Score:  -10.396213186313702 Testing Score: -10.33284993638414
# Loss:  0.9768740952075428
# iteration 98 of 1000
#
# Mean Probability:  0.00037821073505015223
# Training Score:  -10.386505578606876 Testing Score: -10.302369476959633
# Loss:  1.1267849849286558
# iteration 99 of 1000
#
# Mean Probability:  0.0003772462260347017
# Training Score:  -10.385136837086263 Testing Score: -10.309218602867269
# Loss:  0.9145647798258877
# iteration 100 of 1000
#
# Mean Probability:  0.0003767511218939775
# Training Score:  -10.383583802248214 Testing Score: -10.28150511644767
# Loss:  1.3166005148625493
# iteration 101 of 1000
#
# Mean Probability:  0.0003788924878753267
# Training Score:  -10.383989089738972 Testing Score: -10.266897418104158
# Loss:  1.0942128497750585
# iteration 102 of 1000
#
# Mean Probability:  0.00037686664439709326
# Training Score:  -10.38330288471989 Testing Score: -10.273395375896662
# Loss:  1.0939129504714677
# iteration 103 of 1000
#
# Mean Probability:  0.0003764395569771064
# Training Score:  -10.385435909707784 Testing Score: -10.27754119625592
# Loss:  0.9062947712454237
# iteration 104 of 1000
#
# Mean Probability:  0.00037598064390532797
# Training Score:  -10.387170004410827 Testing Score: -10.283066983627243
# Loss:  0.874013971855507
# iteration 105 of 1000
#
# Mean Probability:  0.00037971897224365063
# Training Score:  -10.378541381700323 Testing Score: -10.288157059072228
# Loss:  0.9930150860785911
# iteration 106 of 1000
#
# Mean Probability:  0.0003833719735701842
# Training Score:  -10.370779132968677 Testing Score: -10.275977506026242
# Loss:  0.9869900250316406
# iteration 107 of 1000
#
# Mean Probability:  0.0003824079085984815
# Training Score:  -10.372180780143395 Testing Score: -10.281038249348812
# Loss:  1.096876313095914
# iteration 108 of 1000
#
# Mean Probability:  0.0003880271263770724
# Training Score:  -10.361651614298088 Testing Score: -10.265196848722942
# Loss:  1.0912526164205758
# iteration 109 of 1000
#
# Mean Probability:  0.00038782459187798504
# Training Score:  -10.362422183741103 Testing Score: -10.266722331542715
# Loss:  1.1594102141821498
# iteration 110 of 1000
#
# Mean Probability:  0.00038691243832229876
# Training Score:  -10.3616723766446 Testing Score: -10.26290399763327
# Loss:  1.175501952421925
# iteration 111 of 1000
#
# Mean Probability:  0.0003858451207427231
# Training Score:  -10.357491193520127 Testing Score: -10.270552595606269
# Loss:  1.1191438908567624
# iteration 112 of 1000
#
# Mean Probability:  0.0003911766827318213
# Training Score:  -10.357155378586972 Testing Score: -10.263135177330701
# Loss:  0.8995385049967822
# iteration 113 of 1000
#
# Mean Probability:  0.00039255160724061976
# Training Score:  -10.35335108264022 Testing Score: -10.264724109649189
# Loss:  0.9470475771091489
# iteration 114 of 1000
#
# Mean Probability:  0.0003923705615914363
# Training Score:  -10.352740492566149 Testing Score: -10.252702381424697
# Loss:  0.9364042535660259
# iteration 115 of 1000
#
# Mean Probability:  0.00038934833487951005
# Training Score:  -10.357535275608509 Testing Score: -10.253689254279788
# Loss:  1.0460958663688573
# iteration 116 of 1000
#
# Mean Probability:  0.0003896966128125248
# Training Score:  -10.356606777526933 Testing Score: -10.261128498019225
# Loss:  0.9521300678338955
# iteration 117 of 1000
#
# Mean Probability:  0.0003925607314159706
# Training Score:  -10.355065974634737 Testing Score: -10.262050479395013
# Loss:  1.0388742417644612
# iteration 118 of 1000
#
# Mean Probability:  0.0003910490026111299
# Training Score:  -10.359211970826983 Testing Score: -10.265339541092494
# Loss:  0.873447517414613
# iteration 119 of 1000
#
# Mean Probability:  0.0003963144847854756
# Training Score:  -10.352512614915291 Testing Score: -10.256445685588917
# Loss:  0.9759724952748537
# iteration 120 of 1000
#
# Mean Probability:  0.0003943443603985566
# Training Score:  -10.352315306659115 Testing Score: -10.253620390036165
# Loss:  1.0707845181316324
# iteration 121 of 1000
#
# Mean Probability:  0.00039179827307483163
# Training Score:  -10.350557998064891 Testing Score: -10.259605544141948
# Loss:  1.157339907692657
# iteration 122 of 1000
#
# Mean Probability:  0.00039310295156318436
# Training Score:  -10.347858860279606 Testing Score: -10.243518295451858
# Loss:  0.9992762394315209
# iteration 123 of 1000
#
# Mean Probability:  0.00039513632384765814
# Training Score:  -10.34863910400356 Testing Score: -10.237788903063207
# Loss:  1.026982027617033
# iteration 124 of 1000
#
# Mean Probability:  0.00039686880949085443
# Training Score:  -10.353181655453744 Testing Score: -10.230670926800974
# Loss:  0.9198051004272695
# iteration 125 of 1000
#
# Mean Probability:  0.00039976325294869793
# Training Score:  -10.346730813093265 Testing Score: -10.237003574372887
# Loss:  1.0895939865001132
# iteration 126 of 1000
#
# Mean Probability:  0.0004034577786870405
# Training Score:  -10.323619783903943 Testing Score: -10.244131799500137
# Loss:  1.1762942555108185
# iteration 127 of 1000
#
# Mean Probability:  0.0004008688803117985
# Training Score:  -10.323801540283185 Testing Score: -10.248528340441338
# Loss:  1.0281812410487727
# iteration 128 of 1000
#
# Mean Probability:  0.00040372593076556755
# Training Score:  -10.316293652852265 Testing Score: -10.238676315207776
# Loss:  1.0520267430532693
# iteration 129 of 1000
#
# Mean Probability:  0.00040365730823834796
# Training Score:  -10.319785177567457 Testing Score: -10.242378590854505
# Loss:  0.8652775593554792
# iteration 130 of 1000
#
# Mean Probability:  0.0004015424933262776
# Training Score:  -10.31674116849225 Testing Score: -10.234469516245783
# Loss:  0.9215359548088663
# iteration 131 of 1000
#
# Mean Probability:  0.0004003603094163598
# Training Score:  -10.318184238056814 Testing Score: -10.232627738532333
# Loss:  0.9164305917917305
# iteration 132 of 1000
#
# Mean Probability:  0.00040032481213760947
# Training Score:  -10.31787172633736 Testing Score: -10.226139455100483
# Loss:  0.9139924950814409
# iteration 133 of 1000
#
# Mean Probability:  0.000398859507718478
# Training Score:  -10.318029032885129 Testing Score: -10.222824252547248
# Loss:  1.0621644794263303
# iteration 134 of 1000
#
# Mean Probability:  0.00039912354249364173
# Training Score:  -10.317913891623995 Testing Score: -10.229240816427891
# Loss:  1.1112335685218961
# iteration 135 of 1000
#
# Mean Probability:  0.00039841309875960056
# Training Score:  -10.315351236829235 Testing Score: -10.235510300160291
# Loss:  1.1381143965679974
# iteration 136 of 1000
#
# Mean Probability:  0.0003978942981040905
# Training Score:  -10.310747502557003 Testing Score: -10.241571908162335
# Loss:  1.179479351673697
# iteration 137 of 1000
#
# Mean Probability:  0.00039742663843827034
# Training Score:  -10.31608799759855 Testing Score: -10.235235002992205
# Loss:  0.9507040334608147
# iteration 138 of 1000
#
# Mean Probability:  0.00039838542455239006
# Training Score:  -10.309577216306787 Testing Score: -10.225895205958643
# Loss:  1.0226442484982714
# iteration 139 of 1000
#
# Mean Probability:  0.00039928857686740235
# Training Score:  -10.29992403545794 Testing Score: -10.223061450797285
# Loss:  1.1711866299465248
# iteration 140 of 1000
#
# Mean Probability:  0.00040309894914198924
# Training Score:  -10.291357837143146 Testing Score: -10.22005476621784
# Loss:  1.118905628816774
# iteration 141 of 1000
#
# Mean Probability:  0.0004021884631435322
# Training Score:  -10.291125491508586 Testing Score: -10.220182834239289
# Loss:  0.9404205300956819
# iteration 142 of 1000
#
# Mean Probability:  0.00040104816495899545
# Training Score:  -10.28677935165122 Testing Score: -10.223485507569375
# Loss:  0.9364664896891939
# iteration 143 of 1000
#
# Mean Probability:  0.00040341452715352515
# Training Score:  -10.28828656541485 Testing Score: -10.21526454832531
# Loss:  0.9073170936936742
# iteration 144 of 1000
#
# Mean Probability:  0.0004022666289451574
# Training Score:  -10.291230355974482 Testing Score: -10.221258501194491
# Loss:  0.8983250346876611
# iteration 145 of 1000
#
# Mean Probability:  0.00040558892794111996
# Training Score:  -10.292091879159909 Testing Score: -10.21478232464819
# Loss:  1.118325798452799
# iteration 146 of 1000
#
# Mean Probability:  0.00040483383552729037
# Training Score:  -10.29076574532705 Testing Score: -10.220127201338345
# Loss:  0.9423449736817653
# iteration 147 of 1000
#
# Mean Probability:  0.0004069893002869885
# Training Score:  -10.27767321028834 Testing Score: -10.216108275968727
# Loss:  1.0721900671087718
# iteration 148 of 1000
#
# Mean Probability:  0.0004065979430196266
# Training Score:  -10.28070264498593 Testing Score: -10.219625846801403
# Loss:  0.900170272486757
# iteration 149 of 1000
#
# Mean Probability:  0.0004106465870790477
# Training Score:  -10.275159811532781 Testing Score: -10.20889791035347
# Loss:  1.0186907695733323
# iteration 150 of 1000
#
# Mean Probability:  0.0004102459710959864
# Training Score:  -10.280554063162677 Testing Score: -10.204672510412895
# Loss:  0.798008953940125
# iteration 151 of 1000
#
# Mean Probability:  0.00040803265792408236
# Training Score:  -10.289260865211766 Testing Score: -10.209625014449665
# Loss:  0.8223269317133987
# iteration 152 of 1000
#
# Mean Probability:  0.0004093045371618666
# Training Score:  -10.29072129515366 Testing Score: -10.20704970206764
# Loss:  0.936299282034179
# iteration 153 of 1000
#
# Mean Probability:  0.00041190382656729576
# Training Score:  -10.288513730054042 Testing Score: -10.201466965798126
# Loss:  0.9642468019499097
# iteration 154 of 1000
#
# Mean Probability:  0.00041323117586799526
# Training Score:  -10.289760115158124 Testing Score: -10.193754792538769
# Loss:  0.8414492321983166
# iteration 155 of 1000
#
# Mean Probability:  0.00041303712353802307
# Training Score:  -10.294480458491114 Testing Score: -10.197009032555197
# Loss:  0.8076832026300773
# iteration 156 of 1000
#
# Mean Probability:  0.0004133801075660983
# Training Score:  -10.29742379171061 Testing Score: -10.186424416189885
# Loss:  1.0769534292883698
# iteration 157 of 1000
#
# Mean Probability:  0.0004138452866529737
# Training Score:  -10.298151014392964 Testing Score: -10.185991999654906
# Loss:  0.945018638641639
# iteration 158 of 1000
#
# Mean Probability:  0.000412012718327894
# Training Score:  -10.295645349750385 Testing Score: -10.183300977216563
# Loss:  1.0286455188620653
# iteration 159 of 1000
#
# Mean Probability:  0.00041155104238716763
# Training Score:  -10.293815426569708 Testing Score: -10.186172417706052
# Loss:  0.9559838961690144
# iteration 160 of 1000
#
# Mean Probability:  0.00041249766438276826
# Training Score:  -10.294516270537962 Testing Score: -10.183664725046711
# Loss:  1.3873116394437595
# iteration 161 of 1000
#
# Mean Probability:  0.0004167043545849176
# Training Score:  -10.286600355494038 Testing Score: -10.189574247271644
# Loss:  1.2019573411762787
# iteration 162 of 1000
#
# Mean Probability:  0.00041858298871548066
# Training Score:  -10.284279109671708 Testing Score: -10.193044423763338
# Loss:  1.2396575728176444
# iteration 163 of 1000
#
# Mean Probability:  0.00041535823328854544
# Training Score:  -10.278861983283624 Testing Score: -10.198429333112578
# Loss:  1.0341481154522076
# iteration 164 of 1000
#
# Mean Probability:  0.0004144857902170342
# Training Score:  -10.281470796003076 Testing Score: -10.206468092503563
# Loss:  0.9483524746593619
# iteration 165 of 1000
#
# Mean Probability:  0.00041417891742746816
# Training Score:  -10.285220867339955 Testing Score: -10.196588386448859
# Loss:  1.0996456635384493
# iteration 166 of 1000
#
# Mean Probability:  0.0004138361032883477
# Training Score:  -10.288000946560935 Testing Score: -10.204492445469215
# Loss:  0.8686208444641575
# iteration 167 of 1000
#
# Mean Probability:  0.00041763283391966745
# Training Score:  -10.280729355338194 Testing Score: -10.204310629365992
# Loss:  1.0743738396088636
# iteration 168 of 1000
#
# Mean Probability:  0.00041476244530323395
# Training Score:  -10.287145458690329 Testing Score: -10.210798265529144
# Loss:  1.0052893361788238
# iteration 169 of 1000
#
# Mean Probability:  0.0004196308310105248
# Training Score:  -10.283852625626723 Testing Score: -10.204100573242147
# Loss:  0.8753948792119022
# iteration 170 of 1000
#
# Mean Probability:  0.00041973705517854006
# Training Score:  -10.280668707653811 Testing Score: -10.209974088154468
# Loss:  1.052885304947869
# iteration 171 of 1000
#
# Mean Probability:  0.00041977166998064273
# Training Score:  -10.279614208454436 Testing Score: -10.215500234266417
# Loss:  1.1757907428965368
# iteration 172 of 1000
#
# Mean Probability:  0.00042347083925765915
# Training Score:  -10.282707557636932 Testing Score: -10.209507584127676
# Loss:  0.9780406998301787
# iteration 173 of 1000
#
# Mean Probability:  0.000423587912496373
# Training Score:  -10.2679462463319 Testing Score: -10.21771958296506
# Loss:  1.2810934374025769
# iteration 174 of 1000
#
# Mean Probability:  0.00042398242592434673
# Training Score:  -10.26535247531765 Testing Score: -10.21852694482176
# Loss:  1.1369863777774825
# iteration 175 of 1000
#
# Mean Probability:  0.00042463204920095205
# Training Score:  -10.252888797125728 Testing Score: -10.205042754609478
# Loss:  1.014730085811572
# iteration 176 of 1000
#
# Mean Probability:  0.0004252492018588916
# Training Score:  -10.256663366406228 Testing Score: -10.20339379504895
# Loss:  1.120563469504587
# iteration 177 of 1000
#
# Mean Probability:  0.0004293965489750488
# Training Score:  -10.25548065899525 Testing Score: -10.205437583756916
# Loss:  0.8746594804642245
# iteration 178 of 1000
#
# Mean Probability:  0.0004281872410706717
# Training Score:  -10.258440196751986 Testing Score: -10.209074126421529
# Loss:  1.0152656816201382
# iteration 179 of 1000
#
# Mean Probability:  0.00042718955903755346
# Training Score:  -10.262675655646554 Testing Score: -10.213654184950402
# Loss:  0.8437829032420635
# iteration 180 of 1000
#
# Mean Probability:  0.0004275500091932565
# Training Score:  -10.256490134706565 Testing Score: -10.220608051980859
# Loss:  0.9400170049393218
# iteration 181 of 1000
#
# Mean Probability:  0.00043011444578267894
# Training Score:  -10.257930713940961 Testing Score: -10.21604326974085
# Loss:  0.8791673852591498
# iteration 182 of 1000
#
# Mean Probability:  0.0004308300333882301
# Training Score:  -10.259970816123808 Testing Score: -10.202864272740184
# Loss:  0.9301672906335487
# iteration 183 of 1000
#
# Mean Probability:  0.0004274163148811645
# Training Score:  -10.256281556605554 Testing Score: -10.210121036790282
# Loss:  0.921583881217577
# iteration 184 of 1000
#
# Mean Probability:  0.0004307856684231127
# Training Score:  -10.254545848567455 Testing Score: -10.217209948809545
# Loss:  0.8702751894816276
# iteration 185 of 1000
#
# Mean Probability:  0.00042786454812395185
# Training Score:  -10.242232245760556 Testing Score: -10.223579012481235
# Loss:  1.3157237767170018
# iteration 186 of 1000
#
# Mean Probability:  0.0004268062283369628
# Training Score:  -10.247581643173639 Testing Score: -10.230897484197898
# Loss:  0.9360465069164428
# iteration 187 of 1000
#
# Mean Probability:  0.00042411007587169814
# Training Score:  -10.251330327715388 Testing Score: -10.223700248667352
# Loss:  0.9501456419783634
# iteration 188 of 1000
#
# Mean Probability:  0.0004262394716530698
# Training Score:  -10.25072528907415 Testing Score: -10.219052367864634
# Loss:  1.0370426206468752
# iteration 189 of 1000
#
# Mean Probability:  0.00042542385665806276
# Training Score:  -10.251812919334519 Testing Score: -10.22613773608834
# Loss:  0.9987025999910091
# iteration 190 of 1000
#
# Mean Probability:  0.0004253201922861695
# Training Score:  -10.257373966426975 Testing Score: -10.21741876593778
# Loss:  0.7926638373122359
# iteration 191 of 1000
#
# Mean Probability:  0.000424686293817225
# Training Score:  -10.257015435665581 Testing Score: -10.213037171037934
# Loss:  0.9083458854129838
# iteration 192 of 1000
#
# Mean Probability:  0.0004281509452759289
# Training Score:  -10.254385015656744 Testing Score: -10.219781372354225
# Loss:  1.2013181435917186
# iteration 193 of 1000
#
# Mean Probability:  0.00042655820661020394
# Training Score:  -10.258684094083163 Testing Score: -10.224922607001412
# Loss:  0.8724412880724857
# iteration 194 of 1000
#
# Mean Probability:  0.0004263222987382978
# Training Score:  -10.258636975582574 Testing Score: -10.22981669239187
# Loss:  0.9098799075908692
# iteration 195 of 1000
#
# Mean Probability:  0.00042437624613694645
# Training Score:  -10.254103888164796 Testing Score: -10.225796475212771
# Loss:  1.1915666417953794
# iteration 196 of 1000
#
# Mean Probability:  0.0004222206941571354
# Training Score:  -10.2603158961956 Testing Score: -10.197067312542886
# Loss:  1.0867222321590675
# iteration 197 of 1000
#
# Mean Probability:  0.00042274583712637053
# Training Score:  -10.26381857754505 Testing Score: -10.199494970004114
# Loss:  0.7921757178360616
# iteration 198 of 1000
#
# Mean Probability:  0.00042366246218281437
# Training Score:  -10.253571721569342 Testing Score: -10.193892008925964
# Loss:  1.0130996630576408
# iteration 199 of 1000
#
# Mean Probability:  0.0004211508217326967
# Training Score:  -10.260440771579718 Testing Score: -10.199492417057934
# Loss:  0.8272319115798447
# iteration 200 of 1000
#
# Mean Probability:  0.0004191237532914873
# Training Score:  -10.25750269587791 Testing Score: -10.203887677003555
# Loss:  0.9581396881130193
# iteration 201 of 1000
#
# Mean Probability:  0.0004195926473355101
# Training Score:  -10.258882816807454 Testing Score: -10.204086639654873
# Loss:  0.8956320026833859
# iteration 202 of 1000
#
# Mean Probability:  0.00041914506097028275
# Training Score:  -10.25665950937286 Testing Score: -10.191276126047962
# Loss:  1.0274263126358418
# iteration 203 of 1000
#
# Mean Probability:  0.00041730593106567576
# Training Score:  -10.260423139441912 Testing Score: -10.196391090198475
# Loss:  0.9164061297813669
# iteration 204 of 1000
#
# Mean Probability:  0.00041580958953947903
# Training Score:  -10.26422827693035 Testing Score: -10.201759291931621
# Loss:  0.8490009772737711
# iteration 205 of 1000
#
# Mean Probability:  0.00041523076673598047
# Training Score:  -10.267281083083265 Testing Score: -10.206315919499756
# Loss:  0.9245603458923973
# iteration 206 of 1000
#
# Mean Probability:  0.00041718191440293356
# Training Score:  -10.26194115265153 Testing Score: -10.209450230377938
# Loss:  1.000505195115072
# iteration 207 of 1000
#
# Mean Probability:  0.0004187881296586796
# Training Score:  -10.254623097256367 Testing Score: -10.215371030125391
# Loss:  1.3042418969047902
# iteration 208 of 1000
#
# Mean Probability:  0.0004184481949077191
# Training Score:  -10.25000382372091 Testing Score: -10.214933655923218
# Loss:  1.0352963090846976
# iteration 209 of 1000
#
# Mean Probability:  0.00042056695728718755
# Training Score:  -10.246942851891458 Testing Score: -10.202527174005283
# Loss:  1.2688408628199634
# iteration 210 of 1000
#
# Mean Probability:  0.00042034686077005565
# Training Score:  -10.245851812861584 Testing Score: -10.206363014584744
# Loss:  0.9717229675696114
# iteration 211 of 1000
#
# Mean Probability:  0.0004194920446931729
# Training Score:  -10.250209403471606 Testing Score: -10.21349782282798
# Loss:  0.8013864636647389
# iteration 212 of 1000
#
# Mean Probability:  0.00041933357840884304
# Training Score:  -10.252930098849767 Testing Score: -10.209470417608879
# Loss:  0.9214651304269902
# iteration 213 of 1000
#
# Mean Probability:  0.00041860848002746347
# Training Score:  -10.253988451540216 Testing Score: -10.214051914050719
# Loss:  1.010017011557057
# iteration 214 of 1000
#
# Mean Probability:  0.0004225217117195711
# Training Score:  -10.235614013481404 Testing Score: -10.207069676903727
# Loss:  0.931663901014304
# iteration 215 of 1000
#
# Mean Probability:  0.000423531053611723
# Training Score:  -10.2367837879328 Testing Score: -10.20356860882173
# Loss:  0.9035044716412354
# iteration 216 of 1000
#
# Mean Probability:  0.00042192724927747496
# Training Score:  -10.23987479816732 Testing Score: -10.209395267783721
# Loss:  0.8990016252833203
# iteration 217 of 1000
#
# Mean Probability:  0.00042100206768392164
# Training Score:  -10.245532843278902 Testing Score: -10.192538671503081
# Loss:  0.8794359781268428
# iteration 218 of 1000
#
# Mean Probability:  0.0004259963494006313
# Training Score:  -10.244903350500254 Testing Score: -10.183105587368502
# Loss:  1.0003509105966133
# iteration 219 of 1000
#
# Mean Probability:  0.0004248998839064393
# Training Score:  -10.235054548897114 Testing Score: -10.186829676329676
# Loss:  1.0206455147962148
# iteration 220 of 1000
#
# Mean Probability:  0.0004277374686985204
# Training Score:  -10.232907350601215 Testing Score: -10.19265059667066
# Loss:  0.918635797655753
# iteration 221 of 1000
#
# Mean Probability:  0.00042821414095515955
# Training Score:  -10.238900213928385 Testing Score: -10.176622023773922
# Loss:  0.8328119817374664
# iteration 222 of 1000
#
# Mean Probability:  0.00043176736299165735
# Training Score:  -10.223792858713107 Testing Score: -10.183050951612811
# Loss:  1.0219157844631366
# iteration 223 of 1000
#
# Mean Probability:  0.00043008586661595264
# Training Score:  -10.229748386112178 Testing Score: -10.176340635980354
# Loss:  1.0841029432560538
# iteration 224 of 1000
#
# Mean Probability:  0.00043189156571593905
# Training Score:  -10.227396022269355 Testing Score: -10.184378061796766
# Loss:  0.8832826210646727
# iteration 225 of 1000
#
# Mean Probability:  0.0004321592099356635
# Training Score:  -10.233541536479875 Testing Score: -10.184513345863008
# Loss:  0.8402104583353713
# iteration 226 of 1000
#
# Mean Probability:  0.0004319089684647892
# Training Score:  -10.236700397776854 Testing Score: -10.191105693308009
# Loss:  1.0069939242309172
# iteration 227 of 1000
#
# Mean Probability:  0.0004327244479722814
# Training Score:  -10.238950918624647 Testing Score: -10.196937415322807
# Loss:  1.0979437086631219
# iteration 228 of 1000
#
# Mean Probability:  0.0004367385230662551
# Training Score:  -10.240663383184007 Testing Score: -10.191417168401157
# Loss:  0.9140885678345374
# iteration 229 of 1000
#
# Mean Probability:  0.000440857020964824
# Training Score:  -10.235750817931532 Testing Score: -10.180403808806961
# Loss:  1.0834817973381967
# iteration 230 of 1000
#
# Mean Probability:  0.0004412425489448873
# Training Score:  -10.224636977910299 Testing Score: -10.18700204034374
# Loss:  0.9882778856196256
# iteration 231 of 1000
#
# Mean Probability:  0.0004381916184814721
# Training Score:  -10.214085601925497 Testing Score: -10.194873891609413
# Loss:  1.1258654560253516
# iteration 232 of 1000
#
# Mean Probability:  0.0004372825005346198
# Training Score:  -10.21562832674311 Testing Score: -10.199687558879
# Loss:  0.8805782224716716
# iteration 233 of 1000
#
# Mean Probability:  0.0004425500765509105
# Training Score:  -10.200276498279237 Testing Score: -10.201162868202562
# Loss:  1.1406007730882082
# iteration 234 of 1000
#
# Mean Probability:  0.00044029627348100093
# Training Score:  -10.208177661415185 Testing Score: -10.204710777730945
# Loss:  0.8563796903240268
# iteration 235 of 1000
#
# Mean Probability:  0.00043846737238117494
# Training Score:  -10.21418342836102 Testing Score: -10.211290791047624
# Loss:  0.8769884884992083
# iteration 236 of 1000
#
# Mean Probability:  0.000439559585128384
# Training Score:  -10.214045947885332 Testing Score: -10.212679379366351
# Loss:  0.8876695429753176
# iteration 237 of 1000
#
# Mean Probability:  0.00044210014682880553
# Training Score:  -10.214167312680908 Testing Score: -10.1958036721352
# Loss:  0.9600638034125465
# iteration 238 of 1000
#
# Mean Probability:  0.00044202314449792756
# Training Score:  -10.219243853735495 Testing Score: -10.197992310619583
# Loss:  0.8984555297627923
# iteration 239 of 1000
#
# Mean Probability:  0.0004397263608164962
# Training Score:  -10.216781966582904 Testing Score: -10.202314718020926
# Loss:  0.9303348011427366
# iteration 240 of 1000
#
# Mean Probability:  0.0004432135316965795
# Training Score:  -10.213884634010435 Testing Score: -10.208515810619936
# Loss:  1.2928213148251853
# iteration 241 of 1000
#
# Mean Probability:  0.000442548554877281
# Training Score:  -10.211540615435181 Testing Score: -10.214816790449202
# Loss:  0.9408626477500093
# iteration 242 of 1000
#
# Mean Probability:  0.00044013683942064876
# Training Score:  -10.218138233429377 Testing Score: -10.220071930328457
# Loss:  0.8526216753338128
# iteration 243 of 1000
#
# Mean Probability:  0.00044514924074976896
# Training Score:  -10.214896681221592 Testing Score: -10.205121708635206
# Loss:  1.164605019662865
# iteration 244 of 1000
#
# Mean Probability:  0.000443133156220421
# Training Score:  -10.216882154350664 Testing Score: -10.191152478540527
# Loss:  1.133083352382619
# iteration 245 of 1000
#
# Mean Probability:  0.0004440515131581093
# Training Score:  -10.203545016853377 Testing Score: -10.196897552499923
# Loss:  0.9681866591300363
# iteration 246 of 1000
#
# Mean Probability:  0.00044077960491601846
# Training Score:  -10.210971580217487 Testing Score: -10.204267835909063
# Loss:  0.8548772833522471
# iteration 247 of 1000
#
# Mean Probability:  0.00043992541882248367
# Training Score:  -10.204824442943707 Testing Score: -10.20599177321238
# Loss:  1.2413531965554794
# iteration 248 of 1000
#
# Mean Probability:  0.000438196427381073
# Training Score:  -10.207311613184004 Testing Score: -10.194123694823409
# Loss:  0.7770581277924957
# iteration 249 of 1000
#
# Mean Probability:  0.00043735367439865213
# Training Score:  -10.21303961281289 Testing Score: -10.195896847123791
# Loss:  0.9386254022543131
# iteration 250 of 1000
#
# Mean Probability:  0.00043579205253345936
# Training Score:  -10.218098540681183 Testing Score: -10.20142880197863
# Loss:  0.9673765836520463
# iteration 251 of 1000
#
# Mean Probability:  0.00043819044648594444
# Training Score:  -10.20998865842602 Testing Score: -10.205466846353763
# Loss:  1.068464117015828
# iteration 252 of 1000
#
# Mean Probability:  0.00044082483913278147
# Training Score:  -10.205007631799285 Testing Score: -10.180749186978762
# Loss:  0.9498453848132963
# iteration 253 of 1000
#
# Mean Probability:  0.0004442139680550361
# Training Score:  -10.202044254984072 Testing Score: -10.185216386557729
# Loss:  0.8689947246439033
# iteration 254 of 1000
#
# Mean Probability:  0.00044507583123218195
# Training Score:  -10.193946409399574 Testing Score: -10.172062628652766
# Loss:  1.1006179915057572
# iteration 255 of 1000
#
# Mean Probability:  0.00044331095795300347
# Training Score:  -10.19986627548675 Testing Score: -10.179365319109882
# Loss:  1.1009480213829916
# iteration 256 of 1000
#
# Mean Probability:  0.00044125357869292107
# Training Score:  -10.199863165347333 Testing Score: -10.183396333498953
# Loss:  0.875487388392063
# iteration 257 of 1000
#
# Mean Probability:  0.000446473154887754
# Training Score:  -10.197194333077602 Testing Score: -10.182636868849185
# Loss:  0.8706814804836297
# iteration 258 of 1000
#
# Mean Probability:  0.00044499411682759587
# Training Score:  -10.203783615467565 Testing Score: -10.167125282839912
# Loss:  0.832715560709499
# iteration 259 of 1000
#
# Mean Probability:  0.00044753722912873234
# Training Score:  -10.202031004444855 Testing Score: -10.173590233798311
# Loss:  1.0127125058436617
# iteration 260 of 1000
#
# Mean Probability:  0.0004466845924764576
# Training Score:  -10.20717887850137 Testing Score: -10.179850221048012
# Loss:  0.8309433226144335
# iteration 261 of 1000
#
# Mean Probability:  0.000444963190331918
# Training Score:  -10.20945446087467 Testing Score: -10.165327088342819
# Loss:  0.8490958598810743
# iteration 262 of 1000
#
# Mean Probability:  0.0004447799532522978
# Training Score:  -10.210154616026578 Testing Score: -10.171760837142262
# Loss:  1.0662943031768688
# iteration 263 of 1000
#
# Mean Probability:  0.00044821956881823657
# Training Score:  -10.205275568141342 Testing Score: -10.165100899820136
# Loss:  0.8610539950243006
# iteration 264 of 1000
#
# Mean Probability:  0.0004527882418009459
# Training Score:  -10.183650921052918 Testing Score: -10.158391208470952
# Loss:  0.984287547542478
# iteration 265 of 1000
#
# Mean Probability:  0.0004541665014936197
# Training Score:  -10.181235982578166 Testing Score: -10.154460610282996
# Loss:  0.9873648271460982
# iteration 266 of 1000
#
# Mean Probability:  0.0004521095460170608
# Training Score:  -10.186608812744899 Testing Score: -10.149532111929284
# Loss:  1.0060547858255675
# iteration 267 of 1000
#
# Mean Probability:  0.0004509453429124895
# Training Score:  -10.189270352753047 Testing Score: -10.152185491202404
# Loss:  0.877056896810587
# iteration 268 of 1000
#
# Mean Probability:  0.0004548030717517294
# Training Score:  -10.192210450729682 Testing Score: -10.150099165880246
# Loss:  0.9160431127100143
# iteration 269 of 1000
#
# Mean Probability:  0.0004524416957157022
# Training Score:  -10.18883259326812 Testing Score: -10.157263831613337
# Loss:  0.8554717139954103
# iteration 270 of 1000
#
# Mean Probability:  0.00045259560608977865
# Training Score:  -10.183816198262294 Testing Score: -10.16002561329776
# Loss:  0.9390469280232228
# iteration 271 of 1000
#
# Mean Probability:  0.00045107716978274036
# Training Score:  -10.176475473423217 Testing Score: -10.163587447636914
# Loss:  0.9182452391237338
# iteration 272 of 1000
#
# Mean Probability:  0.0004485257160679229
# Training Score:  -10.177749428689825 Testing Score: -10.168563856795798
# Loss:  0.9397489135615492
# iteration 273 of 1000
#
# Mean Probability:  0.0004455154951002336
# Training Score:  -10.182010524096146 Testing Score: -10.174639395654918
# Loss:  0.8771334564183146
# iteration 274 of 1000
#
# Mean Probability:  0.0004453895862481358
# Training Score:  -10.183175844021967 Testing Score: -10.179897489693433
# Loss:  0.9041666620139021
# iteration 275 of 1000
#
# Mean Probability:  0.00044295290791649154
# Training Score:  -10.187232247421408 Testing Score: -10.183744050452848
# Loss:  1.1497589273636857
# iteration 276 of 1000
#
# Mean Probability:  0.0004421495042792188
# Training Score:  -10.189281898137928 Testing Score: -10.184312368912272
# Loss:  0.8857702909501105
# iteration 277 of 1000
#
# Mean Probability:  0.00044105784637177205
# Training Score:  -10.18929222605163 Testing Score: -10.168458709990507
# Loss:  0.9511553743610424
# iteration 278 of 1000
#
# Mean Probability:  0.0004400483834155127
# Training Score:  -10.1892526265891 Testing Score: -10.150699454981002
# Loss:  0.8781677472800969
# iteration 279 of 1000
#
# Mean Probability:  0.00044506033598884894
# Training Score:  -10.172590772304062 Testing Score: -10.145910935637467
# Loss:  1.3762097995138953
# iteration 280 of 1000
#
# Mean Probability:  0.00044325831815464773
# Training Score:  -10.181776899454844 Testing Score: -10.127151008448743
# Loss:  0.9527101978185318
# iteration 281 of 1000
#
# Mean Probability:  0.0004417395574114034
# Training Score:  -10.187848618527317 Testing Score: -10.133206309366084
# Loss:  0.8459009252468834
# iteration 282 of 1000
#
# Mean Probability:  0.0004407864606943095
# Training Score:  -10.186283609342203 Testing Score: -10.140162543819388
# Loss:  0.8716790040081621
# iteration 283 of 1000
#
# Mean Probability:  0.00043891959169978695
# Training Score:  -10.191071428873395 Testing Score: -10.148018296658224
# Loss:  0.8340298373891499
# iteration 284 of 1000
#
# Mean Probability:  0.0004434243306437054
# Training Score:  -10.182211488946294 Testing Score: -10.13630145563306
# Loss:  0.9633927188963406
# iteration 285 of 1000
#
# Mean Probability:  0.0004435590593881735
# Training Score:  -10.183708128132015 Testing Score: -10.141987974646007
# Loss:  1.1759143237689562
# iteration 286 of 1000
#
# Mean Probability:  0.0004437305315435053
# Training Score:  -10.186002237674135 Testing Score: -10.115162776034769
# Loss:  0.9243711719972569
# iteration 287 of 1000
#
# Mean Probability:  0.00044391020309125025
# Training Score:  -10.180518359018965 Testing Score: -10.111533341465694
# Loss:  0.9448423615670521
# iteration 288 of 1000
#
# Mean Probability:  0.0004434858653938122
# Training Score:  -10.173545193236896 Testing Score: -10.113912409300447
# Loss:  0.9237853382168929
# iteration 289 of 1000
#
# Mean Probability:  0.00044457797213867407
# Training Score:  -10.179991126223207 Testing Score: -10.115834801838337
# Loss:  0.917687400541505
# iteration 290 of 1000
#
# Mean Probability:  0.00044619758300348995
# Training Score:  -10.181185839760769 Testing Score: -10.121419509709837
# Loss:  0.8313919067341018
# iteration 291 of 1000
#
# Mean Probability:  0.00044566200074741677
# Training Score:  -10.180162718550063 Testing Score: -10.121120538359111
# Loss:  1.0204137525358552
# iteration 292 of 1000
#
# Mean Probability:  0.00044903647202397935
# Training Score:  -10.180590793202375 Testing Score: -10.122269753567528
# Loss:  1.0593000195208522
# iteration 293 of 1000
#
# Mean Probability:  0.0004489277001458358
# Training Score:  -10.175825231180532 Testing Score: -10.120458351475833
# Loss:  0.8373593945733854
# iteration 294 of 1000
#
# Mean Probability:  0.0004504606852251667
# Training Score:  -10.17729148180381 Testing Score: -10.124363626572801
# Loss:  1.021207785081071
# iteration 295 of 1000
#
# Mean Probability:  0.0004485602299692103
# Training Score:  -10.173604583579117 Testing Score: -10.130948837328928
# Loss:  1.1916374502426292
# iteration 296 of 1000
#
# Mean Probability:  0.00044771259709888386
# ...
#
# Mean Probability:  0.0060524673766719425
# Training Score:  -1.674235191862831 Testing Score: -12.938882373328024
# Loss:  0.18800579981857352
# iteration 902 of 1000
#
# Mean Probability:  0.005455353956452861
# Training Score:  -1.7782067394685794 Testing Score: -12.938586048471963
# Loss:  0.18890724121663155
# iteration 903 of 1000
#
# Mean Probability:  0.004917988011759716
# Training Score:  -1.8820191312249086 Testing Score: -12.93838217468223
# Loss:  0.18889124342550653
# iteration 904 of 1000
#
# Mean Probability:  0.005342576202404612
# Training Score:  -1.7991208680487123 Testing Score: -12.937857075842656
# Loss:  0.3528880351847121
# iteration 905 of 1000
#
# Mean Probability:  0.005726628144985732
# Training Score:  -1.7296315581636288 Testing Score: -12.937550959981197
# Loss:  0.3411171951077196
# iteration 906 of 1000
#
# Mean Probability:  0.005162018270797295
# Training Score:  -1.8335398966442367 Testing Score: -12.937240436508262
# Loss:  0.18870512843691076
# iteration 907 of 1000
#
# Mean Probability:  0.005564799511013641
# Training Score:  -1.7583277409304936 Testing Score: -12.936888218723077
# Loss:  0.3455509975014537
# iteration 908 of 1000
#
# Mean Probability:  0.005016337089423015
# Training Score:  -1.862201394958017 Testing Score: -12.936516972405913
# Loss:  0.1883787861964926
# iteration 909 of 1000
#
# Mean Probability:  0.0045227435567951075
# Training Score:  -1.9659073830014921 Testing Score: -12.936342354199507
# Loss:  0.1886456546672467
# iteration 910 of 1000
#
# Mean Probability:  0.004988166403142172
# Training Score:  -1.8678422140457933 Testing Score: -12.935759816224092
# Loss:  0.36407676041680054
# iteration 911 of 1000
#
# Mean Probability:  0.005410677452451617
# Training Score:  -1.7864476180332647 Testing Score: -12.935509612373012
# Loss:  0.35010820694381195
# iteration 912 of 1000
#
# Mean Probability:  0.005791288164569876
# Training Score:  -1.718398911582685 Testing Score: -12.933653515221208
# Loss:  0.338928477119539
# iteration 913 of 1000
#
# Mean Probability:  0.00613586350310535
# Training Score:  -1.6605473298861568 Testing Score: -12.933861679116971
# Loss:  0.33036380723131553
# iteration 914 of 1000
#
# Mean Probability:  0.006446523865962249
# Training Score:  -1.6111125003173574 Testing Score: -12.933861443073749
# Loss:  0.3229234150803707
# iteration 915 of 1000
#
# Mean Probability:  0.006727312079097751
# Training Score:  -1.5684410115235186 Testing Score: -12.933810728484435
# Loss:  0.3171569922222478
# iteration 916 of 1000
#
# Mean Probability:  0.006981905011511523
# Training Score:  -1.5312636939859372 Testing Score: -12.933859962733106
# Loss:  0.31227722305400907
# iteration 917 of 1000
#
# Mean Probability:  0.00721187523261889
# Training Score:  -1.4988299935695006 Testing Score: -12.934091403501474
# Loss:  0.307983457746286
# iteration 918 of 1000
#
# Mean Probability:  0.007421469021246635
# Training Score:  -1.4701593631587961 Testing Score: -12.934129695410615
# Loss:  0.3047287251103572
# iteration 919 of 1000
#
# Mean Probability:  0.007608445513989924
# Training Score:  -1.445258182877454 Testing Score: -12.93433756003015
# Loss:  0.30111458450544204
# iteration 920 of 1000
#
# Mean Probability:  0.006855199545704692
# Training Score:  -1.5495916067399615 Testing Score: -12.934487687042383
# Loss:  0.185546688646364
# iteration 921 of 1000
#
# Mean Probability:  0.00709812673028698
# Training Score:  -1.5147397367813642 Testing Score: -12.934336507324996
# Loss:  0.309311664851721
# iteration 922 of 1000
#
# Mean Probability:  0.007317755310052631
# Training Score:  -1.484242935596185 Testing Score: -12.934357915930095
# Loss:  0.30575513981446856
# iteration 923 of 1000
#
# Mean Probability:  0.006593623377719964
# Training Score:  -1.5885287514425102 Testing Score: -12.934472681154897
# Loss:  0.18499915086880123
# iteration 924 of 1000
#
# Mean Probability:  0.005941878506642525
# Training Score:  -1.6927017995716398 Testing Score: -12.934177914267003
# Loss:  0.18545615188685394
# iteration 925 of 1000
#
# Mean Probability:  0.005355403762699339
# Training Score:  -1.7967268835328365 Testing Score: -12.93385982088741
# Loss:  0.18557794365564684
# iteration 926 of 1000
#
# Mean Probability:  0.0048275483794543265
# Training Score:  -1.9006123651741265 Testing Score: -12.933499144541697
# Loss:  0.18616545317691163
# iteration 927 of 1000
#
# Mean Probability:  0.004352537161600216
# Training Score:  -2.0043233287064677 Testing Score: -12.932973888415663
# Loss:  0.18649462089482868
# iteration 928 of 1000
#
# Mean Probability:  0.0048426238729670674
# Training Score:  -1.897494925608765 Testing Score: -12.932342567070798
# Loss:  0.36808647715231557
# iteration 929 of 1000
#
# Mean Probability:  0.004366057941063817
# Training Score:  -2.001221706445188 Testing Score: -12.932052566093743
# Loss:  0.18635372807730793
# iteration 930 of 1000
#
# Mean Probability:  0.004856443480222427
# Training Score:  -1.8946450334733533 Testing Score: -12.93163872797647
# Loss:  0.36764626290397096
# iteration 931 of 1000
#
# Mean Probability:  0.005299152611324838
# Training Score:  -1.8073065569840878 Testing Score: -12.931402678070395
# Loss:  0.35174768674670887
# iteration 932 of 1000
#
# Mean Probability:  0.005700093048528431
# Training Score:  -1.7342950633874739 Testing Score: -12.931194595830148
# Loss:  0.34031962427441526
# iteration 933 of 1000
#
# Mean Probability:  0.006062496243994364
# Training Score:  -1.672595560033179 Testing Score: -12.931094711453206
# Loss:  0.33047921233410193
# iteration 934 of 1000
#
# Mean Probability:  0.006392072288836135
# Training Score:  -1.619609826776118 Testing Score: -12.930940018938355
# Loss:  0.3233908094790083
# iteration 935 of 1000
#
# Mean Probability:  0.005760365265939906
# Training Score:  -1.7237657095646806 Testing Score: -12.931042671749864
# Loss:  0.18457593491560664
# iteration 936 of 1000
#
# Mean Probability:  0.00611716841665143
# Training Score:  -1.6636096464445218 Testing Score: -12.93077588960133
# Loss:  0.32914350769563505
# iteration 937 of 1000
#
# Mean Probability:  0.00644060388140752
# Training Score:  -1.6120390241470808 Testing Score: -12.930827860514494
# Loss:  0.3217500553876509
# iteration 938 of 1000
#
# Mean Probability:  0.006732828184525947
# Training Score:  -1.5676272290925675 Testing Score: -12.930887890698623
# Loss:  0.31559948457432174
# iteration 939 of 1000
#
# Mean Probability:  0.006998541744499171
# Training Score:  -1.5288875209497614 Testing Score: -12.931059563489107
# Loss:  0.3107428761983424
# iteration 940 of 1000
#
# Mean Probability:  0.0072366179764727125
# Training Score:  -1.4954081031303454 Testing Score: -12.931199875211146
# Loss:  0.3061705830325097
# iteration 941 of 1000
#
# Mean Probability:  0.006520282115253605
# Training Score:  -1.5997312267180483 Testing Score: -12.931261062707271
# Loss:  0.18370947698419654
# iteration 942 of 1000
#
# Mean Probability:  0.006805763010429284
# Training Score:  -1.5568422829024642 Testing Score: -12.931274617168134
# Loss:  0.31393334658816485
# iteration 943 of 1000
#
# Mean Probability:  0.0061324891188143235
# Training Score:  -1.661103734693848 Testing Score: -12.931441559552843
# Loss:  0.1837726578650109
# iteration 944 of 1000
#
# Mean Probability:  0.006457034317861988
# Training Score:  -1.6094875874314176 Testing Score: -12.93137168678379
# Loss:  0.3211333077039053
# iteration 945 of 1000
#
# Mean Probability:  0.006750551294098518
# Training Score:  -1.5649949647347008 Testing Score: -12.931304589072582
# Loss:  0.314891060858698
# iteration 946 of 1000
#
# Mean Probability:  0.007018312120500801
# Training Score:  -1.5260639198133361 Testing Score: -12.93127074257782
# Loss:  0.3103232174359859
# iteration 947 of 1000
#
# Mean Probability:  0.007258387297353381
# Training Score:  -1.4924014797172442 Testing Score: -12.931389981960015
# Loss:  0.3055029265803863
# iteration 948 of 1000
#
# Mean Probability:  0.0065396900037830085
# Training Score:  -1.5967561393849892 Testing Score: -12.93150307253263
# Loss:  0.18336510659847494
# iteration 949 of 1000
#
# Mean Probability:  0.006826795005213876
# Training Score:  -1.5537535200701724 Testing Score: -12.931614402048826
# Loss:  0.31341867176932636
# iteration 950 of 1000
#
# Mean Probability:  0.006151266621150429
# Training Score:  -1.6580439354739125 Testing Score: -12.931351714247377
# Loss:  0.1835609665873781
# iteration 951 of 1000
#
# Mean Probability:  0.006477694265105159
# Training Score:  -1.6062902232682512 Testing Score: -12.931420335613847
# Loss:  0.32068372861692784
# iteration 952 of 1000
#
# Mean Probability:  0.005837062108025084
# Training Score:  -1.7105256313856354 Testing Score: -12.931033997579364
# Loss:  0.18373403822167989
# iteration 953 of 1000
#
# Mean Probability:  0.0061972194182339365
# Training Score:  -1.6505957094413437 Testing Score: -12.930821749230036
# Loss:  0.3274516958246215
# iteration 954 of 1000
#
# Mean Probability:  0.005584643598879725
# Training Score:  -1.7547787069678298 Testing Score: -12.930490469746728
# Loss:  0.18382959803637103
# iteration 955 of 1000
#
# Mean Probability:  0.0059706326201909255
# Training Score:  -1.6878802940318132 Testing Score: -12.930276524857693
# Loss:  0.3331477509431884
# iteration 956 of 1000
#
# Mean Probability:  0.006315885746341087
# Training Score:  -1.6316133517123705 Testing Score: -12.930013733269348
# Loss:  0.3243291269059945
# iteration 957 of 1000
#
# Mean Probability:  0.005691434588642774
# Training Score:  -1.7358191060035668 Testing Score: -12.930068223429185
# Loss:  0.18373917131775325
# iteration 958 of 1000
#
# Mean Probability:  0.006065341360043451
# Training Score:  -1.672129142224735 Testing Score: -12.9299213369388
# Loss:  0.3304138144208102
# iteration 959 of 1000
#
# Mean Probability:  0.005465896612196735
# Training Score:  -1.7762960921929933 Testing Score: -12.929907502737212
# Loss:  0.18390526283668643
# iteration 960 of 1000
#
# Mean Probability:  0.004926454147688287
# Training Score:  -1.8803220577453583 Testing Score: -12.929673520043439
# Loss:  0.1843554215149312
# iteration 961 of 1000
#
# Mean Probability:  0.005377046276629758
# Training Score:  -1.7927046938794933 Testing Score: -12.929522850004647
# Loss:  0.3497699996438311
# iteration 962 of 1000
#
# Mean Probability:  0.004846417385685837
# Training Score:  -1.8967233442699327 Testing Score: -12.929276812009292
# Loss:  0.18425979775188195
# iteration 963 of 1000
#
# Mean Probability:  0.005305519566643466
# Training Score:  -1.806112994621847 Testing Score: -12.929077099249406
# Loss:  0.3520502016354146
# iteration 964 of 1000
#
# Mean Probability:  0.004782035868531947
# Training Score:  -1.910115063510344 Testing Score: -12.928930264834023
# Loss:  0.18422790077661957
# iteration 965 of 1000
#
# Mean Probability:  0.005246910587265698
# Training Score:  -1.81723552993189 Testing Score: -12.928628849269897
# Loss:  0.3537230223862248
# iteration 966 of 1000
#
# Mean Probability:  0.005668318596842842
# Training Score:  -1.7399008934423048 Testing Score: -12.928443321164949
# Loss:  0.34090559244041896
# iteration 967 of 1000
#
# Mean Probability:  0.006050447160285077
# Training Score:  -1.6745966288271825 Testing Score: -12.92833647264542
# Loss:  0.3311588214273923
# iteration 968 of 1000
#
# Mean Probability:  0.005452493295889802
# Training Score:  -1.7787612446688144 Testing Score: -12.928363094550198
# Loss:  0.18335790036355723
# iteration 969 of 1000
#
# Mean Probability:  0.005855324820736094
# Training Score:  -1.7074097283492464 Testing Score: -12.928278048412713
# Loss:  0.33601623497145466
# iteration 970 of 1000
#
# Mean Probability:  0.006218778382411313
# Training Score:  -1.647129697952882 Testing Score: -12.928238521446085
# Loss:  0.3265786878802406
# iteration 971 of 1000
#
# Mean Probability:  0.005603896644515871
# Training Score:  -1.7513437024943077 Testing Score: -12.926933543925383
# Loss:  0.1831691332790904
# iteration 972 of 1000
#
# Mean Probability:  0.005050602053943478
# Training Score:  -1.8554128792787148 Testing Score: -12.926875490339937
# Loss:  0.18354127132520154
# iteration 973 of 1000
#
# Mean Probability:  0.006421130532429036
# Training Score:  -1.6150807660673931 Testing Score: -12.926811051563664
# Loss:  0.8350267562217927
# iteration 974 of 1000
#
# Mean Probability:  0.006697594437693613
# Training Score:  -1.5728801069619371 Testing Score: -12.930502587068176
# Loss:  0.3158042021906421
# iteration 975 of 1000
#
# Mean Probability:  0.006036491015006398
# Training Score:  -1.6768912566975955 Testing Score: -12.9337402539515
# Loss:  0.18455450250902877
# iteration 976 of 1000
#
# Mean Probability:  0.006355685344467477
# Training Score:  -1.6253105645558663 Testing Score: -12.935059862895864
# Loss:  0.32206781884567504
# iteration 977 of 1000
#
# Mean Probability:  0.006646069626370762
# Training Score:  -1.5805898639080147 Testing Score: -12.937603468441745
# Loss:  0.3155272995592644
# iteration 978 of 1000
#
# Mean Probability:  0.00598987058542027
# Training Score:  -1.6846336739446335 Testing Score: -12.938348260386437
# Loss:  0.18302170752912209
# iteration 979 of 1000
#
# Mean Probability:  0.0053992513613984605
# Training Score:  -1.7885406523134775 Testing Score: -12.940235221105393
# Loss:  0.18351514848008743
# iteration 980 of 1000
#
# Mean Probability:  0.004867765745049001
# Training Score:  -1.8922746836770217 Testing Score: -12.941738111313205
# Loss:  0.18370272364680557
# iteration 981 of 1000
#
# Mean Probability:  0.005309925670856316
# Training Score:  -1.8052336436217642 Testing Score: -12.943035537220315
# Loss:  0.3496367965304949
# iteration 982 of 1000
#
# Mean Probability:  0.004787194486983104
# Training Score:  -1.9089781092623404 Testing Score: -12.944038490416874
# Loss:  0.1836631830786969
# iteration 983 of 1000
#
# Mean Probability:  0.006071392800854318
# Training Score:  -1.671088573733397 Testing Score: -12.944856311356075
# Loss:  0.7826434129147639
# iteration 984 of 1000
#
# Mean Probability:  0.006338850789004831
# Training Score:  -1.6279304701707726 Testing Score: -12.948949472373533
# Loss:  0.3193902330751342
# iteration 985 of 1000
#
# Mean Probability:  0.005714637270933688
# Training Score:  -1.7316815680235451 Testing Score: -12.95248442656117
# Loss:  0.18477872948357138
# iteration 986 of 1000
#
# Mean Probability:  0.0051528204631875
# Training Score:  -1.835262434823715 Testing Score: -12.955437744416919
# Loss:  0.18468437243554942
# iteration 987 of 1000
#
# Mean Probability:  0.0046471492528756255
# Training Score:  -1.9386576158822018 Testing Score: -12.958013170299816
# Loss:  0.18497844460800952
# iteration 988 of 1000
#
# Mean Probability:  0.005073962328930078
# Training Score:  -1.8506872154338903 Testing Score: -12.96013378076463
# Loss:  0.35389485247701297
# iteration 989 of 1000
#
# Mean Probability:  0.005466766856701644
# Training Score:  -1.7760422771187767 Testing Score: -12.961897053057312
# Loss:  0.3418538770599364
# iteration 990 of 1000
#
# Mean Probability:  0.00582837852120134
# Training Score:  -1.7119275486109382 Testing Score: -12.963330007023874
# Loss:  0.3324672364463616
# iteration 991 of 1000
#
# Mean Probability:  0.006154929955335673
# Training Score:  -1.6573632430769778 Testing Score: -12.964281734559053
# Loss:  0.32378481780370494
# iteration 992 of 1000
#
# Mean Probability:  0.00645461966226127
# Training Score:  -1.6097789899784725 Testing Score: -12.965209031862166
# Loss:  0.3177154388199011
# iteration 993 of 1000
#
# Mean Probability:  0.005817926865520569
# Training Score:  -1.7137183137062195 Testing Score: -12.965688976793752
# Loss:  0.1827914613092203
# iteration 994 of 1000
#
# Mean Probability:  0.006155108307440724
# Training Score:  -1.6573300323232336 Testing Score: -12.964943215323268
# Loss:  0.3246247533225914
# iteration 995 of 1000
#
# Mean Probability:  0.005548317608610227
# Training Score:  -1.7612098449294702 Testing Score: -12.965208269972353
# Loss:  0.18264113503570273
# iteration 996 of 1000
#
# Mean Probability:  0.005913555840931967
# Training Score:  -1.6973992778321505 Testing Score: -12.965412987921644
# Loss:  0.33051414588482014
# iteration 997 of 1000
#
# Mean Probability:  0.006247898569578635
# Training Score:  -1.642354878982161 Testing Score: -12.965416806012286
# Loss:  0.322659617279477
# iteration 998 of 1000
#
# Mean Probability:  0.006549931222631523
# Training Score:  -1.5951074453433074 Testing Score: -12.965405002701758
# Loss:  0.31605987171696964
# iteration 999 of 1000
#
# Mean Probability:  0.006827813228502463
# Training Score:  -1.5535261211919158 Testing Score: -12.965126342999742
# Loss:  0.3108331133746083
#
# Time required for training on clustering with K = 2: 0h 2min 35sec

# %% [markdown]
# ## K = 4

# %%
# train on the clustering with K = 4 and extract the probabilities assigned by the model
start_time = time.time()
clusters_K_4_prob, test_K_4_prob = train_on_clustering(clustering_K_4, test_set, results_trainings_k_4_folder, n_iter=1000)
end_time = time.time()

elapsed_time = end_time - start_time
elapsed_hours = int(elapsed_time // (60 * 60))
elapsed_minutes = int((elapsed_time % (60 * 60)) // 60)
elapsed_seconds = int((elapsed_time % (60 * 60)) % 60)
string_time = str(elapsed_hours) + "h " + str(elapsed_minutes) + "min " + str(elapsed_seconds) + "sec"

print()
print("Time required for training on clustering with K = 2: " +  string_time)
# Out:
# Folder path already exists.
# Folder path created successfully.
# Folder path created successfully.
# Folder path created successfully.
# iteration 0 of 1000
#
# Mean Probability:  3.0211658349317e-05
# Training Score:  -11.919454283572614 Testing Score: -12.095665135869327
# Loss:  9.148786977452295
# iteration 1 of 1000
#
# Mean Probability:  5.920693991482183e-05
# Training Score:  -11.55398886093725 Testing Score: -11.70033545887358
# Loss:  5.152843293978203
# iteration 2 of 1000
#
# Mean Probability:  8.617274002529685e-05
# Training Score:  -11.306815039756343 Testing Score: -11.49908600795954
# Loss:  4.513672310443447
# iteration 3 of 1000
#
# Mean Probability:  0.00011273045062713321
# Training Score:  -11.114488107504416 Testing Score: -11.346695822235564
# Loss:  3.708421756940048
# iteration 4 of 1000
#
# Mean Probability:  0.00013704171339274708
# Training Score:  -10.975152994728901 Testing Score: -11.235607102090965
# Loss:  3.1718048425764778
# iteration 5 of 1000
#
# Mean Probability:  0.00015963887672281507
# Training Score:  -10.868734862286296 Testing Score: -11.140492768191594
# Loss:  3.018543654755382
# iteration 6 of 1000
#
# Mean Probability:  0.00018066393222748592
# Training Score:  -10.78992985111016 Testing Score: -11.040177593781328
# Loss:  2.2985269607507637
# iteration 7 of 1000
#
# Mean Probability:  0.0002004901591008763
# Training Score:  -10.689572012556901 Testing Score: -10.982864366195079
# Loss:  2.5915959589604625
# iteration 8 of 1000
#
# Mean Probability:  0.00022048428101004383
# Training Score:  -10.62410066256836 Testing Score: -10.916870998370392
# Loss:  1.949648317198797
# iteration 9 of 1000
#
# Mean Probability:  0.00023961946232994123
# Training Score:  -10.566592806627076 Testing Score: -10.859033712788271
# Loss:  1.798507933872288
# iteration 10 of 1000
#
# Mean Probability:  0.00026224348206700085
# Training Score:  -10.494756750549238 Testing Score: -10.79851546875466
# Loss:  1.913486985586344
# iteration 11 of 1000
#
# Mean Probability:  0.00027385399094079693
# Training Score:  -10.440242636472894 Testing Score: -10.78052790027387
# Loss:  1.8551187711296508
# iteration 12 of 1000
#
# Mean Probability:  0.00029498820911509323
# Training Score:  -10.396867823354114 Testing Score: -10.756110161929069
# Loss:  1.995037970748307
# iteration 13 of 1000
#
# Mean Probability:  0.0003072628108493103
# Training Score:  -10.372317264090285 Testing Score: -10.737513654854272
# Loss:  1.4014323447196688
# iteration 14 of 1000
#
# Mean Probability:  0.00031417892860482316
# Training Score:  -10.35694768351655 Testing Score: -10.719432436367168
# Loss:  1.5958119504800214
# iteration 15 of 1000
#
# Mean Probability:  0.00032031686717866597
# Training Score:  -10.333658601050226 Testing Score: -10.715063785363718
# Loss:  1.3086014465251348
# iteration 16 of 1000
#
# Mean Probability:  0.0003290307886765847
# Training Score:  -10.312055215457534 Testing Score: -10.710858578356975
# Loss:  1.3532909755154046
# iteration 17 of 1000
#
# Mean Probability:  0.00033511887335447194
# Training Score:  -10.290736348826558 Testing Score: -10.698468427520869
# Loss:  1.5347754532405828
# iteration 18 of 1000
#
# Mean Probability:  0.0003450377748841642
# Training Score:  -10.275858703723593 Testing Score: -10.694685037794258
# Loss:  1.1918439631993172
# iteration 19 of 1000
#
# Mean Probability:  0.00034982023016423027
# Training Score:  -10.255667915731864 Testing Score: -10.69345391671137
# Loss:  1.360434180922275
# iteration 20 of 1000
#
# Mean Probability:  0.0003539820985159087
# Training Score:  -10.229988186773028 Testing Score: -10.69278965555299
# Loss:  1.3881261042396134
# iteration 21 of 1000
#
# Mean Probability:  0.00036346223093333745
# Training Score:  -10.202955678042699 Testing Score: -10.684266360522575
# Loss:  1.5141477311818379
# iteration 22 of 1000
#
# Mean Probability:  0.0003774575854715557
# Training Score:  -10.197375915370442 Testing Score: -10.673627212285103
# Loss:  1.1221438149924556
# iteration 23 of 1000
#
# Mean Probability:  0.0003885978278354359
# Training Score:  -10.175116835171885 Testing Score: -10.676445237841728
# Loss:  1.303809866723321
# iteration 24 of 1000
#
# Mean Probability:  0.0003921073686745802
# Training Score:  -10.150130735781582 Testing Score: -10.661489214012214
# Loss:  1.2381461822662092
# iteration 25 of 1000
#
# Mean Probability:  0.0004004406629946793
# Training Score:  -10.132151282030353 Testing Score: -10.665646140468864
# Loss:  1.4479888065376827
# iteration 26 of 1000
#
# Mean Probability:  0.00039979389342611506
# Training Score:  -10.131847475482546 Testing Score: -10.670022433216745
# Loss:  1.3183244839972172
# iteration 27 of 1000
#
# Mean Probability:  0.00040924638422492406
# Training Score:  -10.10417183802877 Testing Score: -10.625594704798491
# Loss:  1.2323144691739192
# iteration 28 of 1000
#
# Mean Probability:  0.00041825367241904454
# Training Score:  -10.095296438713282 Testing Score: -10.633386719471739
# Loss:  1.2411994994776276
# iteration 29 of 1000
#
# Mean Probability:  0.0004422196888687392
# Training Score:  -10.088512311313844 Testing Score: -10.632437544767123
# Loss:  1.1606881831843285
# iteration 30 of 1000
#
# Mean Probability:  0.0004631173434549174
# Training Score:  -10.065628315542689 Testing Score: -10.630944972179332
# Loss:  1.286524759320779
# iteration 31 of 1000
#
# Mean Probability:  0.00047069691583873736
# Training Score:  -10.034158712307757 Testing Score: -10.63582845644213
# Loss:  1.366013969363405
# iteration 32 of 1000
#
# Mean Probability:  0.00046471737674521875
# Training Score:  -10.037731620789824 Testing Score: -10.63187633274164
# Loss:  0.9357236680109375
# iteration 33 of 1000
#
# Mean Probability:  0.00046047484472072143
# Training Score:  -10.04109050163317 Testing Score: -10.641291831545159
# Loss:  1.1104029366545647
# iteration 34 of 1000
#
# Mean Probability:  0.0004735207676199518
# Training Score:  -10.040469356164076 Testing Score: -10.649638897287675
# Loss:  1.0977222208567858
# iteration 35 of 1000
#
# Mean Probability:  0.00046727489788955253
# Training Score:  -10.049318229887955 Testing Score: -10.655188202612417
# Loss:  1.0573085938971984
# iteration 36 of 1000
#
# Mean Probability:  0.00047468507358233237
# Training Score:  -10.049924496436388 Testing Score: -10.662395608957997
# Loss:  0.9056622609394722
# iteration 37 of 1000
#
# Mean Probability:  0.000471251796290891
# Training Score:  -10.03733176142279 Testing Score: -10.668491452303691
# Loss:  1.135043074209031
# iteration 38 of 1000
#
# Mean Probability:  0.00048614078222132437
# Training Score:  -10.02970663695523 Testing Score: -10.673712690197364
# Loss:  1.196041258760483
# iteration 39 of 1000
#
# Mean Probability:  0.0005076341098373692
# Training Score:  -10.014766297296276 Testing Score: -10.676215611740911
# Loss:  1.1956010704582973
# iteration 40 of 1000
#
# Mean Probability:  0.0005179127295824532
# Training Score:  -10.012603002727209 Testing Score: -10.668322382410286
# Loss:  1.0539748252449628
# iteration 41 of 1000
#
# Mean Probability:  0.0005523082887673937
# Training Score:  -9.996530808411274 Testing Score: -10.664332000988283
# Loss:  1.0254086580628727
# iteration 42 of 1000
#
# Mean Probability:  0.0005546093077205277
# Training Score:  -10.000653796481549 Testing Score: -10.66372148665855
# Loss:  1.1303128156352371
# iteration 43 of 1000
#
# Mean Probability:  0.0005684785596379892
# Training Score:  -9.986782909304189 Testing Score: -10.659178561349822
# Loss:  1.036607044761293
# iteration 44 of 1000
#
# Mean Probability:  0.0005683959390416201
# Training Score:  -9.985065531342315 Testing Score: -10.651130542886321
# Loss:  1.0736031887775428
# iteration 45 of 1000
#
# Mean Probability:  0.0005964327882736784
# Training Score:  -9.978586249165224 Testing Score: -10.645007392615256
# Loss:  1.078049499325409
# iteration 46 of 1000
#
# Mean Probability:  0.0006065687749298213
# Training Score:  -9.962852442167412 Testing Score: -10.629134652163575
# Loss:  1.1902815595845542
# iteration 47 of 1000
#
# Mean Probability:  0.0005936666182948693
# Training Score:  -9.963394724147529 Testing Score: -10.63445218116992
# Loss:  1.0884722279738352
# iteration 48 of 1000
#
# Mean Probability:  0.0005813095213503076
# Training Score:  -9.939680451159026 Testing Score: -10.639522848080396
# Loss:  1.1774152007533454
# iteration 49 of 1000
#
# Mean Probability:  0.0005819541934618974
# Training Score:  -9.929811374510995 Testing Score: -10.63628991268879
# Loss:  1.0567990067286868
# iteration 50 of 1000
#
# Mean Probability:  0.0005873063378419145
# Training Score:  -9.928564158169733 Testing Score: -10.642199303629441
# Loss:  0.9970816913458468
# iteration 51 of 1000
#
# Mean Probability:  0.0005776470356579601
# Training Score:  -9.92501398458495 Testing Score: -10.64722332083105
# Loss:  1.1487242092107537
# iteration 52 of 1000
#
# Mean Probability:  0.0005814964588416628
# Training Score:  -9.923344955122763 Testing Score: -10.647347528175498
# Loss:  0.9510936348726462
# iteration 53 of 1000
#
# Mean Probability:  0.0005829887708765318
# Training Score:  -9.921229301734174 Testing Score: -10.64841586961431
# Loss:  0.9858968774015161
# iteration 54 of 1000
#
# Mean Probability:  0.000577595005579397
# Training Score:  -9.926396196108437 Testing Score: -10.651877481479874
# Loss:  0.9494161213846786
# iteration 55 of 1000
#
# Mean Probability:  0.0005943468182459472
# Training Score:  -9.910772109018316 Testing Score: -10.648458863495637
# Loss:  1.087117583322248
# iteration 56 of 1000
#
# Mean Probability:  0.000601001693221444
# Training Score:  -9.908978933492902 Testing Score: -10.647833257176847
# Loss:  1.058563614869836
# iteration 57 of 1000
#
# Mean Probability:  0.0005879592899492383
# Training Score:  -9.881922862743819 Testing Score: -10.64646541152074
# Loss:  1.2375283431408652
# iteration 58 of 1000
#
# Mean Probability:  0.0005843943265228594
# Training Score:  -9.888355637216959 Testing Score: -10.635600910319162
# Loss:  0.9526699023328357
# iteration 59 of 1000
#
# Mean Probability:  0.0005874648056764763
# Training Score:  -9.889507914877015 Testing Score: -10.639504605432426
# Loss:  1.3114476790378147
# iteration 60 of 1000
#
# Mean Probability:  0.0005892341856309903
# Training Score:  -9.885574498772913 Testing Score: -10.628001073109381
# Loss:  1.0193181247608893
# iteration 61 of 1000
#
# Mean Probability:  0.0006033657297683249
# Training Score:  -9.887690087926675 Testing Score: -10.626939856097449
# Loss:  0.863490770928442
# iteration 62 of 1000
#
# Mean Probability:  0.0006044132464823078
# Training Score:  -9.8891499176005 Testing Score: -10.629863806083872
# Loss:  0.9413081116533072
# iteration 63 of 1000
#
# Mean Probability:  0.0006015096402017718
# Training Score:  -9.887062052133876 Testing Score: -10.613261399856698
# Loss:  1.088418488667853
# iteration 64 of 1000
#
# Mean Probability:  0.0006022067843900087
# Training Score:  -9.882371799684238 Testing Score: -10.611420703408891
# Loss:  1.0690996215628064
# iteration 65 of 1000
#
# Mean Probability:  0.0005998611720267198
# Training Score:  -9.876654060813822 Testing Score: -10.611099159542245
# Loss:  1.0438523874915104
# iteration 66 of 1000
#
# Mean Probability:  0.0006185594856843396
# Training Score:  -9.875019684096339 Testing Score: -10.614786100162403
# Loss:  1.0276545810772202
# iteration 67 of 1000
#
# Mean Probability:  0.0006056724802601173
# Training Score:  -9.885075710470014 Testing Score: -10.617810566598164
# Loss:  0.8893943536567742
# iteration 68 of 1000
#
# Mean Probability:  0.0006030688873170017
# Training Score:  -9.887071607970094 Testing Score: -10.616946951442287
# Loss:  0.9574135816460706
# iteration 69 of 1000
#
# Mean Probability:  0.0006108817465647578
# Training Score:  -9.86341002476412 Testing Score: -10.612553389987047
# Loss:  1.2275573660680967
# iteration 70 of 1000
#
# Mean Probability:  0.0005972222072873958
# Training Score:  -9.85864237505907 Testing Score: -10.613215242953613
# Loss:  1.063331589033941
# iteration 71 of 1000
#
# Mean Probability:  0.000595256594738404
# Training Score:  -9.860214957839744 Testing Score: -10.614267939447178
# Loss:  0.8771504409664557
# iteration 72 of 1000
#
# Mean Probability:  0.0005987306659695374
# Training Score:  -9.86703709362421 Testing Score: -10.612135374954741
# Loss:  0.9741261704898877
# iteration 73 of 1000
#
# Mean Probability:  0.0006082804004877374
# Training Score:  -9.862472831137316 Testing Score: -10.61581686521079
# Loss:  0.9371183168779518
# iteration 74 of 1000
#
# Mean Probability:  0.0006050525328180878
# Training Score:  -9.870649076087012 Testing Score: -10.61530601573432
# Loss:  0.9305803165744436
# iteration 75 of 1000
#
# Mean Probability:  0.000607298207037013
# Training Score:  -9.868899103044061 Testing Score: -10.615076915882783
# Loss:  0.9110939105569893
# iteration 76 of 1000
#
# Mean Probability:  0.0005936380479820886
# Training Score:  -9.875776734957897 Testing Score: -10.590427302525436
# Loss:  0.9965634462452573
# iteration 77 of 1000
#
# Mean Probability:  0.0006026958146277809
# Training Score:  -9.88076239733183 Testing Score: -10.589190451907923
# Loss:  1.0036631102940912
# iteration 78 of 1000
#
# Mean Probability:  0.000595307050692833
# Training Score:  -9.88409487090894 Testing Score: -10.586089895354128
# Loss:  1.010341226200321
# iteration 79 of 1000
#
# Mean Probability:  0.0006009277335811263
# Training Score:  -9.87726948552783 Testing Score: -10.587012008735842
# Loss:  0.9163321288384675
# iteration 80 of 1000
#
# Mean Probability:  0.0006044536135430107
# Training Score:  -9.86495011869787 Testing Score: -10.5901257998038
# Loss:  1.2605364428232988
# iteration 81 of 1000
#
# Mean Probability:  0.0005993481965872192
# Training Score:  -9.867538321557964 Testing Score: -10.574475417661104
# Loss:  0.9403885819918895
# iteration 82 of 1000
#
# Mean Probability:  0.0006038954603211053
# Training Score:  -9.86330206710314 Testing Score: -10.579371654352082
# Loss:  0.947500118963902
# iteration 83 of 1000
#
# Mean Probability:  0.0006219876342931116
# Training Score:  -9.859460858297831 Testing Score: -10.578936039861471
# Loss:  0.9217673756263245
# iteration 84 of 1000
#
# Mean Probability:  0.0006297329253982019
# Training Score:  -9.82466429095087 Testing Score: -10.578830733902741
# Loss:  1.222999469525118
# iteration 85 of 1000
#
# Mean Probability:  0.0006237639215900419
# Training Score:  -9.826812746645375 Testing Score: -10.584847824440327
# Loss:  0.977384958557498
# iteration 86 of 1000
#
# Mean Probability:  0.0006097935639666887
# Training Score:  -9.82861322551197 Testing Score: -10.590105745896691
# Loss:  0.9880106743273563
# iteration 87 of 1000
#
# Mean Probability:  0.0005992346245462156
# Training Score:  -9.828767769512801 Testing Score: -10.590865128228483
# Loss:  1.0323595945250275
# iteration 88 of 1000
#
# Mean Probability:  0.0005907590429237617
# Training Score:  -9.835711867255329 Testing Score: -10.595600094613099
# Loss:  0.9200696283480688
# iteration 89 of 1000
#
# Mean Probability:  0.0005892046897532805
# Training Score:  -9.810142470293842 Testing Score: -10.596453625495373
# Loss:  1.1611998512686648
# iteration 90 of 1000
#
# Mean Probability:  0.0006035739538496265
# Training Score:  -9.80510664835468 Testing Score: -10.599237929545282
# Loss:  1.1835136398357315
# iteration 91 of 1000
#
# Mean Probability:  0.000603345667087432
# Training Score:  -9.803045401016524 Testing Score: -10.594781764245868
# Loss:  0.9114281867459442
# iteration 92 of 1000
#
# Mean Probability:  0.000598853315917747
# Training Score:  -9.80929443372582 Testing Score: -10.557817613578043
# Loss:  0.8399299986416746
# iteration 93 of 1000
#
# Mean Probability:  0.0005932660216384429
# Training Score:  -9.803836255121114 Testing Score: -10.554510785641504
# Loss:  1.0844775513427263
# iteration 94 of 1000
#
# Mean Probability:  0.0005844343575272338
# Training Score:  -9.810585860570686 Testing Score: -10.56047389790579
# Loss:  0.8661936338818116
# iteration 95 of 1000
#
# Mean Probability:  0.000585419080553107
# Training Score:  -9.809787355247872 Testing Score: -10.565876124490531
# Loss:  0.8658368376340689
# iteration 96 of 1000
#
# Mean Probability:  0.0005907790309623583
# Training Score:  -9.809438827279081 Testing Score: -10.545517025438674
# Loss:  1.0427609084755751
# iteration 97 of 1000
#
# Mean Probability:  0.0005845956890127859
# Training Score:  -9.810238788379761 Testing Score: -10.545966171435333
# Loss:  1.198388220351073
# iteration 98 of 1000
#
# Mean Probability:  0.0005797438799363836
# Training Score:  -9.801275491653955 Testing Score: -10.550832969936094
# Loss:  1.0587804880129168
# iteration 99 of 1000
#
# Mean Probability:  0.000621376847209128
# Training Score:  -9.794481679854016 Testing Score: -10.549422640405691
# Loss:  0.9129152329714036
# iteration 100 of 1000
#
# Mean Probability:  0.0006119747909828718
# Training Score:  -9.802907134973706 Testing Score: -10.545922698929722
# Loss:  0.9257095748025631
# iteration 101 of 1000
#
# Mean Probability:  0.0006279150115788624
# Training Score:  -9.798084482751767 Testing Score: -10.542521807841757
# Loss:  0.9120291669904809
# iteration 102 of 1000
#
# Mean Probability:  0.0006272045209111823
# Training Score:  -9.800344725926793 Testing Score: -10.531072513019442
# Loss:  0.8852690578734899
# iteration 103 of 1000
#
# Mean Probability:  0.0006152355876686582
# Training Score:  -9.808357530891078 Testing Score: -10.538339092524494
# Loss:  0.8689894059067403
# iteration 104 of 1000
#
# Mean Probability:  0.000612909445131511
# Training Score:  -9.810451357334587 Testing Score: -10.545573066482858
# Loss:  1.111332275979097
# iteration 105 of 1000
#
# Mean Probability:  0.0006054800734671895
# Training Score:  -9.810545883372404 Testing Score: -10.55329307113352
# Loss:  0.8436961878777653
# iteration 106 of 1000
#
# Mean Probability:  0.0006174985033360715
# Training Score:  -9.780781316358778 Testing Score: -10.554194056497487
# Loss:  1.1988418970901904
# iteration 107 of 1000
#
# Mean Probability:  0.000608956793263556
# Training Score:  -9.776887497047214 Testing Score: -10.556099939635283
# Loss:  1.1063607430847635
# iteration 108 of 1000
#
# Mean Probability:  0.0006273137288198019
# Training Score:  -9.773468623556143 Testing Score: -10.563904276887577
# Loss:  1.0648913921379308
# iteration 109 of 1000
#
# Mean Probability:  0.0006280217278961962
# Training Score:  -9.77325366104517 Testing Score: -10.56532079516574
# Loss:  0.9234842166630584
# iteration 110 of 1000
#
# Mean Probability:  0.0006345253023998206
# Training Score:  -9.765762176291622 Testing Score: -10.567854255722565
# Loss:  0.9402002546077234
# iteration 111 of 1000
#
# Mean Probability:  0.0006237296019671469
# Training Score:  -9.772841847898121 Testing Score: -10.574113534197435
# Loss:  0.9060888493854163
# iteration 112 of 1000
#
# Mean Probability:  0.0006497164559042508
# Training Score:  -9.758430860209112 Testing Score: -10.576475019312412
# Loss:  0.9227397411443262
# iteration 113 of 1000
#
# Mean Probability:  0.000674459684461937
# Training Score:  -9.752555638187355 Testing Score: -10.571890382813041
# Loss:  0.9363012891894475
# iteration 114 of 1000
#
# Mean Probability:  0.0006908817588975647
# Training Score:  -9.75245557330606 Testing Score: -10.577931824092632
# Loss:  0.8874815364646258
# iteration 115 of 1000
#
# Mean Probability:  0.0006766551172848943
# Training Score:  -9.756981403001005 Testing Score: -10.582095946450995
# Loss:  0.8696547461188673
# iteration 116 of 1000
#
# Mean Probability:  0.000666686685790354
# Training Score:  -9.751251956113194 Testing Score: -10.585837553096667
# Loss:  1.0348609890030587
# iteration 117 of 1000
#
# Mean Probability:  0.0006533355684514931
# Training Score:  -9.75452144103521 Testing Score: -10.59085973512892
# Loss:  1.0548234932506393
# iteration 118 of 1000
#
# Mean Probability:  0.0006571278129667303
# Training Score:  -9.752929252236955 Testing Score: -10.572285500796387
# Loss:  0.8476034211642167
# iteration 119 of 1000
#
# Mean Probability:  0.0006539956887233687
# Training Score:  -9.755516728048361 Testing Score: -10.577055817177397
# Loss:  0.8848215333185445
# iteration 120 of 1000
#
# Mean Probability:  0.0006548877822809991
# Training Score:  -9.75870068134953 Testing Score: -10.577560227395233
# Loss:  0.8343156563982936
# iteration 121 of 1000
#
# Mean Probability:  0.0006544928214770795
# Training Score:  -9.757588987904908 Testing Score: -10.581213705157559
# Loss:  1.0107825076068413
# iteration 122 of 1000
#
# Mean Probability:  0.0006423689703840647
# Training Score:  -9.757396654148856 Testing Score: -10.585455379584875
# Loss:  0.9558982195351057
# iteration 123 of 1000
#
# Mean Probability:  0.0006463000083803094
# Training Score:  -9.760307044996487 Testing Score: -10.577213218129867
# Loss:  0.9057440429809066
# iteration 124 of 1000
#
# Mean Probability:  0.000661731160623857
# Training Score:  -9.758194457416282 Testing Score: -10.573718637413267
# Loss:  0.9513268777188475
# iteration 125 of 1000
#
# Mean Probability:  0.0006694547620543823
# Training Score:  -9.706982462739736 Testing Score: -10.578919362990373
# Loss:  1.1428125803834255
# iteration 126 of 1000
#
# Mean Probability:  0.0006712525835199082
# Training Score:  -9.715572427159367 Testing Score: -10.584686356731265
# Loss:  0.9492876716058851
# iteration 127 of 1000
#
# Mean Probability:  0.0006679045914186967
# Training Score:  -9.72142241422693 Testing Score: -10.588532613726063
# Loss:  1.01101221987983
# iteration 128 of 1000
#
# Mean Probability:  0.0006931027944218647
# Training Score:  -9.720319986394498 Testing Score: -10.582386749579907
# Loss:  0.9360029660287525
# iteration 129 of 1000
#
# Mean Probability:  0.0006838783520959691
# Training Score:  -9.72986831189106 Testing Score: -10.566014184240593
# Loss:  0.8659465194281314
# iteration 130 of 1000
#
# Mean Probability:  0.0006710014038498177
# Training Score:  -9.715743768296024 Testing Score: -10.567121370189428
# Loss:  1.1294071434718904
# iteration 131 of 1000
#
# Mean Probability:  0.0006702064954712528
# Training Score:  -9.719773368941771 Testing Score: -10.566638412307839
# Loss:  0.8079578138428243
# iteration 132 of 1000
#
# Mean Probability:  0.0006771433870885291
# Training Score:  -9.71794425014813 Testing Score: -10.513076544713144
# Loss:  0.975943784970554
# iteration 133 of 1000
#
# Mean Probability:  0.0006774114340435598
# Training Score:  -9.7062288558055 Testing Score: -10.518673727363574
# Loss:  0.9482763455081337
# iteration 134 of 1000
#
# Mean Probability:  0.0007088766866965167
# Training Score:  -9.705511237690748 Testing Score: -10.526932131333545
# Loss:  0.9043335759400177
# iteration 135 of 1000
#
# Mean Probability:  0.0006989166981307232
# Training Score:  -9.702384486317069 Testing Score: -10.531319254479593
# Loss:  0.8387670864084663
# iteration 136 of 1000
#
# Mean Probability:  0.0007007528106167258
# Training Score:  -9.701970568069186 Testing Score: -10.53334520928657
# Loss:  0.8516784463029199
# iteration 137 of 1000
#
# Mean Probability:  0.0006961073303485223
# Training Score:  -9.708269187399493 Testing Score: -10.540678922827572
# Loss:  0.891620041754533
# iteration 138 of 1000
#
# Mean Probability:  0.0007055646799406656
# Training Score:  -9.714139828232275 Testing Score: -10.515408089859793
# Loss:  0.8751949953313458
# iteration 139 of 1000
#
# Mean Probability:  0.0006966948248987569
# Training Score:  -9.717546816081756 Testing Score: -10.522794768769515
# Loss:  0.8487676482592763
# iteration 140 of 1000
#
# Mean Probability:  0.0007040175011921051
# Training Score:  -9.717627982155832 Testing Score: -10.528832476466489
# Loss:  0.9142113199760565
# iteration 141 of 1000
#
# Mean Probability:  0.0007090924481933967
# Training Score:  -9.717982456716797 Testing Score: -10.528393179550292
# Loss:  1.122170847601382
# iteration 142 of 1000
#
# Mean Probability:  0.0007321601216265017
# Training Score:  -9.717370932080014 Testing Score: -10.527033226506424
# Loss:  0.8884483923534179
# iteration 143 of 1000
#
# Mean Probability:  0.0007138034707808519
# Training Score:  -9.718982001775155 Testing Score: -10.53500005505653
# Loss:  0.9772293205414594
# iteration 144 of 1000
#
# Mean Probability:  0.0007085487728396906
# Training Score:  -9.720161442584628 Testing Score: -10.53830324113171
# Loss:  0.8255711346792092
# iteration 145 of 1000
#
# Mean Probability:  0.0006966224750260393
# Training Score:  -9.715907269054057 Testing Score: -10.543689634634683
# Loss:  0.8828860217203204
# iteration 146 of 1000
#
# Mean Probability:  0.0006869832527125378
# Training Score:  -9.702248969969547 Testing Score: -10.514071290020539
# Loss:  1.0561630636345098
# iteration 147 of 1000
#
# Mean Probability:  0.0006848658508402528
# Training Score:  -9.707329512584856 Testing Score: -10.520699234497263
# Loss:  0.8474137558451195
# iteration 148 of 1000
#
# Mean Probability:  0.0006881590129029243
# Training Score:  -9.70842131796001 Testing Score: -10.52204085998257
# Loss:  0.8703831250150018
# iteration 149 of 1000
#
# Mean Probability:  0.0006962906152757139
# Training Score:  -9.71159502591211 Testing Score: -10.528020282627137
# Loss:  0.9549250978211988
# iteration 150 of 1000
#
# Mean Probability:  0.0007132179156466787
# Training Score:  -9.700981623704406 Testing Score: -10.525515058318485
# Loss:  0.8858360651002161
# iteration 151 of 1000
#
# Mean Probability:  0.0007087524919443244
# Training Score:  -9.675439534746948 Testing Score: -10.527882743399655
# Loss:  1.2928091839004758
# iteration 152 of 1000
#
# Mean Probability:  0.0007307998031574178
# Training Score:  -9.680103881266236 Testing Score: -10.524385862143284
# Loss:  0.9132401370908492
# iteration 153 of 1000
#
# Mean Probability:  0.0007190223730233281
# Training Score:  -9.68211993211844 Testing Score: -10.52774941727912
# Loss:  0.8179200461341396
# iteration 154 of 1000
#
# Mean Probability:  0.0007442624268389752
# Training Score:  -9.68244237147941 Testing Score: -10.533578901795043
# Loss:  0.9275409527611208
# iteration 155 of 1000
#
# Mean Probability:  0.0007500408900874412
# Training Score:  -9.69128185877773 Testing Score: -10.533287249835684
# Loss:  0.7700016412207132
# iteration 156 of 1000
#
# Mean Probability:  0.0007378947483706788
# Training Score:  -9.691932855117098 Testing Score: -10.534974349454584
# Loss:  0.815770268523464
# iteration 157 of 1000
#
# Mean Probability:  0.0007522645410959747
# Training Score:  -9.694471254656376 Testing Score: -10.514835117024951
# Loss:  0.8232443854301588
# iteration 158 of 1000
#
# Mean Probability:  0.0007493356374973634
# Training Score:  -9.691340663488104 Testing Score: -10.517224150658988
# Loss:  0.979256049419594
# iteration 159 of 1000
#
# Mean Probability:  0.0007401264375094767
# Training Score:  -9.69960940211066 Testing Score: -10.519053178443064
# Loss:  0.818665467943248
# iteration 160 of 1000
#
# Mean Probability:  0.0007240293012851131
# Training Score:  -9.700810638921308 Testing Score: -10.523381025562774
# Loss:  0.9482897580819042
# iteration 161 of 1000
#
# Mean Probability:  0.0007202655845307659
# Training Score:  -9.698675344742236 Testing Score: -10.527511128404244
# Loss:  1.0745992486902214
# iteration 162 of 1000
#
# Mean Probability:  0.0007287047751927459
# Training Score:  -9.685335237111644 Testing Score: -10.527606735496775
# Loss:  0.9132572566492841
# iteration 163 of 1000
#
# Mean Probability:  0.0007235353918169941
# Training Score:  -9.69089067744821 Testing Score: -10.530815194406614
# Loss:  0.8877314828877004
# iteration 164 of 1000
#
# Mean Probability:  0.0007261497841638361
# Training Score:  -9.654700010730409 Testing Score: -10.534371856980567
# Loss:  1.0887408464895945
# iteration 165 of 1000
#
# Mean Probability:  0.0007104944047406105
# Training Score:  -9.658587996230422 Testing Score: -10.538815487682994
# Loss:  0.9166482059908122
# iteration 166 of 1000
#
# Mean Probability:  0.000707606892819138
# Training Score:  -9.669674663185232 Testing Score: -10.528562487114858
# Loss:  0.8040327440838126
# iteration 167 of 1000
#
# Mean Probability:  0.000695827320694126
# Training Score:  -9.673459036013753 Testing Score: -10.534058695261885
# Loss:  0.8434716208070123
# iteration 168 of 1000
#
# Mean Probability:  0.0007182678869278574
# Training Score:  -9.671221807679117 Testing Score: -10.532796523228015
# Loss:  0.9158704785431446
# iteration 169 of 1000
#
# Mean Probability:  0.0007040687451535902
# Training Score:  -9.675964345746236 Testing Score: -10.534220365684494
# Loss:  0.8302713063561526
# iteration 170 of 1000
#
# Mean Probability:  0.0007018136064575177
# Training Score:  -9.678083811100006 Testing Score: -10.53533435752287
# Loss:  0.8408542305412577
# iteration 171 of 1000
#
# Mean Probability:  0.000709698784458693
# Training Score:  -9.682944385331211 Testing Score: -10.534083447215252
# Loss:  0.8988811880485854
# iteration 172 of 1000
#
# Mean Probability:  0.0007065575743750816
# Training Score:  -9.683695157520393 Testing Score: -10.535370718291752
# Loss:  0.943796240845543
# iteration 173 of 1000
#
# Mean Probability:  0.0006978317470720274
# Training Score:  -9.686406979601147 Testing Score: -10.53625699978866
# Loss:  0.9191717384187541
# iteration 174 of 1000
#
# Mean Probability:  0.0006877365316284145
# Training Score:  -9.690957422210014 Testing Score: -10.539932408320208
# Loss:  0.8534729690294572
# iteration 175 of 1000
#
# Mean Probability:  0.0007104797958722455
# Training Score:  -9.697542773497242 Testing Score: -10.537984611582084
# Loss:  0.7815285143435765
# iteration 176 of 1000
#
# Mean Probability:  0.0007007521146371404
# Training Score:  -9.697742559745144 Testing Score: -10.540637714271767
# Loss:  0.9196091108254327
# iteration 177 of 1000
#
# Mean Probability:  0.0007161276746599733
# Training Score:  -9.699894793141977 Testing Score: -10.540428246083918
# Loss:  0.8793037054988985
# iteration 178 of 1000
#
# Mean Probability:  0.0007140974985249026
# Training Score:  -9.665926993188076 Testing Score: -10.543585406994438
# Loss:  0.9788626600134233
# iteration 179 of 1000
#
# Mean Probability:  0.0007207837918298614
# Training Score:  -9.66724835803014 Testing Score: -10.541074292959546
# Loss:  0.8160618296156635
# iteration 180 of 1000
#
# Mean Probability:  0.0007183197868931912
# Training Score:  -9.674026922436907 Testing Score: -10.51944783372611
# Loss:  0.9149474840453289
# iteration 181 of 1000
#
# Mean Probability:  0.0007185731249708041
# Training Score:  -9.678174135547183 Testing Score: -10.521352019391259
# Loss:  0.8722086217129877
# iteration 182 of 1000
#
# Mean Probability:  0.0007154205615025759
# Training Score:  -9.677361943334063 Testing Score: -10.513433698164812
# Loss:  0.8934964516213969
# iteration 183 of 1000
#
# Mean Probability:  0.0007138327257728266
# Training Score:  -9.650321300222043 Testing Score: -10.516010075089962
# Loss:  0.952689826089265
# iteration 184 of 1000
#
# Mean Probability:  0.0007022661499594201
# Training Score:  -9.649482219469435 Testing Score: -10.508482208306935
# Loss:  0.966431586174228
# iteration 185 of 1000
#
# Mean Probability:  0.0007263894715474802
# Training Score:  -9.63408817164956 Testing Score: -10.512530998347906
# Loss:  1.0790755808913663
# iteration 186 of 1000
#
# Mean Probability:  0.0007171190948439347
# Training Score:  -9.639354890189379 Testing Score: -10.519456334626227
# Loss:  0.8134783086724263
# iteration 187 of 1000
#
# Mean Probability:  0.0007236193707812824
# Training Score:  -9.633972810572446 Testing Score: -10.51674172881165
# Loss:  1.209921190382201
# iteration 188 of 1000
#
# Mean Probability:  0.0007393221823347834
# Training Score:  -9.616334086407084 Testing Score: -10.515211414882447
# Loss:  0.9200824945201136
# iteration 189 of 1000
#
# Mean Probability:  0.0007379123009932178
# Training Score:  -9.620691317176872 Testing Score: -10.519270911920954
# Loss:  0.9633554109223067
# iteration 190 of 1000
#
# Mean Probability:  0.0007669942466767636
# Training Score:  -9.627055633634349 Testing Score: -10.52121347135128
# Loss:  0.8451882089392629
# iteration 191 of 1000
#
# Mean Probability:  0.000749123004220212
# Training Score:  -9.635831794786261 Testing Score: -10.52830047563232
# Loss:  0.7756675808745541
# iteration 192 of 1000
#
# Mean Probability:  0.0007806884298106011
# Training Score:  -9.630655499361868 Testing Score: -10.526895371017865
# Loss:  0.8707169144647725
# iteration 193 of 1000
#
# Mean Probability:  0.0007795352103439602
# Training Score:  -9.62555161231404 Testing Score: -10.529539327969776
# Loss:  0.8583203432159406
# iteration 194 of 1000
#
# Mean Probability:  0.0007688106081255006
# Training Score:  -9.616437320667613 Testing Score: -10.534429911681839
# Loss:  0.9126029801482549
# iteration 195 of 1000
#
# Mean Probability:  0.0007506935987285577
# Training Score:  -9.619450781628812 Testing Score: -10.527532280238802
# Loss:  1.0946807263345568
# iteration 196 of 1000
#
# Mean Probability:  0.0007398554980264333
# Training Score:  -9.62518747353956 Testing Score: -10.499397681352384
# Loss:  0.8211660238233653
# iteration 197 of 1000
#
# Mean Probability:  0.0007401742839902476
# Training Score:  -9.626497242534464 Testing Score: -10.506844904649153
# Loss:  0.9069667381642438
# iteration 198 of 1000
#
# Mean Probability:  0.0007464805752857539
# Training Score:  -9.637894622577823 Testing Score: -10.498117207589793
# Loss:  0.7617437048381921
# iteration 199 of 1000
#
# Mean Probability:  0.0007611177752017764
# Training Score:  -9.636096770893351 Testing Score: -10.502680461490938
# Loss:  0.8909408412544285
# iteration 200 of 1000
#
# Mean Probability:  0.0007695917706468669
# Training Score:  -9.6308881855736 Testing Score: -10.50968684146469
# Loss:  0.8969993904419998
# iteration 201 of 1000
#
# Mean Probability:  0.0007585023072805718
# Training Score:  -9.637555982400375 Testing Score: -10.516179175485625
# Loss:  0.7545447059398179
# iteration 202 of 1000
#
# Mean Probability:  0.0007436105580861919
# Training Score:  -9.609619078078827 Testing Score: -10.512871919164944
# Loss:  1.3381107234132805
# iteration 203 of 1000
#
# Mean Probability:  0.0007304436821812322
# Training Score:  -9.589823210468053 Testing Score: -10.519274782580277
# Loss:  1.185452628294092
# iteration 204 of 1000
#
# Mean Probability:  0.0007378520373403071
# Training Score:  -9.596920951385366 Testing Score: -10.524029885248368
# Loss:  0.8080986394417172
# iteration 205 of 1000
#
# Mean Probability:  0.0007354967611230479
# Training Score:  -9.601920276535663 Testing Score: -10.497954032382408
# Loss:  0.7543200480974146
# iteration 206 of 1000
#
# Mean Probability:  0.0007223391185614301
# Training Score:  -9.610632776368314 Testing Score: -10.504309661548012
# Loss:  0.7327939656805063
# iteration 207 of 1000
#
# Mean Probability:  0.0007242129463903836
# Training Score:  -9.616471311171514 Testing Score: -10.500617461116562
# Loss:  0.8767930714135728
# iteration 208 of 1000
#
# Mean Probability:  0.0007366584720755136
# Training Score:  -9.621026659621322 Testing Score: -10.500463999229545
# Loss:  0.8420065254231514
# iteration 209 of 1000
#
# Mean Probability:  0.0007241085682480284
# Training Score:  -9.620261232489613 Testing Score: -10.505410599347314
# Loss:  0.783550143271519
# iteration 210 of 1000
#
# Mean Probability:  0.000716839986598529
# Training Score:  -9.618172203132602 Testing Score: -10.48428597108275
# Loss:  0.8181579764976703
# iteration 211 of 1000
#
# Mean Probability:  0.0007041674401973112
# Training Score:  -9.62020476088658 Testing Score: -10.48704798468792
# Loss:  0.9294297536687587
# iteration 212 of 1000
#
# Mean Probability:  0.0006948877357582402
# Training Score:  -9.62237673373681 Testing Score: -10.489702724520379
# Loss:  0.8429236766798831
# iteration 213 of 1000
#
# Mean Probability:  0.0007065225595949141
# Training Score:  -9.622799242838383 Testing Score: -10.494922300519844
# Loss:  0.8272614999216598
# iteration 214 of 1000
#
# Mean Probability:  0.0007021827495712226
# Training Score:  -9.625588739771727 Testing Score: -10.499378892244856
# Loss:  0.8203535774220183
# iteration 215 of 1000
#
# Mean Probability:  0.0006944684371916663
# Training Score:  -9.619465869521472 Testing Score: -10.49471459958351
# Loss:  0.838328917920429
# iteration 216 of 1000
#
# Mean Probability:  0.0006914359147865574
# Training Score:  -9.61455156674848 Testing Score: -10.479583784329542
# Loss:  1.0962839842476741
# iteration 217 of 1000
#
# Mean Probability:  0.0006908948777100411
# Training Score:  -9.61523340375016 Testing Score: -10.479033221558234
# Loss:  0.8926284330202451
# iteration 218 of 1000
#
# Mean Probability:  0.0006883473599610929
# Training Score:  -9.610649426028184 Testing Score: -10.484653061432992
# Loss:  0.9209706697184302
# iteration 219 of 1000
#
# Mean Probability:  0.0007043153569304011
# Training Score:  -9.609612075481857 Testing Score: -10.4847245940734
# Loss:  0.8243098563873584
# iteration 220 of 1000
#
# Mean Probability:  0.0006954423345338726
# Training Score:  -9.609821957920255 Testing Score: -10.486044054879319
# Loss:  0.925136035371592
# iteration 221 of 1000
#
# Mean Probability:  0.0007073742283939943
# Training Score:  -9.605298091249603 Testing Score: -10.488351600014802
# Loss:  0.9155667400715306
# iteration 222 of 1000
#
# Mean Probability:  0.000717126805191996
# Training Score:  -9.60581527768511 Testing Score: -10.49487791808554
# Loss:  0.8381347137067059
# iteration 223 of 1000
#
# Mean Probability:  0.0007330904568551256
# Training Score:  -9.605507969201279 Testing Score: -10.499989724316672
# Loss:  0.9415908818869941
# iteration 224 of 1000
#
# Mean Probability:  0.0007421975030383164
# Training Score:  -9.580031097210812 Testing Score: -10.5055737757871
# Loss:  0.9266435902811085
# iteration 225 of 1000
#
# Mean Probability:  0.0007468969207266526
# Training Score:  -9.582614622251139 Testing Score: -10.506279182043215
# Loss:  0.8125138002244338
# iteration 226 of 1000
#
# Mean Probability:  0.0007386105165714662
# Training Score:  -9.548320666354973 Testing Score: -10.508490872566433
# Loss:  1.0848679127218666
# iteration 227 of 1000
#
# Mean Probability:  0.0007307780017928643
# Training Score:  -9.528225952305542 Testing Score: -10.513239677292383
# Loss:  0.9375733791023236
# iteration 228 of 1000
#
# Mean Probability:  0.0007176314654897672
# Training Score:  -9.531492258174714 Testing Score: -10.516089927435452
# Loss:  0.9004188576213291
# iteration 229 of 1000
#
# Mean Probability:  0.0007054868676524741
# Training Score:  -9.544287196461012 Testing Score: -10.520545063804107
# Loss:  0.7592723004157808
# iteration 230 of 1000
#
# Mean Probability:  0.0007035617054460242
# Training Score:  -9.517542077263384 Testing Score: -10.524109550494808
# Loss:  1.330395165242735
# iteration 231 of 1000
#
# Mean Probability:  0.0006947423305431928
# Training Score:  -9.52359037154262 Testing Score: -10.528876330532928
# Loss:  0.7537908935371428
# iteration 232 of 1000
#
# Mean Probability:  0.0007242589226687678
# Training Score:  -9.528485146389945 Testing Score: -10.50166021716034
# Loss:  0.8387510015947265
# iteration 233 of 1000
#
# Mean Probability:  0.0007185956857838588
# Training Score:  -9.533699515803418 Testing Score: -10.489129777663784
# Loss:  0.7566114880024927
# iteration 234 of 1000
#
# Mean Probability:  0.0007234526998304676
# Training Score:  -9.538441927469478 Testing Score: -10.493960812423845
# Loss:  0.8734055187587474
# iteration 235 of 1000
#
# Mean Probability:  0.0007443481326708518
# Training Score:  -9.51501273505817 Testing Score: -10.491385518924996
# Loss:  1.039210841575597
# iteration 236 of 1000
#
# Mean Probability:  0.0007696424223923608
# Training Score:  -9.48636951617023 Testing Score: -10.494791519452683
# Loss:  1.155182531317769
# iteration 237 of 1000
#
# Mean Probability:  0.0007726889072835139
# Training Score:  -9.494237588654494 Testing Score: -10.48691708092516
# Loss:  0.812691591267838
# iteration 238 of 1000
#
# Mean Probability:  0.0007883354968640258
# Training Score:  -9.456989124238007 Testing Score: -10.493940802551906
# Loss:  0.9446489990768123
# iteration 239 of 1000
#
# Mean Probability:  0.0008090501446028583
# Training Score:  -9.467187453084382 Testing Score: -10.492611844471154
# Loss:  0.7555386447136465
# iteration 240 of 1000
#
# Mean Probability:  0.0008049322426785252
# Training Score:  -9.47923605492211 Testing Score: -10.496546495186516
# Loss:  0.7665388177190268
# iteration 241 of 1000
#
# Mean Probability:  0.000791490246995808
# Training Score:  -9.48489974755401 Testing Score: -10.496602002684794
# Loss:  0.8988625971592231
# iteration 242 of 1000
#
# Mean Probability:  0.0007928982146737094
# Training Score:  -9.480208139705896 Testing Score: -10.500982576273785
# Loss:  0.9080323412574218
# iteration 243 of 1000
#
# Mean Probability:  0.0007903565360242848
# Training Score:  -9.493829118010009 Testing Score: -10.477153908624803
# Loss:  0.6940961560723162
# iteration 244 of 1000
#
# Mean Probability:  0.0008032211852868552
# Training Score:  -9.489912141647357 Testing Score: -10.482239596555644
# Loss:  0.9371454759473027
# iteration 245 of 1000
#
# Mean Probability:  0.000806057077185696
# Training Score:  -9.495671454132546 Testing Score: -10.473134868734364
# Loss:  0.7841196824363583
# iteration 246 of 1000
#
# Mean Probability:  0.0008437443829817798
# Training Score:  -9.484068234546596 Testing Score: -10.4727040927777
# Loss:  0.9494744800822774
# iteration 247 of 1000
#
# Mean Probability:  0.0008338174587911114
# Training Score:  -9.461585635541129 Testing Score: -10.4752058690179
# Loss:  1.0294506658133615
# iteration 248 of 1000
#
# Mean Probability:  0.0008265834006859318
# Training Score:  -9.470800020149904 Testing Score: -10.475000745700285
# Loss:  0.9773367784739927
# iteration 249 of 1000
#
# Mean Probability:  0.0008366664259735867
# Training Score:  -9.477672474586909 Testing Score: -10.476509309086978
# Loss:  0.7858580882396863
# iteration 250 of 1000
#
# Mean Probability:  0.0008210079290669216
# Training Score:  -9.46450276087502 Testing Score: -10.481830519621198
# Loss:  0.845866878771637
# iteration 251 of 1000
#
# Mean Probability:  0.0008078199190460357
# Training Score:  -9.46959420076693 Testing Score: -10.484722273073903
# Loss:  0.8449790673867347
# iteration 252 of 1000
#
# Mean Probability:  0.0008097518387940376
# Training Score:  -9.47840113971932 Testing Score: -10.490162295907195
# Loss:  0.8360237568130116
# iteration 253 of 1000
#
# Mean Probability:  0.0008295787426406604
# Training Score:  -9.472309936449845 Testing Score: -10.488616639187628
# Loss:  0.8828821511287738
# iteration 254 of 1000
#
# Mean Probability:  0.0008092030324932768
# Training Score:  -9.47554363981243 Testing Score: -10.491682986531536
# Loss:  0.8357117758830297
# iteration 255 of 1000
#
# Mean Probability:  0.0008238417162425912
# Training Score:  -9.466549452377874 Testing Score: -10.491189117979113
# Loss:  0.9313422558315793
# iteration 256 of 1000
#
# Mean Probability:  0.0008322170313024101
# Training Score:  -9.47202066591781 Testing Score: -10.49366336601026
# Loss:  0.8953416161072933
# iteration 257 of 1000
#
# Mean Probability:  0.0008295521480477491
# Training Score:  -9.453702491203224 Testing Score: -10.498864671385093
# Loss:  0.8456291780840494
# iteration 258 of 1000
#
# Mean Probability:  0.0008159964814671158
# Training Score:  -9.456776726235418 Testing Score: -10.504010993682646
# Loss:  0.9218404873129027
# iteration 259 of 1000
#
# Mean Probability:  0.0007975507150395796
# Training Score:  -9.451323272266352 Testing Score: -10.509017702909885
# Loss:  0.9557795747331131
# iteration 260 of 1000
#
# Mean Probability:  0.0007976252841538464
# Training Score:  -9.447271510320796 Testing Score: -10.506274257195653
# Loss:  0.7975191320440222
# iteration 261 of 1000
#
# Mean Probability:  0.0007785443849589595
# Training Score:  -9.462334165824098 Testing Score: -10.51094520017489
# Loss:  0.7248706634984429
# iteration 262 of 1000
#
# Mean Probability:  0.0007997334121698611
# Training Score:  -9.460692422545208 Testing Score: -10.511564751959408
# Loss:  0.7990813534484782
# iteration 263 of 1000
#
# Mean Probability:  0.0007801380746640896
# Training Score:  -9.472494945804367 Testing Score: -10.515264794713502
# Loss:  0.8411633871939167
# iteration 264 of 1000
#
# Mean Probability:  0.0008095680445651691
# Training Score:  -9.473036317761363 Testing Score: -10.493073378482483
# Loss:  0.988961956385439
# iteration 265 of 1000
#
# Mean Probability:  0.0008161507249579159
# Training Score:  -9.482008977704323 Testing Score: -10.495996689864121
# Loss:  0.8278722488809116
# iteration 266 of 1000
#
# Mean Probability:  0.0008327075515590978
# Training Score:  -9.477411882434978 Testing Score: -10.488785322828303
# Loss:  0.906518485298631
# iteration 267 of 1000
#
# Mean Probability:  0.0008406085584618324
# Training Score:  -9.480549404938529 Testing Score: -10.494956508389699
# Loss:  0.7794049983690513
# iteration 268 of 1000
#
# Mean Probability:  0.0008350367987085463
# Training Score:  -9.480225630617163 Testing Score: -10.497164700454091
# Loss:  0.8453711174591604
# iteration 269 of 1000
#
# Mean Probability:  0.0008131512020261955
# Training Score:  -9.487629568835034 Testing Score: -10.502170316985369
# Loss:  0.77484035051061
# iteration 270 of 1000
#
# Mean Probability:  0.0008128185860664671
# Training Score:  -9.500565469054411 Testing Score: -10.498666310982168
# Loss:  0.8572813270089444
# iteration 271 of 1000
#
# Mean Probability:  0.0008136243598095719
# Training Score:  -9.497502979317614 Testing Score: -10.490906469441876
# Loss:  0.8317689023690662
# iteration 272 of 1000
#
# Mean Probability:  0.000796004184374534
# Training Score:  -9.503994404066042 Testing Score: -10.472049021456966
# Loss:  0.7507250050677908
# iteration 273 of 1000
#
# Mean Probability:  0.0007887968307293197
# Training Score:  -9.498449551888372 Testing Score: -10.477258805630884
# Loss:  0.8907437890421556
# iteration 274 of 1000
#
# Mean Probability:  0.0008044306569974308
# Training Score:  -9.5005362202523 Testing Score: -10.466034889038756
# Loss:  1.0607048423902061
# iteration 275 of 1000
#
# Mean Probability:  0.0008135108521189679
# Training Score:  -9.497825859766946 Testing Score: -10.471623016159505
# Loss:  0.8693048584904096
# iteration 276 of 1000
#
# Mean Probability:  0.0008475178645988762
# Training Score:  -9.495808526605385 Testing Score: -10.477968620880791
# Loss:  0.9815434931238736
# iteration 277 of 1000
#
# Mean Probability:  0.0008524264189721532
# Training Score:  -9.483073202249942 Testing Score: -10.480958587176394
# Loss:  0.894195735313299
# iteration 278 of 1000
#
# Mean Probability:  0.0008448262845335666
# Training Score:  -9.47353593247803 Testing Score: -10.466926142911486
# Loss:  0.9122929125222591
# iteration 279 of 1000
#
# Mean Probability:  0.0008922392846710416
# Training Score:  -9.44623047379979 Testing Score: -10.469327231713464
# Loss:  0.9311805175509087
# iteration 280 of 1000
#
# Mean Probability:  0.0008776653374324491
# Training Score:  -9.452200461795817 Testing Score: -10.47324814834381
# Loss:  0.9457696078218926
# iteration 281 of 1000
#
# Mean Probability:  0.0008504315752301876
# Training Score:  -9.469053507042458 Testing Score: -10.480131511399097
# Loss:  0.6947065521870314
# iteration 282 of 1000
#
# Mean Probability:  0.0008276764105569512
# Training Score:  -9.480008604404594 Testing Score: -10.485491769567759
# Loss:  0.7682874446886931
# iteration 283 of 1000
#
# Mean Probability:  0.0008254170188285344
# Training Score:  -9.490020798886384 Testing Score: -10.485043984106571
# Loss:  0.7855813420046154
# iteration 284 of 1000
#
# Mean Probability:  0.000806393597453639
# Training Score:  -9.489073128831153 Testing Score: -10.48961567040227
# Loss:  1.030138618119661
# iteration 285 of 1000
#
# Mean Probability:  0.0007864722776820564
# Training Score:  -9.494876743412659 Testing Score: -10.493709636425674
# Loss:  0.8185150540506573
# iteration 286 of 1000
#
# Mean Probability:  0.0007741644911470356
# Training Score:  -9.444710897558808 Testing Score: -10.496820679126763
# Loss:  1.0724624727035441
# iteration 287 of 1000
#
# Mean Probability:  0.0007857761788858388
# Training Score:  -9.4545881655255 Testing Score: -10.499322653457595
# Loss:  0.7884964489531662
# iteration 288 of 1000
#
# Mean Probability:  0.0007678542580625459
# Training Score:  -9.468833148636822 Testing Score: -10.504061804478146
# Loss:  0.7583331553337453
# iteration 289 of 1000
#
# Mean Probability:  0.0007531621576862012
# Training Score:  -9.474585078569687 Testing Score: -10.508147365871446
# Loss:  0.7841452037419331
# iteration 290 of 1000
#
# Mean Probability:  0.0007899734041371294
# Training Score:  -9.478859193915797 Testing Score: -10.511539296483063
# Loss:  0.7271969010190754
# iteration 291 of 1000
#
# Mean Probability:  0.0007788012267934462
# Training Score:  -9.487122092969912 Testing Score: -10.49577929240592
# Loss:  0.851758688851171
# iteration 292 of 1000
#
# Mean Probability:  0.0007631581882665849
# Training Score:  -9.490188275279385 Testing Score: -10.493816424464903
# Loss:  0.9800482380916661
# iteration 293 of 1000
#
# Mean Probability:  0.0007624097662577989
# Training Score:  -9.487279662460226 Testing Score: -10.492302090480418
# Loss:  0.8374002878239899
# iteration 294 of 1000
#
# Mean Probability:  0.0007506219365376381
# Training Score:  -9.48713622018358 Testing Score: -10.495964224488285
# Loss:  0.889079443181428
# iteration 295 of 1000
#
# Mean Probability:  0.0007571137166910123
# Training Score:  -9.489250752919292 Testing Score: -10.487012420636816
# Loss:  0.7865674022281149
# iteration 296 of 1000
#
# Mean Probability:  0.0007658468409191077
# Training Score:  -9.486055296309294 Testing Score: -10.486560059500516
# Loss:  0.9436201253456544
# iteration 297 of 1000
#
# Mean Probability:  0.0007534629062779909
# Training Score:  -9.490294351309446 Testing Score: -10.490423770682016
# Loss:  0.7749156745179057
# iteration 298 of 1000
#
# Mean Probability:  0.0007580393184412436
# Training Score:  -9.492667289336493 Testing Score: -10.485472228557535
# ...
# iteration 901 of 1000
#
# Mean Probability:  0.00876445211714894
# Training Score:  -1.3034296570570332 Testing Score: -13.129944335499935
# Loss:  0.2245066047293402
# iteration 902 of 1000
#
# Mean Probability:  0.00839587629796799
# Training Score:  -1.346409311652973 Testing Score: -13.130056973437256
# Loss:  0.22647520488572687
# iteration 903 of 1000
#
# Mean Probability:  0.008065703332434074
# Training Score:  -1.3865449273390769 Testing Score: -13.130137741133174
# Loss:  0.22901146589947372
# iteration 904 of 1000
#
# Mean Probability:  0.007772778313886084
# Training Score:  -1.4235535731742404 Testing Score: -13.130133989849096
# Loss:  0.23114603927556593
# iteration 905 of 1000
#
# Mean Probability:  0.007517237890657692
# Training Score:  -1.456996869404546 Testing Score: -13.130026802680959
# Loss:  0.23422853826906537
# iteration 906 of 1000
#
# Mean Probability:  0.007293857129409511
# Training Score:  -1.487176864885671 Testing Score: -13.129853983869173
# Loss:  0.23631501102627092
# iteration 907 of 1000
#
# Mean Probability:  0.007095787892996599
# Training Score:  -1.514720838616789 Testing Score: -13.129544770348012
# Loss:  0.23852203255322701
# iteration 908 of 1000
#
# Mean Probability:  0.006923049625786937
# Training Score:  -1.53937806794674 Testing Score: -13.127902411375294
# Loss:  0.24017329752007893
# iteration 909 of 1000
#
# Mean Probability:  0.006772824730857061
# Training Score:  -1.561327092023215 Testing Score: -13.127786706891568
# Loss:  0.24241899394520977
# iteration 910 of 1000
#
# Mean Probability:  0.0066406304222964615
# Training Score:  -1.5810487661795147 Testing Score: -13.127494454266888
# Loss:  0.24324689409063976
# iteration 911 of 1000
#
# Mean Probability:  0.007509912969812556
# Training Score:  -1.457975889553263 Testing Score: -13.127215244464539
# Loss:  0.3715868923865724
# iteration 912 of 1000
#
# Mean Probability:  0.008287175380713451
# Training Score:  -1.3594507644542193 Testing Score: -13.126712225211259
# Loss:  0.35076284092792553
# iteration 913 of 1000
#
# Mean Probability:  0.00800669866223668
# Training Score:  -1.3938958767098613 Testing Score: -13.126304625294933
# Loss:  0.2308974044500277
# iteration 914 of 1000
#
# Mean Probability:  0.00874252996526187
# Training Score:  -1.3059413353806035 Testing Score: -13.125873743171041
# Loss:  0.34189612528248503
# iteration 915 of 1000
#
# Mean Probability:  0.008422241155629805
# Training Score:  -1.3432798042147989 Testing Score: -13.125437391845061
# Loss:  0.228286699490454
# iteration 916 of 1000
#
# Mean Probability:  0.009124165643697259
# Training Score:  -1.2632001008506315 Testing Score: -13.124956700758688
# Loss:  0.33455463340597813
# iteration 917 of 1000
#
# Mean Probability:  0.00975360203505193
# Training Score:  -1.196467323848838 Testing Score: -13.124498419581537
# Loss:  0.32338787742624264
# iteration 918 of 1000
#
# Mean Probability:  0.010323792054445316
# Training Score:  -1.139634763687373 Testing Score: -13.124046976713192
# Loss:  0.3146877387368301
# iteration 919 of 1000
#
# Mean Probability:  0.01083309337766573
# Training Score:  -1.0914658999549707 Testing Score: -13.123474888734622
# Loss:  0.30723719441561315
# iteration 920 of 1000
#
# Mean Probability:  0.010309328832220545
# Training Score:  -1.1410382604078744 Testing Score: -13.12300075928414
# Loss:  0.21694203851405722
# iteration 921 of 1000
#
# Mean Probability:  0.00984570092838619
# Training Score:  -1.1870681916401842 Testing Score: -13.12250571799588
# Loss:  0.21974649696188087
# iteration 922 of 1000
#
# Mean Probability:  0.009430818111375206
# Training Score:  -1.2301355192157732 Testing Score: -13.122031428959485
# Loss:  0.22159928890139052
# iteration 923 of 1000
#
# Mean Probability:  0.009059619809361694
# Training Score:  -1.2703062074903104 Testing Score: -13.121574480411448
# Loss:  0.22377074482917467
# iteration 924 of 1000
#
# Mean Probability:  0.0087333049146198
# Training Score:  -1.3070037291738998 Testing Score: -13.121113172606972
# Loss:  0.22617380106221094
# iteration 925 of 1000
#
# Mean Probability:  0.009440128010973084
# Training Score:  -1.2291503450442045 Testing Score: -13.120514166298113
# Loss:  0.3304262836956635
# iteration 926 of 1000
#
# Mean Probability:  0.009074770888982642
# Training Score:  -1.2686364055645853 Testing Score: -13.12006943680499
# Loss:  0.22353630373029298
# iteration 927 of 1000
#
# Mean Probability:  0.00974896120896478
# Training Score:  -1.1969491673229526 Testing Score: -13.119449116265043
# Loss:  0.3250227563746222
# iteration 928 of 1000
#
# Mean Probability:  0.009357867055854015
# Training Score:  -1.2379073566434073 Testing Score: -13.118719561899434
# Loss:  0.22191323676668567
# iteration 929 of 1000
#
# Mean Probability:  0.010022177839349942
# Training Score:  -1.1693013067771274 Testing Score: -13.11808282110784
# Loss:  0.32206648137452554
# iteration 930 of 1000
#
# Mean Probability:  0.011284655791377505
# Training Score:  -1.0506209133351552 Testing Score: -13.1175714494059
# Loss:  0.5292353298476749
# iteration 931 of 1000
#
# Mean Probability:  0.010725284788757517
# Training Score:  -1.1014753169167644 Testing Score: -13.119017972630797
# Loss:  0.2158269717349267
# iteration 932 of 1000
#
# Mean Probability:  0.01023197477169472
# Training Score:  -1.1485759641075648 Testing Score: -13.120114625841488
# Loss:  0.2175097239740248
# iteration 933 of 1000
#
# Mean Probability:  0.009803850594865467
# Training Score:  -1.191332038943445 Testing Score: -13.12077626948527
# Loss:  0.2203567657378374
# iteration 934 of 1000
#
# Mean Probability:  0.009421811080244506
# Training Score:  -1.2310932990163856 Testing Score: -13.120828125879916
# Loss:  0.2219812408520268
# iteration 935 of 1000
#
# Mean Probability:  0.010074757658685481
# Training Score:  -1.1640644370907904 Testing Score: -13.121213308588581
# Loss:  0.32022825845479286
# iteration 936 of 1000
#
# Mean Probability:  0.009666580407195296
# Training Score:  -1.2054365911077671 Testing Score: -13.121406524975178
# Loss:  0.22012468991245931
# iteration 937 of 1000
#
# Mean Probability:  0.010307026068433756
# Training Score:  -1.1412639741628912 Testing Score: -13.121542621648482
# Loss:  0.3172371801368872
# iteration 938 of 1000
#
# Mean Probability:  0.010883524808276897
# Training Score:  -1.086822542244016 Testing Score: -13.12166019174985
# Loss:  0.3083551561951623
# iteration 939 of 1000
#
# Mean Probability:  0.010400739880334894
# Training Score:  -1.1322099444889449 Testing Score: -13.12168784994116
# Loss:  0.21655264055422274
# iteration 940 of 1000
#
# Mean Probability:  0.010976306191767654
# Training Score:  -1.0783313794536495 Testing Score: -13.12038832699045
# Loss:  0.3075140277409347
# iteration 941 of 1000
#
# Mean Probability:  0.011489069127976464
# Training Score:  -1.032660903924627 Testing Score: -13.120361456884453
# Loss:  0.3002884001471333
# iteration 942 of 1000
#
# Mean Probability:  0.01095208591566577
# Training Score:  -1.080541362330129 Testing Score: -13.120244963573239
# Loss:  0.21364139111907615
# iteration 943 of 1000
#
# Mean Probability:  0.010480785799936483
# Training Score:  -1.1245415442516364 Testing Score: -13.120034185931695
# Loss:  0.21644093095431421
# iteration 944 of 1000
#
# Mean Probability:  0.010058467231161543
# Training Score:  -1.165684093781399 Testing Score: -13.119669286420885
# Loss:  0.21791327343439965
# iteration 945 of 1000
#
# Mean Probability:  0.009680707309864832
# Training Score:  -1.203977303606311 Testing Score: -13.1192838837314
# Loss:  0.22017913242956594
# iteration 946 of 1000
#
# Mean Probability:  0.00934850570813676
# Training Score:  -1.2389084634003036 Testing Score: -13.118897618445965
# Loss:  0.2219144675531215
# iteration 947 of 1000
#
# Mean Probability:  0.009055851789501326
# Training Score:  -1.2707259628657521 Testing Score: -13.1184067433576
# Loss:  0.22425712733291378
# iteration 948 of 1000
#
# Mean Probability:  0.009825072447666294
# Training Score:  -1.1891714038280665 Testing Score: -13.11767335864121
# Loss:  0.3274872525812764
# iteration 949 of 1000
#
# Mean Probability:  0.010512415791295623
# Training Score:  -1.1215300989371702 Testing Score: -13.117201749599197
# Loss:  0.31616030500461
# iteration 950 of 1000
#
# Mean Probability:  0.011127032348308212
# Training Score:  -1.0646926664052723 Testing Score: -13.116593688967619
# Loss:  0.30646805511569974
# iteration 951 of 1000
#
# Mean Probability:  0.010660920671807912
# Training Score:  -1.1074990345311029 Testing Score: -13.114914879957889
# Loss:  0.2150035120407292
# iteration 952 of 1000
#
# Mean Probability:  0.010243521267664634
# Training Score:  -1.1474519430937102 Testing Score: -13.114405848139903
# Loss:  0.21605112716856378
# iteration 953 of 1000
#
# Mean Probability:  0.009870662367642256
# Training Score:  -1.1845434984266978 Testing Score: -13.11296844225081
# Loss:  0.21827282368581194
# iteration 954 of 1000
#
# Mean Probability:  0.009542041618873866
# Training Score:  -1.2184155516347546 Testing Score: -13.112504473398724
# Loss:  0.21977196239016872
# iteration 955 of 1000
#
# Mean Probability:  0.009258091560606906
# Training Score:  -1.2486365971537474 Testing Score: -13.112166805406126
# Loss:  0.22261967120015494
# iteration 956 of 1000
#
# Mean Probability:  0.010672151958102153
# Training Score:  -1.1064491501046303 Testing Score: -13.110338968452107
# Loss:  0.550504017820705
# iteration 957 of 1000
#
# Mean Probability:  0.011225076170234596
# Training Score:  -1.0559198984849618 Testing Score: -13.112113607230478
# Loss:  0.30252272141056835
# iteration 958 of 1000
#
# Mean Probability:  0.010747072337636204
# Training Score:  -1.0994495757337652 Testing Score: -13.113306343656186
# Loss:  0.21334185717662768
# iteration 959 of 1000
#
# Mean Probability:  0.010328234002457219
# Training Score:  -1.1392137406918739 Testing Score: -13.114377555426906
# Loss:  0.2156782165124208
# iteration 960 of 1000
#
# Mean Probability:  0.00995923554371766
# Training Score:  -1.175606559126869 Testing Score: -13.115064836939228
# Loss:  0.21691067133358177
# iteration 961 of 1000
#
# Mean Probability:  0.009633300202411177
# Training Score:  -1.2088920636172686 Testing Score: -13.115571917208435
# Loss:  0.2190835317850679
# iteration 962 of 1000
#
# Mean Probability:  0.010378744036232755
# Training Score:  -1.1343328887706305 Testing Score: -13.11577976700863
# Loss:  0.3180394399604167
# iteration 963 of 1000
#
# Mean Probability:  0.010016668683004177
# Training Score:  -1.1698537492813066 Testing Score: -13.116012337032739
# Loss:  0.2169927042210309
# iteration 964 of 1000
#
# Mean Probability:  0.01073937054553323
# Training Score:  -1.1001653948837173 Testing Score: -13.115986071919037
# Loss:  0.3135199880352397
# iteration 965 of 1000
#
# Mean Probability:  0.010344876736971922
# Training Score:  -1.1376023683812517 Testing Score: -13.116189906846742
# Loss:  0.21521905167852481
# iteration 966 of 1000
#
# Mean Probability:  0.011041977126781346
# Training Score:  -1.0723693975213753 Testing Score: -13.115959235458513
# Loss:  0.3094844446663023
# iteration 967 of 1000
#
# Mean Probability:  0.010622733331731173
# Training Score:  -1.1110893099011443 Testing Score: -13.115870323588718
# Loss:  0.21395510444099414
# iteration 968 of 1000
#
# Mean Probability:  0.010255288035523684
# Training Score:  -1.1463040274788445 Testing Score: -13.115489162707691
# Loss:  0.215382972371363
# iteration 969 of 1000
#
# Mean Probability:  0.009932702496172152
# Training Score:  -1.1782760194342563 Testing Score: -13.115080975049874
# Loss:  0.21813310725923013
# iteration 970 of 1000
#
# Mean Probability:  0.010716655242668752
# Training Score:  -1.1022852433764374 Testing Score: -13.114501372736179
# Loss:  0.3174300588081005
# iteration 971 of 1000
#
# Mean Probability:  0.011409629361877009
# Training Score:  -1.0396077849318193 Testing Score: -13.11416013134076
# Loss:  0.3069059347148566
# iteration 972 of 1000
#
# Mean Probability:  0.012024468063062106
# Training Score:  -0.9871071500892262 Testing Score: -13.113557746129962
# Loss:  0.29814340528293926
# iteration 973 of 1000
#
# Mean Probability:  0.011523976957962943
# Training Score:  -1.029633469549609 Testing Score: -13.113317026686511
# Loss:  0.2103704857898463
# iteration 974 of 1000
#
# Mean Probability:  0.011081841675872483
# Training Score:  -1.0687677881111401 Testing Score: -13.112691068547385
# Loss:  0.21185997026182252
# iteration 975 of 1000
#
# Mean Probability:  0.010690042724159531
# Training Score:  -1.10477464925364 Testing Score: -13.11213640658548
# Loss:  0.21452851180073335
# iteration 976 of 1000
#
# Mean Probability:  0.010344059410334712
# Training Score:  -1.137686475899587 Testing Score: -13.111457050900624
# Loss:  0.21576637208789526
# iteration 977 of 1000
#
# Mean Probability:  0.011723422151256801
# Training Score:  -1.0124717476259881 Testing Score: -13.109697295828894
# Loss:  0.520535406826454
# iteration 978 of 1000
#
# Mean Probability:  0.011239112906761753
# Training Score:  -1.0546724345447063 Testing Score: -13.110934494303995
# Loss:  0.2123473544631096
# iteration 979 of 1000
#
# Mean Probability:  0.011846178478271512
# Training Score:  -1.0020508119884435 Testing Score: -13.111904003932475
# Loss:  0.2996254691650071
# iteration 980 of 1000
#
# Mean Probability:  0.011374250978330122
# Training Score:  -1.042715735731205 Testing Score: -13.112526044187346
# Loss:  0.21111288197305741
# iteration 981 of 1000
#
# Mean Probability:  0.010961026852024118
# Training Score:  -1.0797330052355774 Testing Score: -13.11301610749046
# Loss:  0.21390127782402207
# iteration 982 of 1000
#
# Mean Probability:  0.011659957726277774
# Training Score:  -1.0178997845160915 Testing Score: -13.113215344429323
# Loss:  0.304819240535009
# iteration 983 of 1000
#
# Mean Probability:  0.012276361553074759
# Training Score:  -0.9663700795296337 Testing Score: -13.112303318567028
# Loss:  0.2969983869986361
# iteration 984 of 1000
#
# Mean Probability:  0.01177373996079063
# Training Score:  -1.0081859479828235 Testing Score: -13.112505357742364
# Loss:  0.20948802872075883
# iteration 985 of 1000
#
# Mean Probability:  0.011334611722833898
# Training Score:  -1.0462079665319124 Testing Score: -13.112470927752357
# Loss:  0.2123150959215221
# iteration 986 of 1000
#
# Mean Probability:  0.012021915663168915
# Training Score:  -0.9873208302359611 Testing Score: -13.112239837888756
# Loss:  0.3019433870601027
# iteration 987 of 1000
#
# Mean Probability:  0.01155758131227755
# Training Score:  -1.0267222402466631 Testing Score: -13.112024537736385
# Loss:  0.21120518605446154
# iteration 988 of 1000
#
# Mean Probability:  0.011151364865606942
# Training Score:  -1.062513112915324 Testing Score: -13.111747858185074
# Loss:  0.21270168177062862
# iteration 989 of 1000
#
# Mean Probability:  0.01187967589350734
# Training Score:  -0.9992276486286049 Testing Score: -13.111020394798306
# Loss:  0.3055989836633426
# iteration 990 of 1000
#
# Mean Probability:  0.01251959600683966
# Training Score:  -0.9467472561997702 Testing Score: -13.110680951919683
# Loss:  0.2959551254837951
# iteration 991 of 1000
#
# Mean Probability:  0.013709278534995806
# Training Score:  -0.8559461132168809 Testing Score: -13.110264301765532
# Loss:  0.4660543497865941
# iteration 992 of 1000
#
# Mean Probability:  0.014063968930951794
# Training Score:  -0.8303958797570637 Testing Score: -13.111573146915584
# Loss:  0.2768756844292173
# iteration 993 of 1000
#
# Mean Probability:  0.013380056817252314
# Training Score:  -0.8802588004668447 Testing Score: -13.112421261805096
# Loss:  0.20510464313331564
# iteration 994 of 1000
#
# Mean Probability:  0.012781975622423374
# Training Score:  -0.9259997720619202 Testing Score: -13.11302233470827
# Loss:  0.2064315042490535
# iteration 995 of 1000
#
# Mean Probability:  0.013318574121110401
# Training Score:  -0.8848653902998836 Testing Score: -13.11316937441389
# Loss:  0.2876918867371492
# iteration 996 of 1000
#
# Mean Probability:  0.01379988314707821
# Training Score:  -0.8493557837968815 Testing Score: -13.113343665745365
# Loss:  0.28243798164311773
# iteration 997 of 1000
#
# Mean Probability:  0.013168822922069497
# Training Score:  -0.8961757998578276 Testing Score: -13.113327348973186
# Loss:  0.20547588753775425
# iteration 998 of 1000
#
# Mean Probability:  0.013690092045649412
# Training Score:  -0.8573457542607731 Testing Score: -13.112737646924275
# Loss:  0.2850507299731895
# iteration 999 of 1000
#
# Mean Probability:  0.014758902749993823
# Training Score:  -0.7821537807909458 Testing Score: -13.112526333889425
# Loss:  0.43896257469395383
#
# Time required for training on clustering with K = 2: 0h 3min 22sec
